# %%
import pickle
import numpy as np
import xgboost as xgb
import glob
import pandas as pd

fl = sorted(glob.glob('../features/*.pkl'))
for l in fl:
    print("'{}',".format(l))
# Out:
# '../features/cnn_1_aug1_feat.pkl',
# '../features/cnn_1_aug_1_fold8_feat.pkl',
# '../features/cnn_1_aug_rescale_preprocess_feat.pkl',
# '../features/cnn_1_aug_skimage_denoise_feat.pkl',
# '../features/cnn_1_aug_skimage_preprocess_feat.pkl',
# '../features/cnn_1_feat.pkl',
# '../features/cnn_2_aug1_feat.pkl',
# '../features/cnn_2_aug_1_fold8_feat.pkl',
# '../features/cnn_2_aug_denoise_preprocess_feat.pkl',
# '../features/cnn_2_aug_rescale_preprocess_feat.pkl',
# '../features/cnn_2_aug_skimage_preprocess_feat.pkl',
# '../features/cnn_2_feat.pkl',
# '../features/cnn_3_aug1_feat.pkl',
# '../features/cnn_3_aug_1_fold8_feat.pkl',
# '../features/cnn_3_aug_denoise_preprocess_feat.pkl',
# '../features/cnn_3_aug_rescale_preprocess_feat.pkl',
# '../features/cnn_3_aug_skimage_preprocess_feat.pkl',
# '../features/cnn_4_aug1_feat.pkl',
# '../features/cnn_4_aug1_feat_add_early.pkl',
# '../features/cnn_4_aug_1_fold8_feat.pkl',
# '../features/cnn_4_aug_denoise_preprocess_feat.pkl',
# '../features/cnn_4_aug_rescale_preprocess_feat.pkl',
# '../features/cnn_4_aug_skimage_preprocess_feat.pkl',
# '../features/cnn_5_aug1_feat.pkl',
# '../features/cnn_5_aug_1_fold8_feat.pkl',
# '../features/cnn_5_aug_denoise_preprocess_feat.pkl',
# '../features/cnn_5_aug_rescale_preprocess_feat.pkl',
# '../features/cnn_5_aug_skimage_preprocess_feat.pkl',
# '../features/incept_1_feat.pkl',
# '../features/incept_aug1_feat.pkl',
# '../features/incept_aug1_fold8_feat.pkl',
# '../features/incept_aug2_feat.pkl',
# '../features/incept_aug3_feat.pkl',
# '../features/incept_aug4_feat.pkl',
# '../features/other_feat.pkl',
# '../features/other_model_gbrt.pkl',
# '../features/other_model_gbrt2.pkl',
# '../features/other_model_gbrt4.pkl',
# '../features/other_model_gbrt5.pkl',
# '../features/other_model_gbrt6.pkl',
# '../features/other_model_lgb.pkl',
# '../features/other_model_lgb2.pkl',
# '../features/other_model_lgb4.pkl',
# '../features/other_model_lgb5.pkl',
# '../features/other_model_lgb6.pkl',
# '../features/other_model_lr.pkl',
# '../features/other_model_lr2.pkl',
# '../features/other_model_lr4.pkl',
# '../features/other_model_lr5.pkl',
# '../features/other_model_lr6.pkl',
# '../features/other_model_rf.pkl',
# '../features/other_model_rf2.pkl',
# '../features/other_model_rf4.pkl',
# '../features/other_model_rf5.pkl',
# '../features/other_model_rf6.pkl',
# '../features/other_model_xgb.pkl',
# '../features/other_model_xgb2.pkl',
# '../features/other_model_xgb4.pkl',
# '../features/other_model_xgb5.pkl',
# '../features/other_model_xgb6.pkl',
# '../features/resnet_1_feat.pkl',
# '../features/resnet_aug1_feat.pkl',
# '../features/resnet_aug1_fold8_feat.pkl',
# '../features/resnet_aug2_feat.pkl',
# '../features/resnet_aug3_feat.pkl',
# '../features/resnet_aug4_feat.pkl',
# '../features/vgg16_1_feat.pkl',
# '../features/vgg_aug1_feat.pkl',
# '../features/vgg_aug1_fold8_feat.pkl',
# '../features/vgg_aug1_new_feat.pkl',
# '../features/xception_aug1_feat.pkl',

# %%
choose_fl = [
#'../features/cnn_1_aug1_feat.pkl',
'../features/cnn_1_aug_1_fold8_feat.pkl',
'../features/cnn_1_aug_rescale_preprocess_feat.pkl',
'../features/cnn_1_aug_skimage_denoise_feat.pkl',
'../features/cnn_1_aug_skimage_preprocess_feat.pkl',
#'../features/cnn_1_feat.pkl',
#'../features/cnn_2_aug1_feat.pkl',
'../features/cnn_2_aug_1_fold8_feat.pkl',
'../features/cnn_2_aug_denoise_preprocess_feat.pkl',
'../features/cnn_2_aug_rescale_preprocess_feat.pkl',
'../features/cnn_2_aug_skimage_preprocess_feat.pkl',
#'../features/cnn_2_feat.pkl',
#'../features/cnn_3_aug1_feat.pkl',
'../features/cnn_3_aug_1_fold8_feat.pkl',
'../features/cnn_3_aug_denoise_preprocess_feat.pkl',
'../features/cnn_3_aug_rescale_preprocess_feat.pkl',
'../features/cnn_3_aug_skimage_preprocess_feat.pkl',
#'../features/cnn_4_aug1_feat.pkl',
#'../features/cnn_4_aug1_feat_add_early.pkl',
'../features/cnn_4_aug_1_fold8_feat.pkl',
'../features/cnn_4_aug_denoise_preprocess_feat.pkl',
'../features/cnn_4_aug_rescale_preprocess_feat.pkl',
'../features/cnn_4_aug_skimage_preprocess_feat.pkl',
#'../features/cnn_5_aug1_feat.pkl',
'../features/cnn_5_aug_1_fold8_feat.pkl',
'../features/cnn_5_aug_denoise_preprocess_feat.pkl',
'../features/cnn_5_aug_rescale_preprocess_feat.pkl',
'../features/cnn_5_aug_skimage_preprocess_feat.pkl',
#'../features/incept_1_feat.pkl',
#'../features/incept_aug1_feat.pkl',
'../features/incept_aug1_fold8_feat.pkl',
'../features/incept_aug2_feat.pkl',
'../features/incept_aug3_feat.pkl',
'../features/incept_aug4_feat.pkl',
#'../features/other_feat.pkl',
'../features/other_model_gbrt.pkl',
'../features/other_model_gbrt2.pkl',
'../features/other_model_gbrt4.pkl',
'../features/other_model_gbrt5.pkl',
'../features/other_model_gbrt6.pkl',
'../features/other_model_lgb.pkl',
'../features/other_model_lgb2.pkl',
'../features/other_model_lgb4.pkl',
'../features/other_model_lgb5.pkl',
'../features/other_model_lgb6.pkl',
'../features/other_model_lr.pkl',
'../features/other_model_lr2.pkl',
'../features/other_model_lr4.pkl',
#'../features/other_model_lr5.pkl',
#'../features/other_model_lr6.pkl',
'../features/other_model_rf.pkl',
'../features/other_model_rf2.pkl',
'../features/other_model_rf4.pkl',
'../features/other_model_rf5.pkl',
'../features/other_model_rf6.pkl',
'../features/other_model_xgb.pkl',
'../features/other_model_xgb2.pkl',
'../features/other_model_xgb4.pkl',
'../features/other_model_xgb5.pkl',
'../features/other_model_xgb6.pkl',
#'../features/resnet_1_feat.pkl',
#'../features/resnet_aug1_feat.pkl',
'../features/resnet_aug1_fold8_feat.pkl',
'../features/resnet_aug2_feat.pkl',
'../features/resnet_aug3_feat.pkl',
'../features/resnet_aug4_feat.pkl',
#'../features/vgg16_1_feat.pkl',
#'../features/vgg_aug1_feat.pkl',
'../features/vgg_aug1_fold8_feat.pkl',
'../features/vgg_aug1_new_feat.pkl',
'../features/xception_aug1_feat.pkl',
]

def load_x_y():
    train_x,test_x=[],[]
    for f in choose_fl:
        print(f)
        with open(f,'rb') as fin:
            a,b = pickle.load(fin)
            train_x.append(a)
            test_x.append(b)
    train_x = np.hstack(train_x)
    test_x = np.hstack(test_x)
    train_df = pd.read_json('../input/train.json')
    y = train_df.is_iceberg.values
    return train_x,test_x,y

train_x,test_x,train_y = load_x_y()
print(train_x.shape,test_x.shape,train_y.shape)
# Out:
# ../features/cnn_1_aug_1_fold8_feat.pkl
# ../features/cnn_1_aug_rescale_preprocess_feat.pkl
# ../features/cnn_1_aug_skimage_denoise_feat.pkl
# ../features/cnn_1_aug_skimage_preprocess_feat.pkl
# ../features/cnn_2_aug_1_fold8_feat.pkl
# ../features/cnn_2_aug_denoise_preprocess_feat.pkl
# ../features/cnn_2_aug_rescale_preprocess_feat.pkl
# ../features/cnn_2_aug_skimage_preprocess_feat.pkl
# ../features/cnn_3_aug_1_fold8_feat.pkl
# ../features/cnn_3_aug_denoise_preprocess_feat.pkl
# ../features/cnn_3_aug_rescale_preprocess_feat.pkl
# ../features/cnn_3_aug_skimage_preprocess_feat.pkl
# ../features/cnn_4_aug_1_fold8_feat.pkl
# ../features/cnn_4_aug_denoise_preprocess_feat.pkl
# ../features/cnn_4_aug_rescale_preprocess_feat.pkl
# ../features/cnn_4_aug_skimage_preprocess_feat.pkl
# ../features/cnn_5_aug_1_fold8_feat.pkl
# ../features/cnn_5_aug_denoise_preprocess_feat.pkl
# ../features/cnn_5_aug_rescale_preprocess_feat.pkl
# ../features/cnn_5_aug_skimage_preprocess_feat.pkl
# ../features/incept_aug1_fold8_feat.pkl
# ../features/incept_aug2_feat.pkl
# ../features/incept_aug3_feat.pkl
# ../features/incept_aug4_feat.pkl
# ../features/other_model_gbrt.pkl
# ../features/other_model_gbrt2.pkl
# ../features/other_model_gbrt4.pkl
# ../features/other_model_gbrt5.pkl
# ../features/other_model_gbrt6.pkl
# ../features/other_model_lgb.pkl
# ../features/other_model_lgb2.pkl
# ../features/other_model_lgb4.pkl
# ../features/other_model_lgb5.pkl
# ../features/other_model_lgb6.pkl
# ../features/other_model_lr.pkl
# ../features/other_model_lr2.pkl
# ../features/other_model_lr4.pkl
# ../features/other_model_rf.pkl
# ../features/other_model_rf2.pkl
# ../features/other_model_rf4.pkl
# ../features/other_model_rf5.pkl
# ../features/other_model_rf6.pkl
# ../features/other_model_xgb.pkl
# ../features/other_model_xgb2.pkl
# ../features/other_model_xgb4.pkl
# ../features/other_model_xgb5.pkl
# ../features/other_model_xgb6.pkl
# ../features/resnet_aug1_fold8_feat.pkl
# ../features/resnet_aug2_feat.pkl
# ../features/resnet_aug3_feat.pkl
# ../features/resnet_aug4_feat.pkl
# ../features/vgg_aug1_fold8_feat.pkl
# ../features/vgg_aug1_new_feat.pkl
# ../features/xception_aug1_feat.pkl
# (1604, 54) (8424, 54) (1604,)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import log_loss
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import log_loss
def cv_test(k_cnt=3,rnd=42,save_flag=False):
    kf = StratifiedKFold(n_splits=k_cnt, shuffle=True, random_state=rnd*2)
    w_test_pred = None
    r_val_loss = 0
    test_pred = None
    val_loss = 0
    val_loss_list = []
    for train_index, test_index in kf.split(train_x,train_y):
        X_train, X_test = train_x[train_index], train_x[test_index]
        y_train, y_test = train_y[train_index], train_y[test_index]

        # train model
        m = LogisticRegression()
        m.fit(X_train,y_train)
        
        # cal val loss
        curr_val_loss = log_loss(y_test,m.predict_proba(X_test))
        curr_tr_loss = log_loss(y_train,m.predict_proba(X_train))
        val_loss += curr_val_loss/k_cnt
        val_loss_list.append(curr_val_loss)
        curr_r_val_loss = 1.0 / curr_val_loss
        r_val_loss += curr_r_val_loss
        print('curr train loss',curr_tr_loss,'curr val loss', curr_val_loss)
        
        if test_pred is None:
            test_pred = m.predict_proba(test_x)
            w_test_pred = m.predict_proba(test_x)*curr_r_val_loss
        else:
            curr_pred = m.predict_proba(test_x)
            test_pred += curr_pred
            w_test_pred = w_test_pred + curr_pred*curr_r_val_loss

    # avg
    test_pred = test_pred / k_cnt
    w_test_pred = w_test_pred / r_val_loss
    
    # train log loss
    print('local average valid loss',val_loss,'val loss std',np.std(val_loss_list))
    print(test_pred.shape)
    if save_flag:
        test_df=pd.read_json('../input/test.json')
        submission = pd.DataFrame(columns=['id','is_iceberg'])
        submission['id']=test_df['id']
        submission['is_iceberg']=test_pred[:,1]
        print(submission.head())
        submission.to_csv('../results/some_lr_sub_fold_{}_rnd_{}.csv'.format(k_cnt,rnd), index=False)
        
        submission['is_iceberg']=w_test_pred[:,1]
        print(submission.head())
        submission.to_csv('../results/weighted_some_lr_sub_fold_{}_rnd_{}.csv'.format(k_cnt,rnd), index=False)

# %%
cv_test(3,42,True)
# Out:
# curr train loss 0.131406066308 curr val loss 0.152379653536
# curr train loss 0.129097754971 curr val loss 0.154450367745
# curr train loss 0.12925363892 curr val loss 0.161773860811
# local average valid loss 0.156201294031 val loss std 0.00403006118432
# (8424, 2)
#          id  is_iceberg
# 0  5941774d    0.011716
# 1  4023181e    0.783562
# 2  b20200e4    0.122994
# 3  e7f018bb    0.987833
# 4  4371c8c3    0.242462
#          id  is_iceberg
# 0  5941774d    0.011693
# 1  4023181e    0.784800
# 2  b20200e4    0.124543
# 3  e7f018bb    0.987794
# 4  4371c8c3    0.243812

# %%
cv_test(5,42,True)
# Out:
# curr train loss 0.1285566945 curr val loss 0.164557807282
# curr train loss 0.135703120508 curr val loss 0.135946129742
# curr train loss 0.129389767898 curr val loss 0.160336007209
# curr train loss 0.13730490488 curr val loss 0.135818240336
# curr train loss 0.12801486893 curr val loss 0.165182168634
# local average valid loss 0.152368070641 val loss std 0.0135635970592
# (8424, 2)
#          id  is_iceberg
# 0  5941774d    0.011383
# 1  4023181e    0.777053
# 2  b20200e4    0.112721
# 3  e7f018bb    0.988213
# 4  4371c8c3    0.228696
#          id  is_iceberg
# 0  5941774d    0.011466
# 1  4023181e    0.780591
# 2  b20200e4    0.115552
# 3  e7f018bb    0.988179
# 4  4371c8c3    0.232332

# %%
cv_test(10,42,True)
# Out:
# curr train loss 0.128038615199 curr val loss 0.191142753336
# curr train loss 0.133257685464 curr val loss 0.147993192099
# curr train loss 0.133761247422 curr val loss 0.141578086327
# curr train loss 0.134715455319 curr val loss 0.128880688038
# curr train loss 0.126602450798 curr val loss 0.201538713845
# curr train loss 0.136168588386 curr val loss 0.119917989342
# curr train loss 0.130684230366 curr val loss 0.177947075329
# curr train loss 0.138555886459 curr val loss 0.101403404215
# curr train loss 0.130718214094 curr val loss 0.169309132858
# curr train loss 0.130867439434 curr val loss 0.161264158766
# local average valid loss 0.154097519415 val loss std 0.0304127755391
# (8424, 2)
#          id  is_iceberg
# 0  5941774d    0.011566
# 1  4023181e    0.775284
# 2  b20200e4    0.107990
# 3  e7f018bb    0.988474
# 4  4371c8c3    0.219319
#          id  is_iceberg
# 0  5941774d    0.011832
# 1  4023181e    0.773607
# 2  b20200e4    0.108781
# 3  e7f018bb    0.988394
# 4  4371c8c3    0.221866

# %%
cv_test(3,252,True)
# Out:
# curr train loss 0.126505921207 curr val loss 0.160668611831
# curr train loss 0.129685715309 curr val loss 0.15439525484
# curr train loss 0.132903986051 curr val loss 0.150854173911
# local average valid loss 0.155306013527 val loss std 0.0040581530251
# (8424, 2)
#          id  is_iceberg
# 0  5941774d    0.011100
# 1  4023181e    0.783796
# 2  b20200e4    0.118060
# 3  e7f018bb    0.987645
# 4  4371c8c3    0.241504
#          id  is_iceberg
# 0  5941774d    0.011109
# 1  4023181e    0.785067
# 2  b20200e4    0.118473
# 3  e7f018bb    0.987646
# 4  4371c8c3    0.244003

# %%
cv_test(5,66,True)
# Out:
# curr train loss 0.132700558474 curr val loss 0.145341869223
# curr train loss 0.127246353001 curr val loss 0.167750978379
# curr train loss 0.133010057291 curr val loss 0.146804490559
# curr train loss 0.130202426224 curr val loss 0.160855617389
# curr train loss 0.13702321647 curr val loss 0.129369212648
# local average valid loss 0.15002443364 val loss std 0.0133452428002
# (8424, 2)
#          id  is_iceberg
# 0  5941774d    0.011641
# 1  4023181e    0.782223
# 2  b20200e4    0.108418
# 3  e7f018bb    0.988079
# 4  4371c8c3    0.219883
#          id  is_iceberg
# 0  5941774d    0.011661
# 1  4023181e    0.782961
# 2  b20200e4    0.109830
# 3  e7f018bb    0.987990
# 4  4371c8c3    0.220627
