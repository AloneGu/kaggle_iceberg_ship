# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

from keras.utils.np_utils import to_categorical
from keras.models import Sequential,load_model
from keras.layers import Dense, Dropout, Flatten, Lambda, Activation
from keras.layers import Conv2D, MaxPooling2D, ZeroPadding2D, GlobalAveragePooling2D
from keras.layers.normalization import BatchNormalization
from keras.optimizers import Adam

train_df = pd.read_json('../input/train.json')
test_df = pd.read_json('../input/test.json')
# Out:
# Using TensorFlow backend.

# %%
def std_img(x):
    for i in range(3):
        x[:, :, i] -= np.mean(x[:, :, i].flatten())
        x[:, :, i] /= np.std(x[:, :, i].flatten()) + 1e-7
    return x

def get_image(df):
    '''Create 3-channel 'images'. Return rescale-normalised images.'''
    images = []
    for i, row in df.iterrows():
        #make 75x75 image
        band_1 = np.array(row['band_1']).reshape(75, 75)
        band_2 = np.array(row['band_2']).reshape(75, 75)
        band_3 = band_1 + band_2 # plus since log(x*y) = log(x) + log(y)
        
        # Rescale
        img = np.dstack((band_1, band_2, band_3))
        images.append(std_img(img))

    return np.array(images)


train_x = get_image(train_df)
test_x = get_image(test_df)

print(train_x.shape,test_x.shape)
# Out:
# (1604, 75, 75, 3) (8424, 75, 75, 3)

# %%
y = train_df.is_iceberg.values
print(y[:5])
# Out:
# [0 0 1 0 0]

# %%
from keras.callbacks import ModelCheckpoint,LearningRateScheduler
def ConvBlock(model, layers, filters):
    '''Create [layers] layers consisting of zero padding, a convolution with [filters] 3x3 filters and batch normalization. Perform max pooling after the last layer.'''
    for i in range(layers):
        model.add(ZeroPadding2D((1, 1)))
        model.add(Conv2D(filters, (3, 3), activation='relu'))
        model.add(BatchNormalization(axis=3))
    model.add(MaxPooling2D((2, 2), strides=(2, 2)))

def create_model():
    '''Create the FCN and return a keras model.'''

    model = Sequential()

    # Input image: 75x75x3
    model.add(Lambda(lambda x: x, input_shape=(75, 75, 3)))
    ConvBlock(model, 1, 32)
    # 37x37x32
    ConvBlock(model, 1, 64)
    # 18x18x64
    ConvBlock(model, 1, 128)
    # 9x9x128
    ConvBlock(model, 1, 128)
    # 4x4x128
    model.add(Flatten())
    model.add(Dense(1,activation='sigmoid'))
    
    return model
print('model model')
# Out:
# model model

# %%
from sklearn.model_selection import KFold
from keras.preprocessing.image import ImageDataGenerator

def lr_f(epoch):
    if epoch<10:
        return 0.001
    elif epoch<30:
        return 0.0005
    else:
        return 0.0001

def kfold_train(fold_cnt=3,rnd=42):
    train_pred, test_pred,best_acc_pred = np.zeros((1604,1)),np.zeros((8424,1)),np.zeros((8424,1))
    kf = KFold(n_splits=fold_cnt, shuffle=True, random_state=2*rnd)
    for train_index, test_index in kf.split(train_x):
        curr_x,curr_y = train_x[train_index],y[train_index]
        val_x,val_y = train_x[test_index],y[test_index]
        datagen = ImageDataGenerator(
            width_shift_range=0.05,
            height_shift_range=0.05,
            shear_range=0.2,
            zoom_range=0.2,
            horizontal_flip=True,
            vertical_flip=True
        )
        
        
        bat_size = 16
        steps_train = len(curr_y)//bat_size
        
        
        model = create_model()
        model.compile(loss='binary_crossentropy', optimizer=Adam(0.0005), metrics=['accuracy'])
        model_p = 'best_m.h5'
        model_p2 = 'best_acc_m.h5'
        model_chk = ModelCheckpoint(filepath=model_p, monitor='val_loss', save_best_only=True, verbose=1)
        model_chk_2 = ModelCheckpoint(filepath=model_p2, monitor='val_acc', save_best_only=True, verbose=1)
        lr_s = LearningRateScheduler(lr_f)
        model.fit_generator(datagen.flow(curr_x, curr_y, batch_size=bat_size),
                  validation_data=(val_x,val_y),
                  steps_per_epoch = steps_train,
                  epochs=50, 
                  verbose=2,
                  callbacks=[model_chk,model_chk_2,lr_s]
                 )
        
        
        model = load_model(model_p)
        train_pred[test_index] = model.predict(val_x)
        test_pred = test_pred + model.predict(test_x)/fold_cnt
        
        model = load_model(model_p2)
        best_acc_pred = best_acc_pred + model.predict(test_x)/fold_cnt
        print('============================')
    return train_pred,test_pred,best_acc_pred

train_pred,test_pred,best_acc_pred = kfold_train(fold_cnt=4)
# Out:
# Epoch 1/50
# Epoch 00001: val_loss improved from inf to 0.46249, saving model to best_m.h5
# Epoch 00001: val_acc improved from -inf to 0.83042, saving model to best_acc_m.h5
#  - 4s - loss: 0.5897 - acc: 0.7220 - val_loss: 0.4625 - val_acc: 0.8304
# Epoch 2/50
# Epoch 00002: val_loss did not improve
# Epoch 00002: val_acc did not improve
#  - 2s - loss: 0.4120 - acc: 0.8072 - val_loss: 0.6816 - val_acc: 0.6035
# Epoch 3/50
# Epoch 00003: val_loss did not improve
# Epoch 00003: val_acc did not improve
#  - 2s - loss: 0.4033 - acc: 0.8039 - val_loss: 0.7368 - val_acc: 0.6633
# Epoch 4/50
# Epoch 00004: val_loss improved from 0.46249 to 0.40211, saving model to best_m.h5
# Epoch 00004: val_acc did not improve
#  - 2s - loss: 0.4098 - acc: 0.8206 - val_loss: 0.4021 - val_acc: 0.8155
# Epoch 5/50
# Epoch 00005: val_loss did not improve
# Epoch 00005: val_acc did not improve
#  - 2s - loss: 0.3523 - acc: 0.8433 - val_loss: 0.4736 - val_acc: 0.8180
# Epoch 6/50
# Epoch 00006: val_loss improved from 0.40211 to 0.23926, saving model to best_m.h5
# Epoch 00006: val_acc improved from 0.83042 to 0.89277, saving model to best_acc_m.h5
#  - 2s - loss: 0.4314 - acc: 0.8214 - val_loss: 0.2393 - val_acc: 0.8928
# Epoch 7/50
# Epoch 00007: val_loss did not improve
# Epoch 00007: val_acc did not improve
#  - 2s - loss: 0.4229 - acc: 0.8139 - val_loss: 0.4051 - val_acc: 0.8429
# Epoch 8/50
# Epoch 00008: val_loss did not improve
# Epoch 00008: val_acc did not improve
#  - 2s - loss: 0.3322 - acc: 0.8550 - val_loss: 0.4424 - val_acc: 0.8279
# Epoch 9/50
# Epoch 00009: val_loss improved from 0.23926 to 0.21814, saving model to best_m.h5
# Epoch 00009: val_acc improved from 0.89277 to 0.92768, saving model to best_acc_m.h5
#  - 2s - loss: 0.3585 - acc: 0.8441 - val_loss: 0.2181 - val_acc: 0.9277
# Epoch 10/50
# Epoch 00010: val_loss did not improve
# Epoch 00010: val_acc did not improve
#  - 2s - loss: 0.2987 - acc: 0.8658 - val_loss: 0.7155 - val_acc: 0.7182
# Epoch 11/50
# Epoch 00011: val_loss improved from 0.21814 to 0.20877, saving model to best_m.h5
# Epoch 00011: val_acc improved from 0.92768 to 0.93017, saving model to best_acc_m.h5
#  - 2s - loss: 0.2670 - acc: 0.8783 - val_loss: 0.2088 - val_acc: 0.9302
# Epoch 12/50
# Epoch 00012: val_loss did not improve
# Epoch 00012: val_acc did not improve
#  - 2s - loss: 0.2440 - acc: 0.9017 - val_loss: 0.2244 - val_acc: 0.9152
# Epoch 13/50
# Epoch 00013: val_loss improved from 0.20877 to 0.20598, saving model to best_m.h5
# Epoch 00013: val_acc did not improve
#  - 2s - loss: 0.2568 - acc: 0.8833 - val_loss: 0.2060 - val_acc: 0.9202
# Epoch 14/50
# Epoch 00014: val_loss improved from 0.20598 to 0.19966, saving model to best_m.h5
# Epoch 00014: val_acc did not improve
#  - 2s - loss: 0.2480 - acc: 0.8956 - val_loss: 0.1997 - val_acc: 0.9227
# Epoch 15/50
# Epoch 00015: val_loss did not improve
# Epoch 00015: val_acc did not improve
#  - 2s - loss: 0.2341 - acc: 0.9083 - val_loss: 0.3615 - val_acc: 0.8504
# Epoch 16/50
# Epoch 00016: val_loss did not improve
# Epoch 00016: val_acc did not improve
#  - 2s - loss: 0.2231 - acc: 0.9116 - val_loss: 0.2228 - val_acc: 0.9027
# Epoch 17/50
# Epoch 00017: val_loss did not improve
# Epoch 00017: val_acc did not improve
#  - 2s - loss: 0.2655 - acc: 0.8858 - val_loss: 0.2708 - val_acc: 0.8828
# Epoch 18/50
# Epoch 00018: val_loss did not improve
# Epoch 00018: val_acc did not improve
#  - 2s - loss: 0.2452 - acc: 0.8956 - val_loss: 0.2004 - val_acc: 0.9252
# Epoch 19/50
# Epoch 00019: val_loss did not improve
# Epoch 00019: val_acc did not improve
#  - 2s - loss: 0.2431 - acc: 0.9000 - val_loss: 0.2002 - val_acc: 0.9177
# Epoch 20/50
# Epoch 00020: val_loss did not improve
# Epoch 00020: val_acc did not improve
#  - 2s - loss: 0.2425 - acc: 0.8967 - val_loss: 0.5029 - val_acc: 0.7830
# Epoch 21/50
# Epoch 00021: val_loss did not improve
# Epoch 00021: val_acc did not improve
#  - 2s - loss: 0.2737 - acc: 0.8803 - val_loss: 0.2054 - val_acc: 0.9077
# Epoch 22/50
# Epoch 00022: val_loss did not improve
# Epoch 00022: val_acc did not improve
#  - 2s - loss: 0.2675 - acc: 0.8856 - val_loss: 0.2067 - val_acc: 0.9152
# Epoch 23/50
# Epoch 00023: val_loss improved from 0.19966 to 0.19631, saving model to best_m.h5
# Epoch 00023: val_acc did not improve
#  - 2s - loss: 0.2211 - acc: 0.9083 - val_loss: 0.1963 - val_acc: 0.9177
# Epoch 24/50
# Epoch 00024: val_loss did not improve
# Epoch 00024: val_acc did not improve
#  - 2s - loss: 0.2273 - acc: 0.9067 - val_loss: 0.2019 - val_acc: 0.9102
# Epoch 25/50
# Epoch 00025: val_loss did not improve
# Epoch 00025: val_acc did not improve
#  - 2s - loss: 0.1892 - acc: 0.9208 - val_loss: 0.2161 - val_acc: 0.9177
# Epoch 26/50
# Epoch 00026: val_loss did not improve
# Epoch 00026: val_acc did not improve
#  - 2s - loss: 0.2075 - acc: 0.9125 - val_loss: 0.2248 - val_acc: 0.9002
# Epoch 27/50
# Epoch 00027: val_loss did not improve
# Epoch 00027: val_acc did not improve
#  - 2s - loss: 0.2405 - acc: 0.8950 - val_loss: 0.3316 - val_acc: 0.8479
# Epoch 28/50
# Epoch 00028: val_loss did not improve
# Epoch 00028: val_acc did not improve
#  - 2s - loss: 0.2182 - acc: 0.9039 - val_loss: 0.2520 - val_acc: 0.9152
# Epoch 29/50
# Epoch 00029: val_loss improved from 0.19631 to 0.18151, saving model to best_m.h5
# Epoch 00029: val_acc did not improve
#  - 2s - loss: 0.2190 - acc: 0.9117 - val_loss: 0.1815 - val_acc: 0.9177
# Epoch 30/50
# Epoch 00030: val_loss did not improve
# Epoch 00030: val_acc did not improve
#  - 2s - loss: 0.2322 - acc: 0.9014 - val_loss: 0.3375 - val_acc: 0.8554
# Epoch 31/50
# Epoch 00031: val_loss did not improve
# Epoch 00031: val_acc did not improve
#  - 2s - loss: 0.2167 - acc: 0.9093 - val_loss: 0.1835 - val_acc: 0.9152
# Epoch 32/50
# Epoch 00032: val_loss did not improve
# Epoch 00032: val_acc did not improve
#  - 2s - loss: 0.1867 - acc: 0.9267 - val_loss: 0.2211 - val_acc: 0.9027
# Epoch 33/50
# Epoch 00033: val_loss improved from 0.18151 to 0.17599, saving model to best_m.h5
# Epoch 00033: val_acc did not improve
#  - 2s - loss: 0.2074 - acc: 0.9037 - val_loss: 0.1760 - val_acc: 0.9252
# Epoch 34/50
# Epoch 00034: val_loss improved from 0.17599 to 0.17338, saving model to best_m.h5
# Epoch 00034: val_acc did not improve
#  - 2s - loss: 0.1838 - acc: 0.9333 - val_loss: 0.1734 - val_acc: 0.9302
# Epoch 35/50
# Epoch 00035: val_loss did not improve
# Epoch 00035: val_acc improved from 0.93017 to 0.93516, saving model to best_acc_m.h5
#  - 2s - loss: 0.1958 - acc: 0.9208 - val_loss: 0.1786 - val_acc: 0.9352
# Epoch 36/50
# Epoch 00036: val_loss did not improve
# Epoch 00036: val_acc did not improve
#  - 2s - loss: 0.1939 - acc: 0.9162 - val_loss: 0.1925 - val_acc: 0.9177
# Epoch 37/50
# Epoch 00037: val_loss did not improve
# Epoch 00037: val_acc did not improve
#  - 2s - loss: 0.1933 - acc: 0.9217 - val_loss: 0.1760 - val_acc: 0.9302
# Epoch 38/50
# Epoch 00038: val_loss did not improve
# Epoch 00038: val_acc did not improve
#  - 2s - loss: 0.1775 - acc: 0.9292 - val_loss: 0.1802 - val_acc: 0.9227
# Epoch 39/50
# Epoch 00039: val_loss did not improve
# Epoch 00039: val_acc did not improve
#  - 2s - loss: 0.1949 - acc: 0.9133 - val_loss: 0.1768 - val_acc: 0.9227
# Epoch 40/50
# Epoch 00040: val_loss did not improve
# Epoch 00040: val_acc did not improve
#  - 2s - loss: 0.1779 - acc: 0.9254 - val_loss: 0.2364 - val_acc: 0.8978
# Epoch 41/50
# Epoch 00041: val_loss did not improve
# Epoch 00041: val_acc did not improve
#  - 2s - loss: 0.1735 - acc: 0.9342 - val_loss: 0.1748 - val_acc: 0.9252
# Epoch 42/50
# Epoch 00042: val_loss did not improve
# Epoch 00042: val_acc did not improve
#  - 2s - loss: 0.2000 - acc: 0.9092 - val_loss: 0.1752 - val_acc: 0.9277
# Epoch 43/50
# Epoch 00043: val_loss did not improve
# Epoch 00043: val_acc did not improve
#  - 2s - loss: 0.1967 - acc: 0.9162 - val_loss: 0.1878 - val_acc: 0.9202
# Epoch 44/50
# Epoch 00044: val_loss did not improve
# Epoch 00044: val_acc did not improve
#  - 2s - loss: 0.1912 - acc: 0.9243 - val_loss: 0.1893 - val_acc: 0.9177
# Epoch 45/50
# Epoch 00045: val_loss did not improve
# Epoch 00045: val_acc did not improve
#  - 2s - loss: 0.1731 - acc: 0.9300 - val_loss: 0.1797 - val_acc: 0.9202
# Epoch 46/50
# Epoch 00046: val_loss did not improve
# Epoch 00046: val_acc did not improve
#  - 2s - loss: 0.1706 - acc: 0.9217 - val_loss: 0.2058 - val_acc: 0.9152
# Epoch 47/50
# Epoch 00047: val_loss did not improve
# Epoch 00047: val_acc did not improve
#  - 2s - loss: 0.1949 - acc: 0.9197 - val_loss: 0.1967 - val_acc: 0.9202
# Epoch 48/50
# Epoch 00048: val_loss did not improve
# Epoch 00048: val_acc did not improve
#  - 2s - loss: 0.1706 - acc: 0.9275 - val_loss: 0.1845 - val_acc: 0.9177
# Epoch 49/50
# Epoch 00049: val_loss did not improve
# Epoch 00049: val_acc did not improve
#  - 2s - loss: 0.1733 - acc: 0.9333 - val_loss: 0.1807 - val_acc: 0.9277
# Epoch 50/50
# Epoch 00050: val_loss did not improve
# Epoch 00050: val_acc did not improve
#  - 2s - loss: 0.1616 - acc: 0.9325 - val_loss: 0.1831 - val_acc: 0.9277
# ============================
# Epoch 1/50
# Epoch 00001: val_loss improved from inf to 0.68997, saving model to best_m.h5
# Epoch 00001: val_acc improved from -inf to 0.65337, saving model to best_acc_m.h5
#  - 4s - loss: 0.6189 - acc: 0.7181 - val_loss: 0.6900 - val_acc: 0.6534
# Epoch 2/50
# Epoch 00002: val_loss improved from 0.68997 to 0.60734, saving model to best_m.h5
# Epoch 00002: val_acc improved from 0.65337 to 0.75561, saving model to best_acc_m.h5
#  - 3s - loss: 0.4092 - acc: 0.8200 - val_loss: 0.6073 - val_acc: 0.7556
# Epoch 3/50
# Epoch 00003: val_loss did not improve
# Epoch 00003: val_acc improved from 0.75561 to 0.76808, saving model to best_acc_m.h5
#  - 2s - loss: 0.3674 - acc: 0.8339 - val_loss: 0.6652 - val_acc: 0.7681
# Epoch 4/50
# Epoch 00004: val_loss improved from 0.60734 to 0.48390, saving model to best_m.h5
# Epoch 00004: val_acc improved from 0.76808 to 0.83042, saving model to best_acc_m.h5
#  - 2s - loss: 0.3349 - acc: 0.8383 - val_loss: 0.4839 - val_acc: 0.8304
# Epoch 5/50
# Epoch 00005: val_loss improved from 0.48390 to 0.47432, saving model to best_m.h5
# Epoch 00005: val_acc did not improve
#  - 2s - loss: 0.3955 - acc: 0.8212 - val_loss: 0.4743 - val_acc: 0.7955
# Epoch 6/50
# Epoch 00006: val_loss improved from 0.47432 to 0.35487, saving model to best_m.h5
# Epoch 00006: val_acc improved from 0.83042 to 0.86035, saving model to best_acc_m.h5
#  - 2s - loss: 0.4114 - acc: 0.8195 - val_loss: 0.3549 - val_acc: 0.8603
# Epoch 7/50
# Epoch 00007: val_loss did not improve
# Epoch 00007: val_acc did not improve
#  - 2s - loss: 0.2928 - acc: 0.8708 - val_loss: 0.6280 - val_acc: 0.7855
# Epoch 8/50
# Epoch 00008: val_loss improved from 0.35487 to 0.29620, saving model to best_m.h5
# Epoch 00008: val_acc improved from 0.86035 to 0.87032, saving model to best_acc_m.h5
#  - 2s - loss: 0.3293 - acc: 0.8625 - val_loss: 0.2962 - val_acc: 0.8703
# Epoch 9/50
# Epoch 00009: val_loss improved from 0.29620 to 0.28376, saving model to best_m.h5
# Epoch 00009: val_acc improved from 0.87032 to 0.87531, saving model to best_acc_m.h5
#  - 2s - loss: 0.2910 - acc: 0.8850 - val_loss: 0.2838 - val_acc: 0.8753
# Epoch 10/50
# Epoch 00010: val_loss did not improve
# Epoch 00010: val_acc did not improve
#  - 2s - loss: 0.2678 - acc: 0.8850 - val_loss: 0.2979 - val_acc: 0.8579
# Epoch 11/50
# Epoch 00011: val_loss improved from 0.28376 to 0.24986, saving model to best_m.h5
# Epoch 00011: val_acc did not improve
#  - 2s - loss: 0.2410 - acc: 0.9025 - val_loss: 0.2499 - val_acc: 0.8753
# Epoch 12/50
# Epoch 00012: val_loss improved from 0.24986 to 0.24568, saving model to best_m.h5
# Epoch 00012: val_acc improved from 0.87531 to 0.88529, saving model to best_acc_m.h5
#  - 2s - loss: 0.2583 - acc: 0.8892 - val_loss: 0.2457 - val_acc: 0.8853
# Epoch 13/50
# Epoch 00013: val_loss did not improve
# Epoch 00013: val_acc did not improve
#  - 2s - loss: 0.2493 - acc: 0.8964 - val_loss: 0.2492 - val_acc: 0.8853
# Epoch 14/50
# Epoch 00014: val_loss improved from 0.24568 to 0.21443, saving model to best_m.h5
# Epoch 00014: val_acc improved from 0.88529 to 0.90524, saving model to best_acc_m.h5
#  - 2s - loss: 0.2205 - acc: 0.9064 - val_loss: 0.2144 - val_acc: 0.9052
# Epoch 15/50
# Epoch 00015: val_loss did not improve
# Epoch 00015: val_acc did not improve
#  - 2s - loss: 0.2778 - acc: 0.8766 - val_loss: 0.2686 - val_acc: 0.8853
# Epoch 16/50
# Epoch 00016: val_loss did not improve
# Epoch 00016: val_acc did not improve
#  - 2s - loss: 0.2229 - acc: 0.9025 - val_loss: 0.2317 - val_acc: 0.8978
# Epoch 17/50
# Epoch 00017: val_loss did not improve
# Epoch 00017: val_acc did not improve
#  - 2s - loss: 0.2100 - acc: 0.9175 - val_loss: 0.3391 - val_acc: 0.8554
# Epoch 18/50
# Epoch 00018: val_loss did not improve
# Epoch 00018: val_acc did not improve
#  - 2s - loss: 0.2488 - acc: 0.8981 - val_loss: 0.4021 - val_acc: 0.8429
# Epoch 19/50
# Epoch 00019: val_loss did not improve
# Epoch 00019: val_acc did not improve
#  - 2s - loss: 0.2477 - acc: 0.8975 - val_loss: 0.2429 - val_acc: 0.8778
# Epoch 20/50
# Epoch 00020: val_loss did not improve
# Epoch 00020: val_acc did not improve
#  - 2s - loss: 0.2077 - acc: 0.9183 - val_loss: 0.3333 - val_acc: 0.8753
# Epoch 21/50
# Epoch 00021: val_loss did not improve
# Epoch 00021: val_acc did not improve
#  - 2s - loss: 0.2224 - acc: 0.9006 - val_loss: 0.2147 - val_acc: 0.9052
# Epoch 22/50
# Epoch 00022: val_loss did not improve
# Epoch 00022: val_acc did not improve
#  - 2s - loss: 0.2263 - acc: 0.9050 - val_loss: 0.3763 - val_acc: 0.8479
# Epoch 23/50
# Epoch 00023: val_loss did not improve
# Epoch 00023: val_acc did not improve
#  - 2s - loss: 0.2032 - acc: 0.9142 - val_loss: 0.2483 - val_acc: 0.8778
# Epoch 24/50
# Epoch 00024: val_loss did not improve
# Epoch 00024: val_acc did not improve
#  - 2s - loss: 0.2097 - acc: 0.9050 - val_loss: 0.2365 - val_acc: 0.9052
# Epoch 25/50
# Epoch 00025: val_loss did not improve
# Epoch 00025: val_acc improved from 0.90524 to 0.91022, saving model to best_acc_m.h5
#  - 2s - loss: 0.1994 - acc: 0.9116 - val_loss: 0.2237 - val_acc: 0.9102
# Epoch 26/50
# Epoch 00026: val_loss did not improve
# Epoch 00026: val_acc did not improve
#  - 2s - loss: 0.2051 - acc: 0.9081 - val_loss: 0.2700 - val_acc: 0.8878
# Epoch 27/50
# Epoch 00027: val_loss did not improve
# Epoch 00027: val_acc improved from 0.91022 to 0.91521, saving model to best_acc_m.h5
#  - 2s - loss: 0.1931 - acc: 0.9208 - val_loss: 0.2380 - val_acc: 0.9152
# Epoch 28/50
# Epoch 00028: val_loss did not improve
# Epoch 00028: val_acc did not improve
#  - 2s - loss: 0.1933 - acc: 0.9192 - val_loss: 0.2684 - val_acc: 0.8953
# Epoch 29/50
# Epoch 00029: val_loss did not improve
# Epoch 00029: val_acc did not improve
#  - 2s - loss: 0.2654 - acc: 0.8970 - val_loss: 0.3636 - val_acc: 0.8504
# Epoch 30/50
# Epoch 00030: val_loss did not improve
# Epoch 00030: val_acc did not improve
#  - 2s - loss: 0.2303 - acc: 0.9008 - val_loss: 0.6979 - val_acc: 0.7606
# Epoch 31/50
# Epoch 00031: val_loss did not improve
# Epoch 00031: val_acc did not improve
#  - 2s - loss: 0.1917 - acc: 0.9166 - val_loss: 0.2174 - val_acc: 0.8928
# Epoch 32/50
# Epoch 00032: val_loss did not improve
# Epoch 00032: val_acc did not improve
#  - 2s - loss: 0.1826 - acc: 0.9200 - val_loss: 0.2222 - val_acc: 0.8903
# Epoch 33/50
# Epoch 00033: val_loss did not improve
# Epoch 00033: val_acc did not improve
#  - 2s - loss: 0.1826 - acc: 0.9173 - val_loss: 0.2210 - val_acc: 0.9027
# Epoch 34/50
# Epoch 00034: val_loss improved from 0.21443 to 0.20757, saving model to best_m.h5
# Epoch 00034: val_acc did not improve
#  - 2s - loss: 0.1745 - acc: 0.9300 - val_loss: 0.2076 - val_acc: 0.9077
# Epoch 35/50
# Epoch 00035: val_loss did not improve
# Epoch 00035: val_acc did not improve
#  - 2s - loss: 0.1729 - acc: 0.9298 - val_loss: 0.2183 - val_acc: 0.9052
# Epoch 36/50
# Epoch 00036: val_loss did not improve
# Epoch 00036: val_acc did not improve
#  - 2s - loss: 0.1664 - acc: 0.9392 - val_loss: 0.2095 - val_acc: 0.9077
# Epoch 37/50
# Epoch 00037: val_loss did not improve
# Epoch 00037: val_acc did not improve
#  - 2s - loss: 0.1835 - acc: 0.9197 - val_loss: 0.2087 - val_acc: 0.9077
# Epoch 38/50
# Epoch 00038: val_loss did not improve
# Epoch 00038: val_acc did not improve
#  - 2s - loss: 0.1717 - acc: 0.9275 - val_loss: 0.2234 - val_acc: 0.8903
# Epoch 39/50
# Epoch 00039: val_loss did not improve
# Epoch 00039: val_acc did not improve
#  - 2s - loss: 0.1596 - acc: 0.9358 - val_loss: 0.2202 - val_acc: 0.9002
# Epoch 40/50
# Epoch 00040: val_loss improved from 0.20757 to 0.20671, saving model to best_m.h5
# Epoch 00040: val_acc did not improve
#  - 2s - loss: 0.1616 - acc: 0.9275 - val_loss: 0.2067 - val_acc: 0.9127
# Epoch 41/50
# Epoch 00041: val_loss improved from 0.20671 to 0.20586, saving model to best_m.h5
# Epoch 00041: val_acc did not improve
#  - 2s - loss: 0.1537 - acc: 0.9342 - val_loss: 0.2059 - val_acc: 0.9027
# Epoch 42/50
# Epoch 00042: val_loss did not improve
# Epoch 00042: val_acc did not improve
#  - 2s - loss: 0.1579 - acc: 0.9358 - val_loss: 0.2106 - val_acc: 0.9077
# Epoch 43/50
# Epoch 00043: val_loss did not improve
# Epoch 00043: val_acc did not improve
#  - 2s - loss: 0.1791 - acc: 0.9250 - val_loss: 0.2123 - val_acc: 0.9052
# Epoch 44/50
# Epoch 00044: val_loss did not improve
# Epoch 00044: val_acc did not improve
#  - 2s - loss: 0.1415 - acc: 0.9381 - val_loss: 0.2252 - val_acc: 0.9077
# Epoch 45/50
# Epoch 00045: val_loss did not improve
# Epoch 00045: val_acc did not improve
#  - 2s - loss: 0.1513 - acc: 0.9356 - val_loss: 0.2412 - val_acc: 0.8803
# Epoch 46/50
# Epoch 00046: val_loss did not improve
# Epoch 00046: val_acc did not improve
#  - 2s - loss: 0.1619 - acc: 0.9339 - val_loss: 0.2752 - val_acc: 0.8803
# Epoch 47/50
# Epoch 00047: val_loss did not improve
# Epoch 00047: val_acc did not improve
#  - 2s - loss: 0.1679 - acc: 0.9375 - val_loss: 0.2178 - val_acc: 0.9127
# Epoch 48/50
# Epoch 00048: val_loss did not improve
# Epoch 00048: val_acc did not improve
#  - 2s - loss: 0.1602 - acc: 0.9333 - val_loss: 0.2336 - val_acc: 0.8853
# Epoch 49/50
# Epoch 00049: val_loss did not improve
# Epoch 00049: val_acc did not improve
#  - 2s - loss: 0.1611 - acc: 0.9314 - val_loss: 0.2434 - val_acc: 0.8878
# Epoch 50/50
# Epoch 00050: val_loss did not improve
# Epoch 00050: val_acc did not improve
#  - 2s - loss: 0.1494 - acc: 0.9392 - val_loss: 0.2261 - val_acc: 0.8928
# ============================
# Epoch 1/50
# Epoch 00001: val_loss improved from inf to 0.55196, saving model to best_m.h5
# Epoch 00001: val_acc improved from -inf to 0.72319, saving model to best_acc_m.h5
#  - 4s - loss: 0.6502 - acc: 0.7289 - val_loss: 0.5520 - val_acc: 0.7232
# Epoch 2/50
# Epoch 00002: val_loss improved from 0.55196 to 0.48205, saving model to best_m.h5
# Epoch 00002: val_acc improved from 0.72319 to 0.77556, saving model to best_acc_m.h5
#  - 2s - loss: 0.4097 - acc: 0.8233 - val_loss: 0.4820 - val_acc: 0.7756
# Epoch 3/50
# Epoch 00003: val_loss did not improve
# Epoch 00003: val_acc did not improve
#  - 2s - loss: 0.4631 - acc: 0.7991 - val_loss: 0.5615 - val_acc: 0.7606
# Epoch 4/50
# Epoch 00004: val_loss improved from 0.48205 to 0.37212, saving model to best_m.h5
# Epoch 00004: val_acc improved from 0.77556 to 0.82544, saving model to best_acc_m.h5
#  - 2s - loss: 0.3598 - acc: 0.8383 - val_loss: 0.3721 - val_acc: 0.8254
# Epoch 5/50
# Epoch 00005: val_loss did not improve
# Epoch 00005: val_acc did not improve
#  - 2s - loss: 0.3542 - acc: 0.8464 - val_loss: 0.6162 - val_acc: 0.7855
# Epoch 6/50
# Epoch 00006: val_loss did not improve
# Epoch 00006: val_acc did not improve
#  - 2s - loss: 0.3509 - acc: 0.8489 - val_loss: 0.5607 - val_acc: 0.7880
# Epoch 7/50
# Epoch 00007: val_loss did not improve
# Epoch 00007: val_acc did not improve
#  - 2s - loss: 0.3469 - acc: 0.8572 - val_loss: 0.6039 - val_acc: 0.7855
# Epoch 8/50
# Epoch 00008: val_loss did not improve
# Epoch 00008: val_acc did not improve
#  - 2s - loss: 0.3585 - acc: 0.8466 - val_loss: 0.6394 - val_acc: 0.7431
# Epoch 9/50
# Epoch 00009: val_loss did not improve
# Epoch 00009: val_acc did not improve
#  - 2s - loss: 0.3422 - acc: 0.8625 - val_loss: 0.4837 - val_acc: 0.8080
# Epoch 10/50
# Epoch 00010: val_loss improved from 0.37212 to 0.27795, saving model to best_m.h5
# Epoch 00010: val_acc improved from 0.82544 to 0.89526, saving model to best_acc_m.h5
#  - 2s - loss: 0.3773 - acc: 0.8378 - val_loss: 0.2779 - val_acc: 0.8953
# Epoch 11/50
# Epoch 00011: val_loss improved from 0.27795 to 0.23617, saving model to best_m.h5
# Epoch 00011: val_acc did not improve
#  - 2s - loss: 0.2697 - acc: 0.8858 - val_loss: 0.2362 - val_acc: 0.8853
# Epoch 12/50
# Epoch 00012: val_loss improved from 0.23617 to 0.22108, saving model to best_m.h5
# Epoch 00012: val_acc did not improve
#  - 2s - loss: 0.2531 - acc: 0.8879 - val_loss: 0.2211 - val_acc: 0.8853
# Epoch 13/50
# Epoch 00013: val_loss improved from 0.22108 to 0.19059, saving model to best_m.h5
# Epoch 00013: val_acc improved from 0.89526 to 0.91771, saving model to best_acc_m.h5
#  - 2s - loss: 0.2722 - acc: 0.8748 - val_loss: 0.1906 - val_acc: 0.9177
# Epoch 14/50
# Epoch 00014: val_loss did not improve
# Epoch 00014: val_acc did not improve
#  - 2s - loss: 0.2515 - acc: 0.8833 - val_loss: 0.2291 - val_acc: 0.9127
# Epoch 15/50
# Epoch 00015: val_loss did not improve
# Epoch 00015: val_acc did not improve
#  - 2s - loss: 0.2691 - acc: 0.8758 - val_loss: 0.2368 - val_acc: 0.9052
# Epoch 16/50
# Epoch 00016: val_loss did not improve
# Epoch 00016: val_acc did not improve
#  - 2s - loss: 0.2849 - acc: 0.8651 - val_loss: 0.3416 - val_acc: 0.8279
# Epoch 17/50
# Epoch 00017: val_loss did not improve
# Epoch 00017: val_acc did not improve
#  - 2s - loss: 0.2326 - acc: 0.8964 - val_loss: 0.2977 - val_acc: 0.8603
# Epoch 18/50
# Epoch 00018: val_loss did not improve
# Epoch 00018: val_acc did not improve
#  - 2s - loss: 0.2823 - acc: 0.8733 - val_loss: 0.2698 - val_acc: 0.8878
# Epoch 19/50
# Epoch 00019: val_loss did not improve
# Epoch 00019: val_acc did not improve
#  - 2s - loss: 0.2767 - acc: 0.8737 - val_loss: 0.3496 - val_acc: 0.8454
# Epoch 20/50
# Epoch 00020: val_loss did not improve
# Epoch 00020: val_acc did not improve
#  - 2s - loss: 0.2822 - acc: 0.8942 - val_loss: 0.6398 - val_acc: 0.7257
# Epoch 21/50
# Epoch 00021: val_loss did not improve
# Epoch 00021: val_acc did not improve
#  - 2s - loss: 0.2489 - acc: 0.8989 - val_loss: 0.3975 - val_acc: 0.8229
# Epoch 22/50
# Epoch 00022: val_loss did not improve
# Epoch 00022: val_acc did not improve
#  - 2s - loss: 0.2220 - acc: 0.9133 - val_loss: 0.2270 - val_acc: 0.8878
# Epoch 23/50
# Epoch 00023: val_loss did not improve
# Epoch 00023: val_acc did not improve
#  - 2s - loss: 0.2399 - acc: 0.8989 - val_loss: 0.2617 - val_acc: 0.8853
# Epoch 24/50
# Epoch 00024: val_loss did not improve
# Epoch 00024: val_acc did not improve
#  - 2s - loss: 0.2160 - acc: 0.9067 - val_loss: 0.2473 - val_acc: 0.8678
# Epoch 25/50
# Epoch 00025: val_loss did not improve
# Epoch 00025: val_acc did not improve
#  - 2s - loss: 0.2184 - acc: 0.9000 - val_loss: 0.2192 - val_acc: 0.9052
# Epoch 26/50
# Epoch 00026: val_loss did not improve
# Epoch 00026: val_acc did not improve
#  - 2s - loss: 0.2273 - acc: 0.9133 - val_loss: 0.2580 - val_acc: 0.8778
# Epoch 27/50
# Epoch 00027: val_loss did not improve
# Epoch 00027: val_acc did not improve
#  - 2s - loss: 0.2201 - acc: 0.9125 - val_loss: 0.4239 - val_acc: 0.8254
# Epoch 28/50
# Epoch 00028: val_loss did not improve
# Epoch 00028: val_acc did not improve
#  - 2s - loss: 0.2420 - acc: 0.8889 - val_loss: 0.2276 - val_acc: 0.9027
# Epoch 29/50
# Epoch 00029: val_loss did not improve
# Epoch 00029: val_acc did not improve
#  - 2s - loss: 0.2055 - acc: 0.9217 - val_loss: 0.2360 - val_acc: 0.8853
# Epoch 30/50
# Epoch 00030: val_loss did not improve
# Epoch 00030: val_acc did not improve
#  - 2s - loss: 0.2218 - acc: 0.9075 - val_loss: 0.2909 - val_acc: 0.8803
# Epoch 31/50
# Epoch 00031: val_loss did not improve
# Epoch 00031: val_acc did not improve
#  - 2s - loss: 0.2135 - acc: 0.9117 - val_loss: 0.2357 - val_acc: 0.8928
# Epoch 32/50
# Epoch 00032: val_loss did not improve
# Epoch 00032: val_acc did not improve
#  - 2s - loss: 0.2106 - acc: 0.9141 - val_loss: 0.2178 - val_acc: 0.9027
# Epoch 33/50
# Epoch 00033: val_loss did not improve
# Epoch 00033: val_acc did not improve
#  - 2s - loss: 0.1948 - acc: 0.9225 - val_loss: 0.2347 - val_acc: 0.9052
# Epoch 34/50
# Epoch 00034: val_loss did not improve
# Epoch 00034: val_acc did not improve
#  - 2s - loss: 0.1805 - acc: 0.9164 - val_loss: 0.2124 - val_acc: 0.9027
# Epoch 35/50
# Epoch 00035: val_loss did not improve
# Epoch 00035: val_acc did not improve
#  - 2s - loss: 0.1900 - acc: 0.9256 - val_loss: 0.2123 - val_acc: 0.9152
# Epoch 36/50
# Epoch 00036: val_loss did not improve
# Epoch 00036: val_acc did not improve
#  - 2s - loss: 0.1919 - acc: 0.9239 - val_loss: 0.2416 - val_acc: 0.8878
# Epoch 37/50
# Epoch 00037: val_loss did not improve
# Epoch 00037: val_acc did not improve
#  - 2s - loss: 0.1955 - acc: 0.9112 - val_loss: 0.2215 - val_acc: 0.9027
# Epoch 38/50
# Epoch 00038: val_loss did not improve
# Epoch 00038: val_acc did not improve
#  - 2s - loss: 0.1906 - acc: 0.9192 - val_loss: 0.2026 - val_acc: 0.9152
# Epoch 39/50
# Epoch 00039: val_loss did not improve
# Epoch 00039: val_acc did not improve
#  - 2s - loss: 0.1885 - acc: 0.9250 - val_loss: 0.2249 - val_acc: 0.8928
# Epoch 40/50
# Epoch 00040: val_loss did not improve
# Epoch 00040: val_acc did not improve
#  - 2s - loss: 0.1532 - acc: 0.9442 - val_loss: 0.2441 - val_acc: 0.8903
# Epoch 41/50
# Epoch 00041: val_loss did not improve
# Epoch 00041: val_acc did not improve
#  - 2s - loss: 0.1913 - acc: 0.9195 - val_loss: 0.2217 - val_acc: 0.9127
# Epoch 42/50
# Epoch 00042: val_loss did not improve
# Epoch 00042: val_acc did not improve
#  - 2s - loss: 0.1736 - acc: 0.9283 - val_loss: 0.2101 - val_acc: 0.9102
# Epoch 43/50
# Epoch 00043: val_loss did not improve
# Epoch 00043: val_acc did not improve
#  - 2s - loss: 0.1776 - acc: 0.9250 - val_loss: 0.2170 - val_acc: 0.9152
# Epoch 44/50
# Epoch 00044: val_loss did not improve
# Epoch 00044: val_acc did not improve
#  - 2s - loss: 0.1654 - acc: 0.9300 - val_loss: 0.2163 - val_acc: 0.9102
# Epoch 45/50
# Epoch 00045: val_loss did not improve
# Epoch 00045: val_acc did not improve
#  - 2s - loss: 0.1536 - acc: 0.9364 - val_loss: 0.2103 - val_acc: 0.9177
# Epoch 46/50
# Epoch 00046: val_loss did not improve
# Epoch 00046: val_acc did not improve
#  - 3s - loss: 0.1766 - acc: 0.9217 - val_loss: 0.2279 - val_acc: 0.9027
# Epoch 47/50
# Epoch 00047: val_loss did not improve
# Epoch 00047: val_acc did not improve
#  - 2s - loss: 0.1677 - acc: 0.9216 - val_loss: 0.2329 - val_acc: 0.9152
# Epoch 48/50
# Epoch 00048: val_loss did not improve
# Epoch 00048: val_acc did not improve
#  - 2s - loss: 0.2020 - acc: 0.9206 - val_loss: 0.2158 - val_acc: 0.9177
# Epoch 49/50
# Epoch 00049: val_loss did not improve
# Epoch 00049: val_acc did not improve
#  - 2s - loss: 0.1770 - acc: 0.9258 - val_loss: 0.2075 - val_acc: 0.9152
# Epoch 50/50
# Epoch 00050: val_loss did not improve
# Epoch 00050: val_acc did not improve
#  - 2s - loss: 0.1684 - acc: 0.9314 - val_loss: 0.2473 - val_acc: 0.9127
# ============================
# Epoch 1/50
# Epoch 00001: val_loss improved from inf to 0.48832, saving model to best_m.h5
# Epoch 00001: val_acc improved from -inf to 0.76559, saving model to best_acc_m.h5
#  - 5s - loss: 0.6622 - acc: 0.7231 - val_loss: 0.4883 - val_acc: 0.7656
# Epoch 2/50
# Epoch 00002: val_loss did not improve
# Epoch 00002: val_acc did not improve
#  - 2s - loss: 0.4180 - acc: 0.8108 - val_loss: 0.5179 - val_acc: 0.7332
# Epoch 3/50
# Epoch 00003: val_loss improved from 0.48832 to 0.44175, saving model to best_m.h5
# Epoch 00003: val_acc improved from 0.76559 to 0.79302, saving model to best_acc_m.h5
#  - 2s - loss: 0.4329 - acc: 0.8053 - val_loss: 0.4418 - val_acc: 0.7930
# Epoch 4/50
# Epoch 00004: val_loss improved from 0.44175 to 0.36423, saving model to best_m.h5
# Epoch 00004: val_acc improved from 0.79302 to 0.81796, saving model to best_acc_m.h5
#  - 2s - loss: 0.3463 - acc: 0.8347 - val_loss: 0.3642 - val_acc: 0.8180
# Epoch 5/50
# Epoch 00005: val_loss did not improve
# Epoch 00005: val_acc did not improve
#  - 2s - loss: 0.3409 - acc: 0.8464 - val_loss: 0.6035 - val_acc: 0.7282
# Epoch 6/50
# Epoch 00006: val_loss did not improve
# Epoch 00006: val_acc did not improve
#  - 2s - loss: 0.4242 - acc: 0.8203 - val_loss: 0.6765 - val_acc: 0.7456
# Epoch 7/50
# Epoch 00007: val_loss improved from 0.36423 to 0.34924, saving model to best_m.h5
# Epoch 00007: val_acc improved from 0.81796 to 0.84788, saving model to best_acc_m.h5
#  - 2s - loss: 0.3499 - acc: 0.8483 - val_loss: 0.3492 - val_acc: 0.8479
# Epoch 8/50
# Epoch 00008: val_loss did not improve
# Epoch 00008: val_acc did not improve
#  - 2s - loss: 0.3258 - acc: 0.8675 - val_loss: 0.6156 - val_acc: 0.8030
# Epoch 9/50
# Epoch 00009: val_loss did not improve
# Epoch 00009: val_acc did not improve
#  - 2s - loss: 0.3218 - acc: 0.8704 - val_loss: 0.4045 - val_acc: 0.8454
# Epoch 10/50
# Epoch 00010: val_loss did not improve
# Epoch 00010: val_acc did not improve
#  - 2s - loss: 0.3087 - acc: 0.8639 - val_loss: 0.3652 - val_acc: 0.8254
# Epoch 11/50
# Epoch 00011: val_loss improved from 0.34924 to 0.32596, saving model to best_m.h5
# Epoch 00011: val_acc improved from 0.84788 to 0.86534, saving model to best_acc_m.h5
#  - 2s - loss: 0.2491 - acc: 0.8925 - val_loss: 0.3260 - val_acc: 0.8653
# Epoch 12/50
# Epoch 00012: val_loss improved from 0.32596 to 0.28645, saving model to best_m.h5
# Epoch 00012: val_acc improved from 0.86534 to 0.88279, saving model to best_acc_m.h5
#  - 2s - loss: 0.2210 - acc: 0.9117 - val_loss: 0.2865 - val_acc: 0.8828
# Epoch 13/50
# Epoch 00013: val_loss did not improve
# Epoch 00013: val_acc did not improve
#  - 2s - loss: 0.2102 - acc: 0.9117 - val_loss: 0.3081 - val_acc: 0.8803
# Epoch 14/50
# Epoch 00014: val_loss did not improve
# Epoch 00014: val_acc did not improve
#  - 2s - loss: 0.2585 - acc: 0.8942 - val_loss: 0.3167 - val_acc: 0.8703
# Epoch 15/50
# Epoch 00015: val_loss did not improve
# Epoch 00015: val_acc did not improve
#  - 2s - loss: 0.2215 - acc: 0.9092 - val_loss: 0.3198 - val_acc: 0.8479
# Epoch 16/50
# Epoch 00016: val_loss did not improve
# Epoch 00016: val_acc did not improve
#  - 2s - loss: 0.2285 - acc: 0.8970 - val_loss: 0.3267 - val_acc: 0.8678
# Epoch 17/50
# Epoch 00017: val_loss improved from 0.28645 to 0.27011, saving model to best_m.h5
# Epoch 00017: val_acc improved from 0.88279 to 0.88529, saving model to best_acc_m.h5
#  - 3s - loss: 0.1882 - acc: 0.9192 - val_loss: 0.2701 - val_acc: 0.8853
# Epoch 18/50
# Epoch 00018: val_loss did not improve
# Epoch 00018: val_acc did not improve
#  - 2s - loss: 0.2175 - acc: 0.9064 - val_loss: 0.3772 - val_acc: 0.8454
# Epoch 19/50
# Epoch 00019: val_loss did not improve
# Epoch 00019: val_acc did not improve
#  - 2s - loss: 0.2120 - acc: 0.9158 - val_loss: 0.2985 - val_acc: 0.8753
# Epoch 20/50
# Epoch 00020: val_loss did not improve
# Epoch 00020: val_acc improved from 0.88529 to 0.89027, saving model to best_acc_m.h5
#  - 2s - loss: 0.1954 - acc: 0.9131 - val_loss: 0.3068 - val_acc: 0.8903
# Epoch 21/50
# Epoch 00021: val_loss did not improve
# Epoch 00021: val_acc did not improve
#  - 2s - loss: 0.2027 - acc: 0.9142 - val_loss: 0.3561 - val_acc: 0.8379
# Epoch 22/50
# Epoch 00022: val_loss did not improve
# Epoch 00022: val_acc did not improve
#  - 2s - loss: 0.2109 - acc: 0.9047 - val_loss: 0.4451 - val_acc: 0.8204
# Epoch 23/50
# Epoch 00023: val_loss did not improve
# Epoch 00023: val_acc did not improve
#  - 2s - loss: 0.2195 - acc: 0.9042 - val_loss: 0.4150 - val_acc: 0.8155
# Epoch 24/50
# Epoch 00024: val_loss did not improve
# Epoch 00024: val_acc did not improve
#  - 2s - loss: 0.2263 - acc: 0.9056 - val_loss: 0.3916 - val_acc: 0.8479
# Epoch 25/50
# Epoch 00025: val_loss did not improve
# Epoch 00025: val_acc did not improve
#  - 2s - loss: 0.2113 - acc: 0.9064 - val_loss: 0.5236 - val_acc: 0.8180
# Epoch 26/50
# Epoch 00026: val_loss did not improve
# Epoch 00026: val_acc did not improve
#  - 3s - loss: 0.1624 - acc: 0.9333 - val_loss: 0.3860 - val_acc: 0.8603
# Epoch 27/50
# Epoch 00027: val_loss did not improve
# Epoch 00027: val_acc did not improve
#  - 2s - loss: 0.2094 - acc: 0.9100 - val_loss: 0.2768 - val_acc: 0.8728
# Epoch 28/50
# Epoch 00028: val_loss did not improve
# Epoch 00028: val_acc did not improve
#  - 2s - loss: 0.1942 - acc: 0.9100 - val_loss: 0.4666 - val_acc: 0.8429
# Epoch 29/50
# Epoch 00029: val_loss did not improve
# Epoch 00029: val_acc did not improve
#  - 2s - loss: 0.1932 - acc: 0.9233 - val_loss: 0.2997 - val_acc: 0.8903
# Epoch 30/50
# Epoch 00030: val_loss did not improve
# Epoch 00030: val_acc did not improve
#  - 2s - loss: 0.1783 - acc: 0.9250 - val_loss: 0.5057 - val_acc: 0.8180
# Epoch 31/50
# Epoch 00031: val_loss did not improve
# Epoch 00031: val_acc did not improve
#  - 2s - loss: 0.1702 - acc: 0.9275 - val_loss: 0.2776 - val_acc: 0.8878
# Epoch 32/50
# Epoch 00032: val_loss did not improve
# Epoch 00032: val_acc did not improve
#  - 2s - loss: 0.2029 - acc: 0.9154 - val_loss: 0.3120 - val_acc: 0.8778
# Epoch 33/50
# Epoch 00033: val_loss did not improve
# Epoch 00033: val_acc did not improve
#  - 2s - loss: 0.1609 - acc: 0.9375 - val_loss: 0.2925 - val_acc: 0.8828
# Epoch 34/50
# Epoch 00034: val_loss did not improve
# Epoch 00034: val_acc did not improve
#  - 2s - loss: 0.1439 - acc: 0.9450 - val_loss: 0.2792 - val_acc: 0.8903
# Epoch 35/50
# Epoch 00035: val_loss did not improve
# Epoch 00035: val_acc did not improve
#  - 2s - loss: 0.1570 - acc: 0.9342 - val_loss: 0.2758 - val_acc: 0.8828
# Epoch 36/50
# Epoch 00036: val_loss did not improve
# Epoch 00036: val_acc did not improve
#  - 2s - loss: 0.1513 - acc: 0.9400 - val_loss: 0.2772 - val_acc: 0.8878
# Epoch 37/50
# Epoch 00037: val_loss did not improve
# Epoch 00037: val_acc did not improve
#  - 2s - loss: 0.1816 - acc: 0.9292 - val_loss: 0.2778 - val_acc: 0.8878
# Epoch 38/50
# Epoch 00038: val_loss did not improve
# Epoch 00038: val_acc did not improve
#  - 3s - loss: 0.1471 - acc: 0.9364 - val_loss: 0.3175 - val_acc: 0.8778
# Epoch 39/50
# Epoch 00039: val_loss did not improve
# Epoch 00039: val_acc did not improve
#  - 2s - loss: 0.1367 - acc: 0.9467 - val_loss: 0.3067 - val_acc: 0.8828
# Epoch 40/50
# Epoch 00040: val_loss did not improve
# Epoch 00040: val_acc did not improve
#  - 2s - loss: 0.1658 - acc: 0.9292 - val_loss: 0.2886 - val_acc: 0.8878
# Epoch 41/50
# Epoch 00041: val_loss did not improve
# Epoch 00041: val_acc did not improve
#  - 2s - loss: 0.1489 - acc: 0.9300 - val_loss: 0.2874 - val_acc: 0.8803
# Epoch 42/50
# Epoch 00042: val_loss did not improve
# Epoch 00042: val_acc did not improve
#  - 2s - loss: 0.1384 - acc: 0.9458 - val_loss: 0.2871 - val_acc: 0.8853
# Epoch 43/50
# Epoch 00043: val_loss did not improve
# Epoch 00043: val_acc did not improve
#  - 2s - loss: 0.1490 - acc: 0.9375 - val_loss: 0.2844 - val_acc: 0.8828
# Epoch 44/50
# Epoch 00044: val_loss did not improve
# Epoch 00044: val_acc did not improve
#  - 2s - loss: 0.1432 - acc: 0.9383 - val_loss: 0.3128 - val_acc: 0.8753
# Epoch 45/50
# Epoch 00045: val_loss did not improve
# Epoch 00045: val_acc did not improve
#  - 2s - loss: 0.1476 - acc: 0.9408 - val_loss: 0.2896 - val_acc: 0.8778
# Epoch 46/50
# Epoch 00046: val_loss did not improve
# Epoch 00046: val_acc did not improve
#  - 2s - loss: 0.1320 - acc: 0.9416 - val_loss: 0.3081 - val_acc: 0.8728
# Epoch 47/50
# Epoch 00047: val_loss did not improve
# Epoch 00047: val_acc did not improve
#  - 2s - loss: 0.1399 - acc: 0.9442 - val_loss: 0.3463 - val_acc: 0.8703
# Epoch 48/50
# Epoch 00048: val_loss did not improve
# Epoch 00048: val_acc did not improve
#  - 2s - loss: 0.1725 - acc: 0.9298 - val_loss: 0.2997 - val_acc: 0.8653
# Epoch 49/50
# Epoch 00049: val_loss did not improve
# Epoch 00049: val_acc did not improve
#  - 2s - loss: 0.1320 - acc: 0.9400 - val_loss: 0.3521 - val_acc: 0.8678
# Epoch 50/50
# Epoch 00050: val_loss did not improve
# Epoch 00050: val_acc did not improve
#  - 2s - loss: 0.1325 - acc: 0.9400 - val_loss: 0.3170 - val_acc: 0.8803
# ============================

# %%
import pickle
with open('../features/cnn_4_aug1_feat.pkl','wb') as fout:
    pickle.dump([train_pred,test_pred],fout)

# train feat loss
from sklearn.metrics import log_loss
print(log_loss(y,train_pred))
    
submission = pd.DataFrame()
submission['id']=test_df['id']
submission['is_iceberg']=test_pred
print(submission.head())
submission.to_csv('../results/cnn_4_aug1_sub.csv', index=False)

print('---------------')

    
submission = pd.DataFrame()
submission['id']=test_df['id']
submission['is_iceberg']=best_acc_pred
print(submission.head())
submission.to_csv('../results/cnn_4_aug1_best_acc_sub.csv', index=False)
# Out:
# 0.209987771801
#          id  is_iceberg
# 0  5941774d    0.009021
# 1  4023181e    0.965640
# 2  b20200e4    0.238042
# 3  e7f018bb    0.994940
# 4  4371c8c3    0.494432
# ---------------
#          id  is_iceberg
# 0  5941774d    0.066792
# 1  4023181e    0.937345
# 2  b20200e4    0.238906
# 3  e7f018bb    0.992169
# 4  4371c8c3    0.356168
