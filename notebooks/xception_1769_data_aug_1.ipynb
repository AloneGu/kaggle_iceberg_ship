# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

from keras.utils.np_utils import to_categorical
from keras.models import Sequential,load_model
from keras.layers import Dense, Dropout, Flatten, Lambda, Activation
from keras.layers import Conv2D, MaxPooling2D, ZeroPadding2D, GlobalAveragePooling2D
from keras.layers.normalization import BatchNormalization
from keras.optimizers import Adam

train_df = pd.read_json('../input/train.json')
test_df = pd.read_json('../input/test.json')
# Out:
# Using TensorFlow backend.

# %%
def std_img(x):
    for i in range(3):
        x[:, :, i] -= np.mean(x[:, :, i].flatten())
        x[:, :, i] /= np.std(x[:, :, i].flatten()) + 1e-7
    return x

def get_image(df):
    '''Create 3-channel 'images'. Return rescale-normalised images.'''
    images = []
    for i, row in df.iterrows():
        # Formulate the bands as 75x75 arrays
        band_1 = np.array(row['band_1']).reshape(75, 75)
        band_2 = np.array(row['band_2']).reshape(75, 75)
        band_3 = (band_1 + band_2)/2

        # Rescale
        img = np.dstack([band_1,band_2,band_3])
        img = std_img(img)

        images.append(img)
    return np.array(images)


train_x = get_image(train_df)
test_x = get_image(test_df)

print(train_x.shape,test_x.shape)
# Out:
# (1604, 75, 75, 3) (8424, 75, 75, 3)

# %%
y = train_df.is_iceberg.values
print(y[:5])
# Out:
# [0 0 1 0 0]

# %%
from keras.callbacks import ModelCheckpoint,LearningRateScheduler
from keras.models import Model
from keras.applications.xception import Xception
def create_model():
    base_model = Xception(include_top=False, weights=None, input_tensor=None, input_shape=(75,75,3), pooling='max')
    x = Dense(512,activation='relu')(base_model.output)
    x = Dropout(0.2)(x)
    x = Dense(1,activation='sigmoid')(x)
    return Model(inputs=base_model.input, outputs=x)
print('model model')


tmp_m = create_model()
tmp_m.summary()
# Out:
# model model
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 75, 75, 3)    0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 37, 37, 32)   864         input_1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_bn (BatchNormaliza (None, 37, 37, 32)   128         block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_act (Activation)   (None, 37, 37, 32)   0           block1_conv1_bn[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 35, 35, 64)   18432       block1_conv1_act[0][0]
# __________________________________________________________________________________________________
# block1_conv2_bn (BatchNormaliza (None, 35, 35, 64)   256         block1_conv2[0][0]
# __________________________________________________________________________________________________
# block1_conv2_act (Activation)   (None, 35, 35, 64)   0           block1_conv2_bn[0][0]
# __________________________________________________________________________________________________
# block2_sepconv1 (SeparableConv2 (None, 35, 35, 128)  8768        block1_conv2_act[0][0]
# __________________________________________________________________________________________________
# block2_sepconv1_bn (BatchNormal (None, 35, 35, 128)  512         block2_sepconv1[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2_act (Activation (None, 35, 35, 128)  0           block2_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2 (SeparableConv2 (None, 35, 35, 128)  17536       block2_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2_bn (BatchNormal (None, 35, 35, 128)  512         block2_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 18, 18, 128)  8192        block1_conv2_act[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 18, 18, 128)  0           block2_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 18, 18, 128)  512         conv2d_1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 18, 18, 128)  0           block2_pool[0][0]
#                                                                  batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1_act (Activation (None, 18, 18, 128)  0           add_1[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1 (SeparableConv2 (None, 18, 18, 256)  33920       block3_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1_bn (BatchNormal (None, 18, 18, 256)  1024        block3_sepconv1[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2_act (Activation (None, 18, 18, 256)  0           block3_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2 (SeparableConv2 (None, 18, 18, 256)  67840       block3_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2_bn (BatchNormal (None, 18, 18, 256)  1024        block3_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 9, 9, 256)    32768       add_1[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, 9, 9, 256)    0           block3_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 9, 9, 256)    1024        conv2d_2[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 9, 9, 256)    0           block3_pool[0][0]
#                                                                  batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1_act (Activation (None, 9, 9, 256)    0           add_2[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1 (SeparableConv2 (None, 9, 9, 728)    188672      block4_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1_bn (BatchNormal (None, 9, 9, 728)    2912        block4_sepconv1[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2_act (Activation (None, 9, 9, 728)    0           block4_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2 (SeparableConv2 (None, 9, 9, 728)    536536      block4_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2_bn (BatchNormal (None, 9, 9, 728)    2912        block4_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 5, 5, 728)    186368      add_2[0][0]
# __________________________________________________________________________________________________
# block4_pool (MaxPooling2D)      (None, 5, 5, 728)    0           block4_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 5, 5, 728)    2912        conv2d_3[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 5, 5, 728)    0           block4_pool[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1_act (Activation (None, 5, 5, 728)    0           add_3[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1 (SeparableConv2 (None, 5, 5, 728)    536536      block5_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1_bn (BatchNormal (None, 5, 5, 728)    2912        block5_sepconv1[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2_act (Activation (None, 5, 5, 728)    0           block5_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2 (SeparableConv2 (None, 5, 5, 728)    536536      block5_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2_bn (BatchNormal (None, 5, 5, 728)    2912        block5_sepconv2[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3_act (Activation (None, 5, 5, 728)    0           block5_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3 (SeparableConv2 (None, 5, 5, 728)    536536      block5_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3_bn (BatchNormal (None, 5, 5, 728)    2912        block5_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 5, 5, 728)    0           block5_sepconv3_bn[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1_act (Activation (None, 5, 5, 728)    0           add_4[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1 (SeparableConv2 (None, 5, 5, 728)    536536      block6_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1_bn (BatchNormal (None, 5, 5, 728)    2912        block6_sepconv1[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2_act (Activation (None, 5, 5, 728)    0           block6_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2 (SeparableConv2 (None, 5, 5, 728)    536536      block6_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2_bn (BatchNormal (None, 5, 5, 728)    2912        block6_sepconv2[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3_act (Activation (None, 5, 5, 728)    0           block6_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3 (SeparableConv2 (None, 5, 5, 728)    536536      block6_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3_bn (BatchNormal (None, 5, 5, 728)    2912        block6_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 5, 5, 728)    0           block6_sepconv3_bn[0][0]
#                                                                  add_4[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1_act (Activation (None, 5, 5, 728)    0           add_5[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1 (SeparableConv2 (None, 5, 5, 728)    536536      block7_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1_bn (BatchNormal (None, 5, 5, 728)    2912        block7_sepconv1[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2_act (Activation (None, 5, 5, 728)    0           block7_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2 (SeparableConv2 (None, 5, 5, 728)    536536      block7_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2_bn (BatchNormal (None, 5, 5, 728)    2912        block7_sepconv2[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3_act (Activation (None, 5, 5, 728)    0           block7_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3 (SeparableConv2 (None, 5, 5, 728)    536536      block7_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3_bn (BatchNormal (None, 5, 5, 728)    2912        block7_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 5, 5, 728)    0           block7_sepconv3_bn[0][0]
#                                                                  add_5[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1_act (Activation (None, 5, 5, 728)    0           add_6[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1 (SeparableConv2 (None, 5, 5, 728)    536536      block8_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1_bn (BatchNormal (None, 5, 5, 728)    2912        block8_sepconv1[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2_act (Activation (None, 5, 5, 728)    0           block8_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2 (SeparableConv2 (None, 5, 5, 728)    536536      block8_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2_bn (BatchNormal (None, 5, 5, 728)    2912        block8_sepconv2[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3_act (Activation (None, 5, 5, 728)    0           block8_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3 (SeparableConv2 (None, 5, 5, 728)    536536      block8_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3_bn (BatchNormal (None, 5, 5, 728)    2912        block8_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 5, 5, 728)    0           block8_sepconv3_bn[0][0]
#                                                                  add_6[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1_act (Activation (None, 5, 5, 728)    0           add_7[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1 (SeparableConv2 (None, 5, 5, 728)    536536      block9_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1_bn (BatchNormal (None, 5, 5, 728)    2912        block9_sepconv1[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2_act (Activation (None, 5, 5, 728)    0           block9_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2 (SeparableConv2 (None, 5, 5, 728)    536536      block9_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2_bn (BatchNormal (None, 5, 5, 728)    2912        block9_sepconv2[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3_act (Activation (None, 5, 5, 728)    0           block9_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3 (SeparableConv2 (None, 5, 5, 728)    536536      block9_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3_bn (BatchNormal (None, 5, 5, 728)    2912        block9_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 5, 5, 728)    0           block9_sepconv3_bn[0][0]
#                                                                  add_7[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1_act (Activatio (None, 5, 5, 728)    0           add_8[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1 (SeparableConv (None, 5, 5, 728)    536536      block10_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1_bn (BatchNorma (None, 5, 5, 728)    2912        block10_sepconv1[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2_act (Activatio (None, 5, 5, 728)    0           block10_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2 (SeparableConv (None, 5, 5, 728)    536536      block10_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2_bn (BatchNorma (None, 5, 5, 728)    2912        block10_sepconv2[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3_act (Activatio (None, 5, 5, 728)    0           block10_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3 (SeparableConv (None, 5, 5, 728)    536536      block10_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3_bn (BatchNorma (None, 5, 5, 728)    2912        block10_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 5, 5, 728)    0           block10_sepconv3_bn[0][0]
#                                                                  add_8[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1_act (Activatio (None, 5, 5, 728)    0           add_9[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1 (SeparableConv (None, 5, 5, 728)    536536      block11_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1_bn (BatchNorma (None, 5, 5, 728)    2912        block11_sepconv1[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2_act (Activatio (None, 5, 5, 728)    0           block11_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2 (SeparableConv (None, 5, 5, 728)    536536      block11_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2_bn (BatchNorma (None, 5, 5, 728)    2912        block11_sepconv2[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3_act (Activatio (None, 5, 5, 728)    0           block11_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3 (SeparableConv (None, 5, 5, 728)    536536      block11_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3_bn (BatchNorma (None, 5, 5, 728)    2912        block11_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 5, 5, 728)    0           block11_sepconv3_bn[0][0]
#                                                                  add_9[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1_act (Activatio (None, 5, 5, 728)    0           add_10[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1 (SeparableConv (None, 5, 5, 728)    536536      block12_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1_bn (BatchNorma (None, 5, 5, 728)    2912        block12_sepconv1[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2_act (Activatio (None, 5, 5, 728)    0           block12_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2 (SeparableConv (None, 5, 5, 728)    536536      block12_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2_bn (BatchNorma (None, 5, 5, 728)    2912        block12_sepconv2[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3_act (Activatio (None, 5, 5, 728)    0           block12_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3 (SeparableConv (None, 5, 5, 728)    536536      block12_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3_bn (BatchNorma (None, 5, 5, 728)    2912        block12_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 5, 5, 728)    0           block12_sepconv3_bn[0][0]
#                                                                  add_10[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1_act (Activatio (None, 5, 5, 728)    0           add_11[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1 (SeparableConv (None, 5, 5, 728)    536536      block13_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1_bn (BatchNorma (None, 5, 5, 728)    2912        block13_sepconv1[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2_act (Activatio (None, 5, 5, 728)    0           block13_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2 (SeparableConv (None, 5, 5, 1024)   752024      block13_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2_bn (BatchNorma (None, 5, 5, 1024)   4096        block13_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 3, 3, 1024)   745472      add_11[0][0]
# __________________________________________________________________________________________________
# block13_pool (MaxPooling2D)     (None, 3, 3, 1024)   0           block13_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 3, 3, 1024)   4096        conv2d_4[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 3, 3, 1024)   0           block13_pool[0][0]
#                                                                  batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1 (SeparableConv (None, 3, 3, 1536)   1582080     add_12[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1_bn (BatchNorma (None, 3, 3, 1536)   6144        block14_sepconv1[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1_act (Activatio (None, 3, 3, 1536)   0           block14_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2 (SeparableConv (None, 3, 3, 2048)   3159552     block14_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2_bn (BatchNorma (None, 3, 3, 2048)   8192        block14_sepconv2[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2_act (Activatio (None, 3, 3, 2048)   0           block14_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# global_max_pooling2d_1 (GlobalM (None, 2048)         0           block14_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 512)          1049088     global_max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 512)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1)            513         dropout_1[0][0]
# ==================================================================================================
# Total params: 21,911,081
# Trainable params: 21,856,553
# Non-trainable params: 54,528
# __________________________________________________________________________________________________

# %%
from sklearn.model_selection import KFold
from keras.preprocessing.image import ImageDataGenerator
import gc

def lr_f(epoch):
    if epoch<10:
        return 0.001
    elif epoch<30:
        return 0.0005
    else:
        return 0.0001

def kfold_train(fold_cnt=3,rnd=233):
    train_pred, test_pred = np.zeros((1604,1)),np.zeros((8424,1))
    kf = KFold(n_splits=fold_cnt, shuffle=True, random_state=2*rnd)
    for train_index, test_index in kf.split(train_x):
        curr_x,curr_y = train_x[train_index],y[train_index]
        val_x,val_y = train_x[test_index],y[test_index]
        datagen = ImageDataGenerator(
            width_shift_range=0.05,
            height_shift_range=0.05,
            shear_range=0.2,
            zoom_range=0.2,
            horizontal_flip=True,
            vertical_flip=True
        )
        
        
        bat_size = 12
        steps_train = len(curr_y)//bat_size
        
        
        model = create_model()
        model.compile(loss='binary_crossentropy', optimizer=Adam(0.0005), metrics=['accuracy'])
        model_p = 'best_m.h5'
        model_chk = ModelCheckpoint(filepath=model_p, monitor='val_loss', save_best_only=True, verbose=1)
        lr_s = LearningRateScheduler(lr_f)
        model.fit_generator(datagen.flow(curr_x, curr_y, batch_size=bat_size),
                  validation_data=(val_x,val_y),
                  steps_per_epoch = steps_train,
                  epochs=70, 
                  verbose=2,
                  callbacks=[model_chk,lr_s]
                 )
        
        
        model = load_model(model_p)
        train_pred[test_index] = model.predict(val_x)
        test_pred = test_pred + model.predict(test_x)/fold_cnt
        
        del model
        gc.collect()
        print('============================')
    return train_pred,test_pred

train_pred,test_pred = kfold_train(fold_cnt=3)
# Out:
# Epoch 1/70
# Epoch 00001: val_loss improved from inf to 0.69241, saving model to best_m.h5
#  - 22s - loss: 0.7253 - acc: 0.6891 - val_loss: 0.6924 - val_acc: 0.5533
# Epoch 2/70
# Epoch 00002: val_loss did not improve
#  - 14s - loss: 0.6057 - acc: 0.7257 - val_loss: 0.6968 - val_acc: 0.4467
# Epoch 3/70
# Epoch 00003: val_loss did not improve
#  - 14s - loss: 0.4541 - acc: 0.8080 - val_loss: 0.7114 - val_acc: 0.4467
# Epoch 4/70
# Epoch 00004: val_loss did not improve
#  - 14s - loss: 0.4607 - acc: 0.7922 - val_loss: 0.7220 - val_acc: 0.4467
# Epoch 5/70
# Epoch 00005: val_loss did not improve
#  - 15s - loss: 0.5083 - acc: 0.7754 - val_loss: 0.8782 - val_acc: 0.4467
# Epoch 6/70
# Epoch 00006: val_loss improved from 0.69241 to 0.50515, saving model to best_m.h5
#  - 16s - loss: 0.4615 - acc: 0.8025 - val_loss: 0.5051 - val_acc: 0.8187
# Epoch 7/70
# Epoch 00007: val_loss improved from 0.50515 to 0.40607, saving model to best_m.h5
#  - 16s - loss: 0.4537 - acc: 0.8081 - val_loss: 0.4061 - val_acc: 0.8168
# Epoch 8/70
# Epoch 00008: val_loss did not improve
#  - 14s - loss: 0.4317 - acc: 0.8371 - val_loss: 0.5551 - val_acc: 0.8168
# Epoch 9/70
# Epoch 00009: val_loss did not improve
#  - 14s - loss: 0.3497 - acc: 0.8381 - val_loss: 0.8882 - val_acc: 0.6150
# Epoch 10/70
# Epoch 00010: val_loss improved from 0.40607 to 0.38136, saving model to best_m.h5
#  - 15s - loss: 0.3666 - acc: 0.8269 - val_loss: 0.3814 - val_acc: 0.8187
# Epoch 11/70
# Epoch 00011: val_loss improved from 0.38136 to 0.24928, saving model to best_m.h5
#  - 15s - loss: 0.3287 - acc: 0.8614 - val_loss: 0.2493 - val_acc: 0.8860
# Epoch 12/70
# Epoch 00012: val_loss did not improve
#  - 14s - loss: 0.3045 - acc: 0.8652 - val_loss: 0.3083 - val_acc: 0.8991
# Epoch 13/70
# Epoch 00013: val_loss did not improve
#  - 15s - loss: 0.2849 - acc: 0.8670 - val_loss: 0.2768 - val_acc: 0.9028
# Epoch 14/70
# Epoch 00014: val_loss did not improve
#  - 14s - loss: 0.3412 - acc: 0.8522 - val_loss: 0.4149 - val_acc: 0.8523
# Epoch 15/70
# Epoch 00015: val_loss did not improve
#  - 14s - loss: 0.3093 - acc: 0.8746 - val_loss: 0.3282 - val_acc: 0.8822
# Epoch 16/70
# Epoch 00016: val_loss did not improve
#  - 14s - loss: 0.3044 - acc: 0.8793 - val_loss: 0.2775 - val_acc: 0.8822
# Epoch 17/70
# Epoch 00017: val_loss did not improve
#  - 14s - loss: 0.3264 - acc: 0.8606 - val_loss: 0.3128 - val_acc: 0.8785
# Epoch 18/70
# Epoch 00018: val_loss did not improve
#  - 15s - loss: 0.2981 - acc: 0.8726 - val_loss: 0.3359 - val_acc: 0.8542
# Epoch 19/70
# Epoch 00019: val_loss did not improve
#  - 15s - loss: 0.2937 - acc: 0.8718 - val_loss: 0.2626 - val_acc: 0.9065
# Epoch 20/70
# Epoch 00020: val_loss did not improve
#  - 14s - loss: 0.2971 - acc: 0.8820 - val_loss: 0.3567 - val_acc: 0.8766
# Epoch 21/70
# Epoch 00021: val_loss did not improve
#  - 14s - loss: 0.2722 - acc: 0.8764 - val_loss: 0.3764 - val_acc: 0.8355
# Epoch 22/70
# Epoch 00022: val_loss did not improve
#  - 14s - loss: 0.3467 - acc: 0.8689 - val_loss: 0.2777 - val_acc: 0.8729
# Epoch 23/70
# Epoch 00023: val_loss improved from 0.24928 to 0.24323, saving model to best_m.h5
#  - 15s - loss: 0.2978 - acc: 0.8727 - val_loss: 0.2432 - val_acc: 0.8991
# Epoch 24/70
# Epoch 00024: val_loss did not improve
#  - 15s - loss: 0.2887 - acc: 0.8801 - val_loss: 0.2503 - val_acc: 0.9028
# Epoch 25/70
# Epoch 00025: val_loss did not improve
#  - 14s - loss: 0.2416 - acc: 0.9026 - val_loss: 0.2863 - val_acc: 0.8785
# Epoch 26/70
# Epoch 00026: val_loss did not improve
#  - 14s - loss: 0.2841 - acc: 0.8868 - val_loss: 0.2556 - val_acc: 0.9103
# Epoch 27/70
# Epoch 00027: val_loss did not improve
#  - 14s - loss: 0.2918 - acc: 0.8727 - val_loss: 0.2757 - val_acc: 0.8916
# Epoch 28/70
# Epoch 00028: val_loss did not improve
#  - 14s - loss: 0.2554 - acc: 0.8979 - val_loss: 0.2518 - val_acc: 0.8953
# Epoch 29/70
# Epoch 00029: val_loss did not improve
#  - 14s - loss: 0.3365 - acc: 0.8624 - val_loss: 0.2501 - val_acc: 0.9140
# Epoch 30/70
# Epoch 00030: val_loss did not improve
#  - 15s - loss: 0.2820 - acc: 0.8783 - val_loss: 0.3862 - val_acc: 0.8355
# Epoch 31/70
# Epoch 00031: val_loss did not improve
#  - 14s - loss: 0.2557 - acc: 0.8962 - val_loss: 0.3204 - val_acc: 0.8729
# Epoch 32/70
# Epoch 00032: val_loss improved from 0.24323 to 0.23395, saving model to best_m.h5
#  - 15s - loss: 0.2264 - acc: 0.9157 - val_loss: 0.2339 - val_acc: 0.9009
# Epoch 33/70
# Epoch 00033: val_loss did not improve
#  - 14s - loss: 0.2447 - acc: 0.9063 - val_loss: 0.2521 - val_acc: 0.8972
# Epoch 34/70
# Epoch 00034: val_loss did not improve
#  - 14s - loss: 0.1953 - acc: 0.9232 - val_loss: 0.2390 - val_acc: 0.8991
# Epoch 35/70
# Epoch 00035: val_loss did not improve
#  - 14s - loss: 0.2108 - acc: 0.9064 - val_loss: 0.2405 - val_acc: 0.9084
# Epoch 36/70
# Epoch 00036: val_loss did not improve
#  - 14s - loss: 0.2387 - acc: 0.8980 - val_loss: 0.3541 - val_acc: 0.8654
# Epoch 37/70
# Epoch 00037: val_loss did not improve
#  - 14s - loss: 0.2256 - acc: 0.9082 - val_loss: 0.2371 - val_acc: 0.8953
# Epoch 38/70
# Epoch 00038: val_loss did not improve
#  - 14s - loss: 0.2059 - acc: 0.9167 - val_loss: 0.2768 - val_acc: 0.8972
# Epoch 39/70
# Epoch 00039: val_loss did not improve
#  - 14s - loss: 0.2087 - acc: 0.9102 - val_loss: 0.2807 - val_acc: 0.8860
# Epoch 40/70
# Epoch 00040: val_loss did not improve
#  - 14s - loss: 0.2255 - acc: 0.8952 - val_loss: 0.2524 - val_acc: 0.8916
# Epoch 41/70
# Epoch 00041: val_loss did not improve
#  - 14s - loss: 0.2028 - acc: 0.9054 - val_loss: 0.2480 - val_acc: 0.9028
# Epoch 42/70
# Epoch 00042: val_loss did not improve
#  - 14s - loss: 0.2063 - acc: 0.9204 - val_loss: 0.2498 - val_acc: 0.8953
# Epoch 43/70
# Epoch 00043: val_loss did not improve
#  - 14s - loss: 0.2145 - acc: 0.9064 - val_loss: 0.3017 - val_acc: 0.8935
# Epoch 44/70
# Epoch 00044: val_loss did not improve
#  - 14s - loss: 0.2112 - acc: 0.9054 - val_loss: 0.2529 - val_acc: 0.8953
# Epoch 45/70
# Epoch 00045: val_loss did not improve
#  - 14s - loss: 0.1990 - acc: 0.9130 - val_loss: 0.2594 - val_acc: 0.9047
# Epoch 46/70
# Epoch 00046: val_loss did not improve
#  - 15s - loss: 0.2076 - acc: 0.9036 - val_loss: 0.2579 - val_acc: 0.8916
# Epoch 47/70
# Epoch 00047: val_loss did not improve
#  - 14s - loss: 0.1812 - acc: 0.9241 - val_loss: 0.2930 - val_acc: 0.8822
# Epoch 48/70
# Epoch 00048: val_loss did not improve
#  - 14s - loss: 0.1923 - acc: 0.9260 - val_loss: 0.2941 - val_acc: 0.8841
# Epoch 49/70
# Epoch 00049: val_loss did not improve
#  - 14s - loss: 0.2071 - acc: 0.9148 - val_loss: 0.2404 - val_acc: 0.8972
# Epoch 50/70
# Epoch 00050: val_loss did not improve
#  - 14s - loss: 0.2076 - acc: 0.9232 - val_loss: 0.2892 - val_acc: 0.9009
# Epoch 51/70
# Epoch 00051: val_loss did not improve
#  - 14s - loss: 0.2455 - acc: 0.9055 - val_loss: 0.3330 - val_acc: 0.8748
# Epoch 52/70
# Epoch 00052: val_loss did not improve
#  - 14s - loss: 0.2014 - acc: 0.9167 - val_loss: 0.2630 - val_acc: 0.9028
# Epoch 53/70
# Epoch 00053: val_loss did not improve
#  - 14s - loss: 0.1812 - acc: 0.9139 - val_loss: 0.3119 - val_acc: 0.8991
# Epoch 54/70
# Epoch 00054: val_loss did not improve
#  - 14s - loss: 0.2040 - acc: 0.9213 - val_loss: 0.2747 - val_acc: 0.9028
# Epoch 55/70
# Epoch 00055: val_loss did not improve
#  - 14s - loss: 0.2189 - acc: 0.9102 - val_loss: 0.3646 - val_acc: 0.8692
# Epoch 56/70
# Epoch 00056: val_loss did not improve
#  - 14s - loss: 0.2045 - acc: 0.9223 - val_loss: 0.2780 - val_acc: 0.8785
# Epoch 57/70
# Epoch 00057: val_loss did not improve
#  - 14s - loss: 0.1965 - acc: 0.9148 - val_loss: 0.2742 - val_acc: 0.9009
# Epoch 58/70
# Epoch 00058: val_loss did not improve
#  - 14s - loss: 0.1862 - acc: 0.9241 - val_loss: 0.3695 - val_acc: 0.8710
# Epoch 59/70
# Epoch 00059: val_loss did not improve
#  - 14s - loss: 0.2512 - acc: 0.9037 - val_loss: 0.6127 - val_acc: 0.8019
# Epoch 60/70
# Epoch 00060: val_loss did not improve
#  - 20s - loss: 0.1921 - acc: 0.9241 - val_loss: 0.2642 - val_acc: 0.9028
# Epoch 61/70
# Epoch 00061: val_loss did not improve
#  - 15s - loss: 0.2020 - acc: 0.9195 - val_loss: 0.2868 - val_acc: 0.8897
# Epoch 62/70
# Epoch 00062: val_loss did not improve
#  - 14s - loss: 0.1970 - acc: 0.9140 - val_loss: 0.2510 - val_acc: 0.9009
# Epoch 63/70
# Epoch 00063: val_loss did not improve
#  - 14s - loss: 0.1770 - acc: 0.9391 - val_loss: 0.3055 - val_acc: 0.8916
# Epoch 64/70
# Epoch 00064: val_loss did not improve
#  - 14s - loss: 0.2131 - acc: 0.9130 - val_loss: 0.2577 - val_acc: 0.9028
# Epoch 65/70
# Epoch 00065: val_loss did not improve
#  - 14s - loss: 0.1960 - acc: 0.9241 - val_loss: 0.2507 - val_acc: 0.9028
# Epoch 66/70
# Epoch 00066: val_loss did not improve
#  - 14s - loss: 0.2082 - acc: 0.9251 - val_loss: 0.2502 - val_acc: 0.8972
# Epoch 67/70
# Epoch 00067: val_loss did not improve
#  - 14s - loss: 0.1786 - acc: 0.9242 - val_loss: 0.2552 - val_acc: 0.9009
# Epoch 68/70
# Epoch 00068: val_loss did not improve
#  - 14s - loss: 0.2058 - acc: 0.9129 - val_loss: 0.2425 - val_acc: 0.9084
# Epoch 69/70
# Epoch 00069: val_loss did not improve
#  - 14s - loss: 0.1726 - acc: 0.9196 - val_loss: 0.2843 - val_acc: 0.9065
# Epoch 70/70
# Epoch 00070: val_loss did not improve
#  - 14s - loss: 0.1897 - acc: 0.9204 - val_loss: 0.2751 - val_acc: 0.9065
# ============================
# Epoch 1/70
# Epoch 00001: val_loss improved from inf to 0.69322, saving model to best_m.h5
#  - 33s - loss: 0.7940 - acc: 0.6282 - val_loss: 0.6932 - val_acc: 0.4860
# Epoch 2/70
# Epoch 00002: val_loss did not improve
#  - 14s - loss: 0.7452 - acc: 0.6761 - val_loss: 0.6951 - val_acc: 0.4860
# Epoch 3/70
# Epoch 00003: val_loss did not improve
#  - 14s - loss: 0.5712 - acc: 0.7584 - val_loss: 0.7065 - val_acc: 0.4860
# Epoch 4/70
# Epoch 00004: val_loss did not improve
#  - 14s - loss: 0.6199 - acc: 0.6995 - val_loss: 0.7087 - val_acc: 0.4860
# Epoch 5/70
# Epoch 00005: val_loss improved from 0.69322 to 0.67644, saving model to best_m.h5
#  - 15s - loss: 0.6056 - acc: 0.7228 - val_loss: 0.6764 - val_acc: 0.5757
# Epoch 6/70
# Epoch 00006: val_loss improved from 0.67644 to 0.54200, saving model to best_m.h5
#  - 15s - loss: 0.4686 - acc: 0.7977 - val_loss: 0.5420 - val_acc: 0.7794
# Epoch 7/70
# Epoch 00007: val_loss improved from 0.54200 to 0.33426, saving model to best_m.h5
#  - 15s - loss: 0.6249 - acc: 0.8053 - val_loss: 0.3343 - val_acc: 0.8486
# Epoch 8/70
# Epoch 00008: val_loss improved from 0.33426 to 0.32251, saving model to best_m.h5
#  - 15s - loss: 0.4587 - acc: 0.8202 - val_loss: 0.3225 - val_acc: 0.8467
# Epoch 9/70
# Epoch 00009: val_loss improved from 0.32251 to 0.27668, saving model to best_m.h5
#  - 15s - loss: 0.5370 - acc: 0.8390 - val_loss: 0.2767 - val_acc: 0.8785
# Epoch 10/70
# Epoch 00010: val_loss did not improve
#  - 14s - loss: 0.3711 - acc: 0.8343 - val_loss: 0.4412 - val_acc: 0.7925
# Epoch 11/70
# Epoch 00011: val_loss improved from 0.27668 to 0.27095, saving model to best_m.h5
#  - 15s - loss: 0.4062 - acc: 0.8614 - val_loss: 0.2710 - val_acc: 0.8879
# Epoch 12/70
# Epoch 00012: val_loss did not improve
#  - 14s - loss: 0.8292 - acc: 0.6797 - val_loss: 7.8331 - val_acc: 0.5140
# Epoch 13/70
# Epoch 00013: val_loss did not improve
#  - 14s - loss: 0.7617 - acc: 0.6329 - val_loss: 7.0056 - val_acc: 0.5140
# Epoch 14/70
# Epoch 00014: val_loss did not improve
#  - 14s - loss: 0.5912 - acc: 0.7256 - val_loss: 0.5909 - val_acc: 0.6579
# Epoch 15/70
# Epoch 00015: val_loss did not improve
#  - 14s - loss: 0.4296 - acc: 0.8081 - val_loss: 0.4576 - val_acc: 0.7757
# Epoch 16/70
# Epoch 00016: val_loss did not improve
#  - 14s - loss: 0.5929 - acc: 0.7959 - val_loss: 3.8870 - val_acc: 0.6206
# Epoch 17/70
# Epoch 00017: val_loss did not improve
#  - 14s - loss: 0.5952 - acc: 0.7874 - val_loss: 0.6846 - val_acc: 0.6336
# Epoch 18/70
# Epoch 00018: val_loss did not improve
#  - 14s - loss: 0.6218 - acc: 0.7773 - val_loss: 0.4485 - val_acc: 0.8355
# Epoch 19/70
# Epoch 00019: val_loss improved from 0.27095 to 0.26182, saving model to best_m.h5
#  - 15s - loss: 0.4346 - acc: 0.8250 - val_loss: 0.2618 - val_acc: 0.8935
# Epoch 20/70
# Epoch 00020: val_loss did not improve
#  - 14s - loss: 0.4965 - acc: 0.8081 - val_loss: 0.4905 - val_acc: 0.7981
# Epoch 21/70
# Epoch 00021: val_loss did not improve
#  - 14s - loss: 0.4551 - acc: 0.8249 - val_loss: 0.5208 - val_acc: 0.8000
# Epoch 22/70
# Epoch 00022: val_loss did not improve
#  - 14s - loss: 0.4976 - acc: 0.8138 - val_loss: 0.8327 - val_acc: 0.7252
# Epoch 23/70
# Epoch 00023: val_loss did not improve
#  - 14s - loss: 0.3803 - acc: 0.8436 - val_loss: 0.3252 - val_acc: 0.8393
# Epoch 24/70
# Epoch 00024: val_loss did not improve
#  - 14s - loss: 0.5232 - acc: 0.7819 - val_loss: 3.8936 - val_acc: 0.5084
# Epoch 25/70
# Epoch 00025: val_loss did not improve
#  - 14s - loss: 0.5133 - acc: 0.7537 - val_loss: 0.3849 - val_acc: 0.8187
# Epoch 26/70
# Epoch 00026: val_loss did not improve
#  - 14s - loss: 0.3990 - acc: 0.8183 - val_loss: 0.3838 - val_acc: 0.7907
# Epoch 27/70
# Epoch 00027: val_loss did not improve
#  - 14s - loss: 0.4166 - acc: 0.8119 - val_loss: 0.2758 - val_acc: 0.8561
# Epoch 28/70
# Epoch 00028: val_loss did not improve
#  - 14s - loss: 0.3499 - acc: 0.8530 - val_loss: 0.2867 - val_acc: 0.8579
# Epoch 29/70
# Epoch 00029: val_loss did not improve
#  - 14s - loss: 0.3896 - acc: 0.8419 - val_loss: 0.2781 - val_acc: 0.8897
# Epoch 30/70
# Epoch 00030: val_loss did not improve
#  - 14s - loss: 0.3621 - acc: 0.8427 - val_loss: 0.2676 - val_acc: 0.8748
# Epoch 31/70
# Epoch 00031: val_loss improved from 0.26182 to 0.23407, saving model to best_m.h5
#  - 15s - loss: 0.3019 - acc: 0.8811 - val_loss: 0.2341 - val_acc: 0.9047
# Epoch 32/70
# Epoch 00032: val_loss did not improve
#  - 14s - loss: 0.3393 - acc: 0.8428 - val_loss: 0.2429 - val_acc: 0.9084
# Epoch 33/70
# Epoch 00033: val_loss improved from 0.23407 to 0.22584, saving model to best_m.h5
#  - 15s - loss: 0.3038 - acc: 0.8569 - val_loss: 0.2258 - val_acc: 0.9047
# Epoch 34/70
# Epoch 00034: val_loss improved from 0.22584 to 0.22320, saving model to best_m.h5
#  - 15s - loss: 0.3008 - acc: 0.8615 - val_loss: 0.2232 - val_acc: 0.9009
# Epoch 35/70
# Epoch 00035: val_loss improved from 0.22320 to 0.21756, saving model to best_m.h5
#  - 15s - loss: 0.2973 - acc: 0.8961 - val_loss: 0.2176 - val_acc: 0.9084
# Epoch 36/70
# Epoch 00036: val_loss did not improve
#  - 14s - loss: 0.3023 - acc: 0.8773 - val_loss: 0.2294 - val_acc: 0.9047
# Epoch 37/70
# Epoch 00037: val_loss improved from 0.21756 to 0.21214, saving model to best_m.h5
#  - 15s - loss: 0.3030 - acc: 0.8652 - val_loss: 0.2121 - val_acc: 0.9178
# Epoch 38/70
# Epoch 00038: val_loss did not improve
#  - 14s - loss: 0.3125 - acc: 0.8644 - val_loss: 0.2216 - val_acc: 0.9103
# Epoch 39/70
# Epoch 00039: val_loss did not improve
#  - 14s - loss: 0.3270 - acc: 0.8764 - val_loss: 0.2267 - val_acc: 0.8991
# Epoch 40/70
# Epoch 00040: val_loss did not improve
#  - 14s - loss: 0.2868 - acc: 0.8803 - val_loss: 0.2395 - val_acc: 0.8935
# Epoch 41/70
# Epoch 00041: val_loss did not improve
#  - 14s - loss: 0.2857 - acc: 0.8886 - val_loss: 0.3115 - val_acc: 0.8486
# Epoch 42/70
# Epoch 00042: val_loss did not improve
#  - 14s - loss: 0.2990 - acc: 0.8689 - val_loss: 0.2521 - val_acc: 0.8916
# Epoch 43/70
# Epoch 00043: val_loss did not improve
#  - 14s - loss: 0.3148 - acc: 0.8699 - val_loss: 0.2136 - val_acc: 0.9121
# Epoch 44/70
# Epoch 00044: val_loss improved from 0.21214 to 0.20839, saving model to best_m.h5
#  - 15s - loss: 0.2583 - acc: 0.8961 - val_loss: 0.2084 - val_acc: 0.9121
# Epoch 45/70
# Epoch 00045: val_loss improved from 0.20839 to 0.20463, saving model to best_m.h5
#  - 15s - loss: 0.3041 - acc: 0.8709 - val_loss: 0.2046 - val_acc: 0.9065
# Epoch 46/70
# Epoch 00046: val_loss did not improve
#  - 14s - loss: 0.2694 - acc: 0.9017 - val_loss: 0.2108 - val_acc: 0.9084
# Epoch 47/70
# Epoch 00047: val_loss did not improve
#  - 14s - loss: 0.2623 - acc: 0.8942 - val_loss: 0.2211 - val_acc: 0.9196
# Epoch 48/70
# Epoch 00048: val_loss did not improve
#  - 14s - loss: 0.3034 - acc: 0.8643 - val_loss: 0.2081 - val_acc: 0.9103
# Epoch 49/70
# Epoch 00049: val_loss did not improve
#  - 14s - loss: 0.2560 - acc: 0.8895 - val_loss: 0.2128 - val_acc: 0.9065
# Epoch 50/70
# Epoch 00050: val_loss did not improve
#  - 14s - loss: 0.3050 - acc: 0.8606 - val_loss: 0.2264 - val_acc: 0.9140
# Epoch 51/70
# Epoch 00051: val_loss did not improve
#  - 14s - loss: 0.2842 - acc: 0.8859 - val_loss: 0.2239 - val_acc: 0.9047
# Epoch 52/70
# Epoch 00052: val_loss did not improve
#  - 14s - loss: 0.2663 - acc: 0.8904 - val_loss: 0.2145 - val_acc: 0.8953
# Epoch 53/70
# Epoch 00053: val_loss did not improve
#  - 14s - loss: 0.2824 - acc: 0.8709 - val_loss: 0.2608 - val_acc: 0.8841
# Epoch 54/70
# Epoch 00054: val_loss did not improve
#  - 14s - loss: 0.2714 - acc: 0.8914 - val_loss: 0.2915 - val_acc: 0.8542
# Epoch 55/70
# Epoch 00055: val_loss did not improve
#  - 14s - loss: 0.2802 - acc: 0.8942 - val_loss: 0.2412 - val_acc: 0.8916
# Epoch 56/70
# Epoch 00056: val_loss improved from 0.20463 to 0.19130, saving model to best_m.h5
#  - 15s - loss: 0.2603 - acc: 0.8803 - val_loss: 0.1913 - val_acc: 0.9252
# Epoch 57/70
# Epoch 00057: val_loss did not improve
#  - 14s - loss: 0.2930 - acc: 0.8839 - val_loss: 0.3370 - val_acc: 0.8561
# Epoch 58/70
# Epoch 00058: val_loss did not improve
#  - 14s - loss: 0.2649 - acc: 0.8951 - val_loss: 0.2896 - val_acc: 0.8542
# Epoch 59/70
# Epoch 00059: val_loss did not improve
#  - 14s - loss: 0.3164 - acc: 0.8690 - val_loss: 0.2117 - val_acc: 0.9084
# Epoch 60/70
# Epoch 00060: val_loss did not improve
#  - 14s - loss: 0.2689 - acc: 0.8848 - val_loss: 0.2412 - val_acc: 0.8879
# Epoch 61/70
# Epoch 00061: val_loss did not improve
#  - 14s - loss: 0.2514 - acc: 0.9026 - val_loss: 0.3123 - val_acc: 0.8785
# Epoch 62/70
# Epoch 00062: val_loss did not improve
#  - 14s - loss: 0.2562 - acc: 0.8970 - val_loss: 0.2224 - val_acc: 0.8972
# Epoch 63/70
# Epoch 00063: val_loss did not improve
#  - 14s - loss: 0.2696 - acc: 0.8923 - val_loss: 0.7511 - val_acc: 0.8561
# Epoch 64/70
# Epoch 00064: val_loss did not improve
#  - 14s - loss: 0.2531 - acc: 0.8887 - val_loss: 0.2103 - val_acc: 0.9009
# Epoch 65/70
# Epoch 00065: val_loss did not improve
#  - 14s - loss: 0.2661 - acc: 0.8952 - val_loss: 0.2316 - val_acc: 0.9009
# Epoch 66/70
# Epoch 00066: val_loss did not improve
#  - 14s - loss: 0.2304 - acc: 0.9092 - val_loss: 0.1914 - val_acc: 0.9103
# Epoch 67/70
# Epoch 00067: val_loss did not improve
#  - 14s - loss: 0.2700 - acc: 0.8915 - val_loss: 0.2023 - val_acc: 0.9178
# Epoch 68/70
# Epoch 00068: val_loss did not improve
#  - 14s - loss: 0.2667 - acc: 0.8887 - val_loss: 0.2227 - val_acc: 0.9009
# Epoch 69/70
# Epoch 00069: val_loss did not improve
#  - 14s - loss: 0.2386 - acc: 0.8933 - val_loss: 0.1970 - val_acc: 0.9196
# Epoch 70/70
# Epoch 00070: val_loss did not improve
#  - 14s - loss: 0.2372 - acc: 0.9063 - val_loss: 0.2092 - val_acc: 0.9178
# ============================
# Epoch 1/70
# Epoch 00001: val_loss improved from inf to 0.69340, saving model to best_m.h5
#  - 44s - loss: 0.7787 - acc: 0.6536 - val_loss: 0.6934 - val_acc: 0.4757
# Epoch 2/70
# Epoch 00002: val_loss did not improve
#  - 15s - loss: 0.4845 - acc: 0.7724 - val_loss: 0.6951 - val_acc: 0.4757
# Epoch 3/70
# Epoch 00003: val_loss did not improve
#  - 15s - loss: 0.5038 - acc: 0.7875 - val_loss: 0.6996 - val_acc: 0.4757
# Epoch 4/70
# Epoch 00004: val_loss did not improve
#  - 15s - loss: 0.4350 - acc: 0.8137 - val_loss: 0.6966 - val_acc: 0.4757
# Epoch 5/70
# Epoch 00005: val_loss did not improve
#  - 15s - loss: 0.4138 - acc: 0.8156 - val_loss: 0.7528 - val_acc: 0.4757
# Epoch 6/70
# Epoch 00006: val_loss improved from 0.69340 to 0.69176, saving model to best_m.h5
#  - 16s - loss: 0.4326 - acc: 0.8249 - val_loss: 0.6918 - val_acc: 0.6217
# Epoch 7/70
# Epoch 00007: val_loss improved from 0.69176 to 0.48468, saving model to best_m.h5
#  - 16s - loss: 0.3592 - acc: 0.8296 - val_loss: 0.4847 - val_acc: 0.7884
# Epoch 8/70
# Epoch 00008: val_loss did not improve
#  - 15s - loss: 0.3640 - acc: 0.8380 - val_loss: 1.1756 - val_acc: 0.5787
# Epoch 9/70
# Epoch 00009: val_loss did not improve
#  - 15s - loss: 0.3740 - acc: 0.8484 - val_loss: 0.5360 - val_acc: 0.7303
# Epoch 10/70
# Epoch 00010: val_loss improved from 0.48468 to 0.32058, saving model to best_m.h5
#  - 16s - loss: 0.3397 - acc: 0.8539 - val_loss: 0.3206 - val_acc: 0.8858
# Epoch 11/70
# Epoch 00011: val_loss did not improve
#  - 15s - loss: 0.3123 - acc: 0.8745 - val_loss: 0.3941 - val_acc: 0.7734
# Epoch 12/70
# Epoch 00012: val_loss improved from 0.32058 to 0.28716, saving model to best_m.h5
#  - 16s - loss: 0.3377 - acc: 0.8587 - val_loss: 0.2872 - val_acc: 0.8483
# Epoch 13/70
# Epoch 00013: val_loss improved from 0.28716 to 0.24423, saving model to best_m.h5
#  - 16s - loss: 0.2959 - acc: 0.8680 - val_loss: 0.2442 - val_acc: 0.8933
# Epoch 14/70
# Epoch 00014: val_loss did not improve
#  - 16s - loss: 0.2986 - acc: 0.8726 - val_loss: 0.2516 - val_acc: 0.8933
# Epoch 15/70
# Epoch 00015: val_loss did not improve
#  - 15s - loss: 0.2881 - acc: 0.8801 - val_loss: 0.2923 - val_acc: 0.8577
# Epoch 16/70
# Epoch 00016: val_loss did not improve
#  - 16s - loss: 0.2763 - acc: 0.8736 - val_loss: 0.3379 - val_acc: 0.8783
# Epoch 17/70
# Epoch 00017: val_loss did not improve
#  - 16s - loss: 0.2755 - acc: 0.8923 - val_loss: 0.2640 - val_acc: 0.8689
# Epoch 18/70
# Epoch 00018: val_loss did not improve
#  - 15s - loss: 0.3289 - acc: 0.8568 - val_loss: 0.2906 - val_acc: 0.8970
# Epoch 19/70
# Epoch 00019: val_loss did not improve
#  - 16s - loss: 0.2482 - acc: 0.8989 - val_loss: 0.4268 - val_acc: 0.8708
# Epoch 20/70
# Epoch 00020: val_loss did not improve
#  - 15s - loss: 0.3378 - acc: 0.8502 - val_loss: 0.4862 - val_acc: 0.8202
# Epoch 21/70
# Epoch 00021: val_loss did not improve
#  - 15s - loss: 0.3320 - acc: 0.8736 - val_loss: 0.3578 - val_acc: 0.8165
# Epoch 22/70
# Epoch 00022: val_loss did not improve
#  - 15s - loss: 0.2803 - acc: 0.8914 - val_loss: 0.4498 - val_acc: 0.8333
# Epoch 23/70
# Epoch 00023: val_loss did not improve
#  - 15s - loss: 0.2791 - acc: 0.8895 - val_loss: 0.7083 - val_acc: 0.7210
# Epoch 24/70
# Epoch 00024: val_loss improved from 0.24423 to 0.23926, saving model to best_m.h5
#  - 16s - loss: 0.2837 - acc: 0.8792 - val_loss: 0.2393 - val_acc: 0.9045
# Epoch 25/70
# Epoch 00025: val_loss did not improve
#  - 15s - loss: 0.4413 - acc: 0.7847 - val_loss: 0.8472 - val_acc: 0.6629
# Epoch 26/70
# Epoch 00026: val_loss did not improve
#  - 15s - loss: 0.5015 - acc: 0.7650 - val_loss: 5.3195 - val_acc: 0.5243
# Epoch 27/70
# Epoch 00027: val_loss did not improve
#  - 15s - loss: 0.3628 - acc: 0.8549 - val_loss: 1.3805 - val_acc: 0.6479
# Epoch 28/70
# Epoch 00028: val_loss did not improve
#  - 15s - loss: 0.3270 - acc: 0.8689 - val_loss: 0.5749 - val_acc: 0.7397
# Epoch 29/70
# Epoch 00029: val_loss did not improve
#  - 15s - loss: 0.3244 - acc: 0.8521 - val_loss: 0.5115 - val_acc: 0.7397
# Epoch 30/70
# Epoch 00030: val_loss did not improve
#  - 15s - loss: 0.3113 - acc: 0.8745 - val_loss: 0.2541 - val_acc: 0.8858
# Epoch 31/70
# Epoch 00031: val_loss did not improve
#  - 15s - loss: 0.2904 - acc: 0.8830 - val_loss: 0.2494 - val_acc: 0.9026
# Epoch 32/70
# Epoch 00032: val_loss improved from 0.23926 to 0.23469, saving model to best_m.h5
#  - 16s - loss: 0.2806 - acc: 0.8895 - val_loss: 0.2347 - val_acc: 0.8933
# Epoch 33/70
# Epoch 00033: val_loss improved from 0.23469 to 0.23340, saving model to best_m.h5
#  - 16s - loss: 0.2457 - acc: 0.9045 - val_loss: 0.2334 - val_acc: 0.8933
# Epoch 34/70
# Epoch 00034: val_loss improved from 0.23340 to 0.22707, saving model to best_m.h5
#  - 16s - loss: 0.2515 - acc: 0.9082 - val_loss: 0.2271 - val_acc: 0.9026
# Epoch 35/70
# Epoch 00035: val_loss did not improve
#  - 15s - loss: 0.2496 - acc: 0.8961 - val_loss: 0.2321 - val_acc: 0.8914
# Epoch 36/70
# Epoch 00036: val_loss did not improve
#  - 15s - loss: 0.2368 - acc: 0.9204 - val_loss: 0.2329 - val_acc: 0.8970
# Epoch 37/70
# Epoch 00037: val_loss did not improve
#  - 15s - loss: 0.2465 - acc: 0.9035 - val_loss: 0.2304 - val_acc: 0.8895
# Epoch 38/70
# Epoch 00038: val_loss did not improve
#  - 15s - loss: 0.2338 - acc: 0.8989 - val_loss: 0.2766 - val_acc: 0.8839
# Epoch 39/70
# Epoch 00039: val_loss did not improve
#  - 15s - loss: 0.2704 - acc: 0.8961 - val_loss: 0.2476 - val_acc: 0.8895
# Epoch 40/70
# Epoch 00040: val_loss improved from 0.22707 to 0.22216, saving model to best_m.h5
#  - 16s - loss: 0.2441 - acc: 0.9017 - val_loss: 0.2222 - val_acc: 0.8951
# Epoch 41/70
# Epoch 00041: val_loss did not improve
#  - 15s - loss: 0.2221 - acc: 0.9157 - val_loss: 0.2259 - val_acc: 0.8933
# Epoch 42/70
# Epoch 00042: val_loss did not improve
#  - 15s - loss: 0.2417 - acc: 0.8923 - val_loss: 0.2409 - val_acc: 0.8839
# Epoch 43/70
# Epoch 00043: val_loss did not improve
#  - 15s - loss: 0.2960 - acc: 0.8783 - val_loss: 0.2355 - val_acc: 0.8951
# Epoch 44/70
# Epoch 00044: val_loss did not improve
#  - 15s - loss: 0.2373 - acc: 0.9007 - val_loss: 0.2311 - val_acc: 0.9007
# Epoch 45/70
# Epoch 00045: val_loss did not improve
#  - 15s - loss: 0.2340 - acc: 0.9036 - val_loss: 0.2498 - val_acc: 0.8839
# Epoch 46/70
# Epoch 00046: val_loss did not improve
#  - 15s - loss: 0.2275 - acc: 0.8942 - val_loss: 0.2815 - val_acc: 0.8708
# Epoch 47/70
# Epoch 00047: val_loss did not improve
#  - 15s - loss: 0.2758 - acc: 0.8943 - val_loss: 0.2355 - val_acc: 0.8876
# Epoch 48/70
# Epoch 00048: val_loss did not improve
#  - 15s - loss: 0.2393 - acc: 0.9017 - val_loss: 0.2241 - val_acc: 0.9045
# Epoch 49/70
# Epoch 00049: val_loss improved from 0.22216 to 0.22086, saving model to best_m.h5
#  - 16s - loss: 0.2295 - acc: 0.8979 - val_loss: 0.2209 - val_acc: 0.8951
# Epoch 50/70
# Epoch 00050: val_loss did not improve
#  - 15s - loss: 0.2630 - acc: 0.8831 - val_loss: 0.2498 - val_acc: 0.8895
# Epoch 51/70
# Epoch 00051: val_loss improved from 0.22086 to 0.21190, saving model to best_m.h5
#  - 18s - loss: 0.2661 - acc: 0.8933 - val_loss: 0.2119 - val_acc: 0.9064
# Epoch 52/70
# Epoch 00052: val_loss did not improve
#  - 15s - loss: 0.2206 - acc: 0.9026 - val_loss: 0.2220 - val_acc: 0.9064
# Epoch 53/70
# Epoch 00053: val_loss did not improve
#  - 15s - loss: 0.1984 - acc: 0.9148 - val_loss: 0.2364 - val_acc: 0.8933
# Epoch 54/70
# Epoch 00054: val_loss did not improve
#  - 15s - loss: 0.2181 - acc: 0.9101 - val_loss: 0.2656 - val_acc: 0.8801
# Epoch 55/70
# Epoch 00055: val_loss did not improve
#  - 15s - loss: 0.2518 - acc: 0.8961 - val_loss: 0.2201 - val_acc: 0.9120
# Epoch 56/70
# Epoch 00056: val_loss did not improve
#  - 15s - loss: 0.2382 - acc: 0.8971 - val_loss: 0.2228 - val_acc: 0.9157
# Epoch 57/70
# Epoch 00057: val_loss did not improve
#  - 15s - loss: 0.2423 - acc: 0.8876 - val_loss: 0.2324 - val_acc: 0.8914
# Epoch 58/70
# Epoch 00058: val_loss did not improve
#  - 15s - loss: 0.2186 - acc: 0.9101 - val_loss: 0.2494 - val_acc: 0.8895
# Epoch 59/70
# Epoch 00059: val_loss did not improve
#  - 15s - loss: 0.2226 - acc: 0.9026 - val_loss: 0.2195 - val_acc: 0.8951
# Epoch 60/70
# Epoch 00060: val_loss did not improve
#  - 15s - loss: 0.2133 - acc: 0.9073 - val_loss: 0.2322 - val_acc: 0.8970
# Epoch 61/70
# Epoch 00061: val_loss did not improve
#  - 15s - loss: 0.2241 - acc: 0.8877 - val_loss: 0.2201 - val_acc: 0.9082
# Epoch 62/70
# Epoch 00062: val_loss did not improve
#  - 15s - loss: 0.2213 - acc: 0.9082 - val_loss: 0.2320 - val_acc: 0.9007
# Epoch 63/70
# Epoch 00063: val_loss did not improve
#  - 15s - loss: 0.2279 - acc: 0.8962 - val_loss: 0.2312 - val_acc: 0.8895
# Epoch 64/70
# Epoch 00064: val_loss did not improve
#  - 15s - loss: 0.1938 - acc: 0.9232 - val_loss: 0.2634 - val_acc: 0.8839
# Epoch 65/70
# Epoch 00065: val_loss did not improve
#  - 15s - loss: 0.1963 - acc: 0.9185 - val_loss: 0.2280 - val_acc: 0.8989
# Epoch 66/70
# Epoch 00066: val_loss did not improve
#  - 15s - loss: 0.2536 - acc: 0.9036 - val_loss: 0.2217 - val_acc: 0.9064
# Epoch 67/70
# Epoch 00067: val_loss did not improve
#  - 15s - loss: 0.2013 - acc: 0.9288 - val_loss: 0.2356 - val_acc: 0.8951
# Epoch 68/70
# Epoch 00068: val_loss did not improve
#  - 15s - loss: 0.1921 - acc: 0.9232 - val_loss: 0.2616 - val_acc: 0.8933
# Epoch 69/70
# Epoch 00069: val_loss did not improve
#  - 15s - loss: 0.1790 - acc: 0.9363 - val_loss: 0.2258 - val_acc: 0.9007
# Epoch 70/70
# Epoch 00070: val_loss did not improve
#  - 15s - loss: 0.1829 - acc: 0.9363 - val_loss: 0.2345 - val_acc: 0.8989
# ============================

# %%
import pickle
with open('../features/xception_aug1_feat.pkl','wb') as fout:
    pickle.dump([train_pred,test_pred],fout)

# train feat loss
from sklearn.metrics import log_loss
print(log_loss(y,train_pred))
    
submission = pd.DataFrame()
submission['id']=test_df['id']
submission['is_iceberg']=test_pred
print(submission.head())
submission.to_csv('../results/xception_aug1_sub.csv', index=False)
# Out:
# 0.212381384877
#          id  is_iceberg
# 0  5941774d    0.038126
# 1  4023181e    0.899046
# 2  b20200e4    0.327146
# 3  e7f018bb    0.973960
# 4  4371c8c3    0.401795
