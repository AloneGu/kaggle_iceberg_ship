# %%
import pickle
import numpy as np
import xgboost as xgb
import glob
import pandas as pd

fl=[
'../2nd_features/cnn_1_aug_1_fold5_feat.pkl',
'../2nd_features/cnn_2_aug_1_fold5_feat.pkl',
'../2nd_features/cnn_3_aug_1_fold5_feat.pkl',
'../2nd_features/cnn_4_aug_1_fold5_feat.pkl',
'../2nd_features/cnn_5_aug_1_fold5_feat.pkl',
'../2nd_features/incept_aug2_feat.pkl',
#'../2nd_features/other_model_gbrt.pkl',
#'../2nd_features/other_model_gbrt2.pkl',
'../2nd_features/other_model_gbrt4.pkl',
#'../2nd_features/other_model_gbrt5.pkl',
'../2nd_features/other_model_gbrt6.pkl',
#'../2nd_features/other_model_gbrt7.pkl',
#'../2nd_features/other_model_lgb.pkl',
#'../2nd_features/other_model_lgb2.pkl',
#'../2nd_features/other_model_lgb4.pkl',
#'../2nd_features/other_model_lgb5.pkl',
'../2nd_features/other_model_lgb6.pkl',
'../2nd_features/other_model_lgb7.pkl',
#'../2nd_features/other_model_lr.pkl',
#'../2nd_features/other_model_lr2.pkl',
#'../2nd_features/other_model_lr4.pkl',
#'../2nd_features/other_model_lr7.pkl',
#'../2nd_features/other_model_rf.pkl',
#'../2nd_features/other_model_rf2.pkl',
'../2nd_features/other_model_rf4.pkl',
'../2nd_features/other_model_rf5.pkl',
'../2nd_features/other_model_rf6.pkl',
'../2nd_features/other_model_rf7.pkl',
'../2nd_features/other_model_xgb.pkl',
#'../2nd_features/other_model_xgb2.pkl',
'../2nd_features/other_model_xgb4.pkl',
'../2nd_features/other_model_xgb5.pkl',
#'../2nd_features/other_model_xgb6.pkl',
'../2nd_features/other_model_xgb7.pkl',
'../2nd_features/resnet_aug2_feat.pkl',
'../2nd_features/xception_aug1_feat.pkl',
'../2nd_features/vgg_aug1_new_feat.pkl',

 '../features/cnn_1_aug1_feat.pkl',
# '../features/cnn_1_aug_1_fold8_feat.pkl',
# '../features/cnn_1_aug_rescale_preprocess_feat.pkl',
# '../features/cnn_1_aug_skimage_denoise_feat.pkl',
# '../features/cnn_1_aug_skimage_preprocess_feat.pkl',
 '../features/cnn_1_feat.pkl',
# '../features/cnn_2_aug1_feat.pkl',
# '../features/cnn_2_aug_1_fold8_feat.pkl',
# '../features/cnn_2_aug_denoise_preprocess_feat.pkl',
# '../features/cnn_2_aug_rescale_preprocess_feat.pkl',
# '../features/cnn_2_aug_skimage_preprocess_feat.pkl',
# '../features/cnn_2_feat.pkl',
# '../features/cnn_3_aug1_feat.pkl',
# '../features/cnn_3_aug_1_fold8_feat.pkl',
 '../features/cnn_3_aug_denoise_preprocess_feat.pkl',
# '../features/cnn_3_aug_rescale_preprocess_feat.pkl',
# '../features/cnn_3_aug_skimage_preprocess_feat.pkl',
# '../features/cnn_4_aug1_feat.pkl',
# '../features/cnn_4_aug1_feat_add_early.pkl',
# '../features/cnn_4_aug_1_fold8_feat.pkl',
# '../features/cnn_4_aug_denoise_preprocess_feat.pkl',
# '../features/cnn_4_aug_rescale_preprocess_feat.pkl',
# '../features/cnn_4_aug_skimage_preprocess_feat.pkl',
# '../features/cnn_5_aug1_feat.pkl',
# '../features/cnn_5_aug_1_fold8_feat.pkl',
# '../features/cnn_5_aug_denoise_preprocess_feat.pkl',
# '../features/cnn_5_aug_rescale_preprocess_feat.pkl',
# '../features/cnn_5_aug_skimage_preprocess_feat.pkl',
# '../features/incept_1_feat.pkl',
# '../features/incept_aug1_feat.pkl',
 '../features/incept_aug1_fold8_feat.pkl',
# '../features/incept_aug2_feat.pkl',
# '../features/incept_aug3_feat.pkl',
# '../features/incept_aug4_feat.pkl',
# '../features/other_feat.pkl',
# '../features/other_model_gbrt.pkl',
# '../features/other_model_gbrt2.pkl',
# '../features/other_model_gbrt4.pkl',
# '../features/other_model_gbrt5.pkl',
# '../features/other_model_gbrt6.pkl',
# '../features/other_model_lgb.pkl',
# '../features/other_model_lgb2.pkl',
# '../features/other_model_lgb4.pkl',
# '../features/other_model_lgb5.pkl',
# '../features/other_model_lgb6.pkl',
# '../features/other_model_lr.pkl',
# '../features/other_model_lr2.pkl',
# '../features/other_model_lr4.pkl',
# '../features/other_model_lr5.pkl',
# '../features/other_model_lr6.pkl',
# '../features/other_model_rf.pkl',
# '../features/other_model_rf2.pkl',
# '../features/other_model_rf4.pkl',
# '../features/other_model_rf5.pkl',
# '../features/other_model_rf6.pkl',
# '../features/other_model_xgb.pkl',
# '../features/other_model_xgb2.pkl',
# '../features/other_model_xgb4.pkl',
# '../features/other_model_xgb5.pkl',
# '../features/other_model_xgb6.pkl',
# '../features/resnet_1_feat.pkl',
# '../features/resnet_aug1_feat.pkl',
 '../features/resnet_aug1_fold8_feat.pkl',
 '../features/resnet_aug2_feat.pkl',
# '../features/resnet_aug3_feat.pkl',
# '../features/resnet_aug4_feat.pkl',
# '../features/vgg16_1_feat.pkl',
# '../features/vgg_aug1_feat.pkl',
 '../features/vgg_aug1_fold8_feat.pkl',
# '../features/vgg_aug1_new_feat.pkl',
# '../features/xception_aug1_feat.pkl',
]

# %%
def load_x_y():
    train_x,test_x=[],[]
    for f in fl:
        with open(f,'rb') as fin:
            a,b = pickle.load(fin)
            train_x.append(a)
            test_x.append(b)
    train_x = np.hstack(train_x)
    test_x = np.hstack(test_x)
    train_df = pd.read_json('../input/train.json')
    y = train_df.is_iceberg.values
    return train_x,test_x,y

train_x,test_x,train_y = load_x_y()
print(train_x.shape,test_x.shape,train_y.shape)
# Out:
# (1604, 29) (8424, 29) (1604,)

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import log_loss
def cv_test(k_cnt=3,rnd=42,save_flag=False,verbose_cnt=False):
    kf = StratifiedKFold(n_splits=k_cnt, shuffle=True, random_state=rnd*2)
    w_test_pred = None
    r_val_loss = 0
    test_pred = None
    val_loss = 0
    val_loss_list = []
    for train_index, test_index in kf.split(train_x,train_y):
        X_train, X_test = train_x[train_index], train_x[test_index]
        y_train, y_test = train_y[train_index], train_y[test_index]
        params = {
                'colsample_bytree': 0.75,
                'colsample_bylevel':0.95,
                'gamma':0.2,
                'subsample': 0.9,
                'eta': 0.07,
                'max_depth': 3,
                'eval_metric':'logloss',
                'objective':'binary:logistic',
                'scale_pos_weight': 0.85,
                
                }
        
        # def mat
        d_train = xgb.DMatrix(X_train, y_train)
        d_valid = xgb.DMatrix(X_test, y_test)
        d_test = xgb.DMatrix(test_x)
        
        watchlist = [(d_train, 'train'), (d_valid, 'valid')]
        # train model
        m = xgb.train(params, d_train, 500, watchlist, 
                        early_stopping_rounds=20,
                        verbose_eval=verbose_cnt
                        )
        
        # cal val loss
        curr_val_loss = log_loss(y_test,m.predict(d_valid))
        val_loss += curr_val_loss/k_cnt
        val_loss_list.append(curr_val_loss)
        curr_r_val_loss = 1.0 / curr_val_loss
        r_val_loss += curr_r_val_loss
        
        if test_pred is None:
            test_pred = m.predict(d_test)
            w_test_pred = m.predict(d_test)*curr_r_val_loss
        else:
            curr_pred = m.predict(d_test)
            test_pred += curr_pred
            w_test_pred = w_test_pred + curr_pred*curr_r_val_loss

    # avg
    test_pred = test_pred / k_cnt
    w_test_pred = w_test_pred / r_val_loss
    
    # train log loss
    print('local average valid loss',val_loss,'val loss std',np.std(val_loss_list))
    if save_flag:
        test_df=pd.read_json('../input/test.json')
        submission = pd.DataFrame()
        submission['id']=test_df['id']
        submission['is_iceberg']=test_pred
        print(submission.head())
        submission.to_csv('../results/all_xgb3rd_sub_fold_{}_rnd_{}.csv'.format(k_cnt,rnd), index=False)
        


    
print('def done')
# Out:
# def done

# %%
# find new rnd seed
for i in range(100):
    rnd = i*6
    print(rnd)
    cv_test(3,rnd,False)
# Out:
# 0
# local average valid loss 0.140694388935 val loss std 0.0308380932999
# 6
# local average valid loss 0.136198962797 val loss std 0.0179244447626
# 12
# local average valid loss 0.134958198862 val loss std 0.0164103089492
# 18
# local average valid loss 0.145254086905 val loss std 0.0145297803193
# 24
# local average valid loss 0.134006795472 val loss std 0.00653449659583
# 30
# local average valid loss 0.139749572604 val loss std 0.0224025019019
# 36
# local average valid loss 0.139658921641 val loss std 0.0266445782564
# 42
# local average valid loss 0.132941946983 val loss std 0.00757021799504
# 48
# local average valid loss 0.135689035719 val loss std 0.0288101067394
# 54
# local average valid loss 0.134422487176 val loss std 0.0162656787329
# 60
# local average valid loss 0.132452608229 val loss std 0.0143381284928
# 66
# local average valid loss 0.132027397078 val loss std 0.0142344753609
# 72
# local average valid loss 0.135915627091 val loss std 0.0126725907243
# 78
# local average valid loss 0.135206225195 val loss std 0.0104782660821
# 84
# local average valid loss 0.12519952472 val loss std 0.00908726756706
# 90
# local average valid loss 0.139687163443 val loss std 0.0226329497158
# 96
# local average valid loss 0.135140605531 val loss std 0.0267639281499
# 102
# local average valid loss 0.131191256256 val loss std 0.0290187453199
# 108
# local average valid loss 0.141290862771 val loss std 0.0243067887624
# 114
# local average valid loss 0.138961035112 val loss std 0.0306506510377
# 120
# local average valid loss 0.135603235837 val loss std 0.0247842179668
# 126
# local average valid loss 0.13627460135 val loss std 0.0315750603066
# 132
# local average valid loss 0.137199317953 val loss std 0.00220621563947
# 138
# local average valid loss 0.141242682758 val loss std 0.0375083656042
# 144
# local average valid loss 0.139700329562 val loss std 0.0119333094166
# 150
# local average valid loss 0.137377142742 val loss std 0.0277778059447
# 156
# local average valid loss 0.136426077954 val loss std 0.0162203326909
# 162
# local average valid loss 0.133186312035 val loss std 0.0299465413119
# 168
# local average valid loss 0.144650103749 val loss std 0.0425721129317
# 174
# local average valid loss 0.141502179746 val loss std 0.0178411417102
# 180
# local average valid loss 0.140118913631 val loss std 0.00527480499281
# 186
# local average valid loss 0.136392872746 val loss std 0.0285054937526
# 192
# local average valid loss 0.132862793679 val loss std 0.0018086221016
# 198
# local average valid loss 0.143115689157 val loss std 0.0438108750271
# 204
# local average valid loss 0.133153381824 val loss std 0.0241305034759
# 210
# local average valid loss 0.138008251101 val loss std 0.00780156110617
# 216
# local average valid loss 0.137289731263 val loss std 0.0222153731583
# 222
# local average valid loss 0.144044475276 val loss std 0.0127076408093
# 228
# local average valid loss 0.134018440332 val loss std 0.012984945956
# 234
# local average valid loss 0.139407950909 val loss std 0.0145051494285
# 240
# local average valid loss 0.138514328039 val loss std 0.0195057591164
# 246
# local average valid loss 0.133866098749 val loss std 0.0171099194726
# 252
# local average valid loss 0.132824228913 val loss std 0.00385890035392
# 258
# local average valid loss 0.132352084164 val loss std 0.0296594975562
# 264
# local average valid loss 0.13034748806 val loss std 0.0109027048302
# 270
# local average valid loss 0.136447761989 val loss std 0.0234846609367
# 276
# local average valid loss 0.134057413013 val loss std 0.0264495363003
# 282
# local average valid loss 0.13015351902 val loss std 0.01228621919
# 288
# local average valid loss 0.133735438067 val loss std 0.0200086525627
# 294
# local average valid loss 0.140290674631 val loss std 0.0235651711052
# 300
# local average valid loss 0.139339782759 val loss std 0.00758418116508
# 306
# local average valid loss 0.145198468397 val loss std 0.0264291559715
# 312
# local average valid loss 0.147280007027 val loss std 0.0104505699851
# 318
# local average valid loss 0.137530230871 val loss std 0.0320898528565
# 324
# local average valid loss 0.136716283069 val loss std 0.0145565861659
# 330
# local average valid loss 0.135356135531 val loss std 0.00830251577809
# 336
# local average valid loss 0.133313390413 val loss std 0.00823402744089
# 342
# local average valid loss 0.142593556634 val loss std 0.0079768893447
# 348
# local average valid loss 0.141474926406 val loss std 0.0278193515978
# 354
# local average valid loss 0.144167549936 val loss std 0.00655811043419
# 360
# local average valid loss 0.133567996891 val loss std 0.0328188153208
# 366
# local average valid loss 0.13654302686 val loss std 0.0384593904971
# 372
# local average valid loss 0.145531480722 val loss std 0.0111057757673
# 378
# local average valid loss 0.13916184059 val loss std 0.0175686679824
# 384
# local average valid loss 0.136293972657 val loss std 0.0155660158057
# 390
# local average valid loss 0.135782178018 val loss std 0.0304775065942
# 396
# local average valid loss 0.133196199725 val loss std 0.00609678945552
# 402
# local average valid loss 0.136906787079 val loss std 0.0217949349046
# 408
# local average valid loss 0.138251036202 val loss std 0.0275385286775
# 414
# local average valid loss 0.144871673794 val loss std 0.039238517849
# 420
# local average valid loss 0.135880004624 val loss std 0.0203320039666
# 426
# local average valid loss 0.139216486328 val loss std 0.0163926376673
# 432
# local average valid loss 0.130746629426 val loss std 0.012370355423
# 438
# local average valid loss 0.145223619271 val loss std 0.00174105244308
# 444
# local average valid loss 0.140242475972 val loss std 0.0434930529482
# 450
# local average valid loss 0.1355239988 val loss std 0.0299211914234
# 456
# local average valid loss 0.140132723686 val loss std 0.0194571658603
# 462
# local average valid loss 0.131216482727 val loss std 0.00996916382748
# 468
# local average valid loss 0.141943860014 val loss std 0.0181529049436
# 474
# local average valid loss 0.133611928519 val loss std 0.016929577128
# 480
# local average valid loss 0.13231254554 val loss std 0.0221069075595
# 486
# local average valid loss 0.13463816375 val loss std 0.00756360529689
# 492
# local average valid loss 0.1411978269 val loss std 0.0155831527057
# 498
# local average valid loss 0.14288795691 val loss std 0.0273211702811
# 504
# local average valid loss 0.132144820123 val loss std 0.0185465427109
# 510
# local average valid loss 0.134111069344 val loss std 0.0124877218916
# 516
# local average valid loss 0.133632079066 val loss std 0.0180062405575
# 522
# local average valid loss 0.141609733038 val loss std 0.0109212817063
# 528
# local average valid loss 0.145746769989 val loss std 0.0159172100147
# 534
# local average valid loss 0.134889752096 val loss std 0.0254223559157
# 540
# local average valid loss 0.13663298288 val loss std 0.00876735280665
# 546
# local average valid loss 0.137223649937 val loss std 0.0123035043674
# 552
# local average valid loss 0.131837243035 val loss std 0.0304996785555
# 558
# local average valid loss 0.134739635117 val loss std 0.0319310250497
# 564
# local average valid loss 0.137700043203 val loss std 0.0152427814309
# 570
# local average valid loss 0.135853898858 val loss std 0.0169620806033
# 576
# local average valid loss 0.134781473984 val loss std 0.00886805303406
# 582
# local average valid loss 0.140536757426 val loss std 0.0290652284646
# 588
# local average valid loss 0.140063577996 val loss std 0.0140486942638
# 594
# local average valid loss 0.132204606398 val loss std 0.0238074913653

# %%
# find new rnd seed
for i in range(100):
    rnd = i*6
    print(rnd)
    cv_test(5,rnd,False)
# Out:
# 0
# local average valid loss 0.135563150496 val loss std 0.0380211792135
# 6
# local average valid loss 0.132096581598 val loss std 0.0159821140933
# 12
# local average valid loss 0.133345822456 val loss std 0.0277046679788
# 18
# local average valid loss 0.136490590228 val loss std 0.0103027774456
# 24
# local average valid loss 0.137669894571 val loss std 0.011292389796
# 30
# local average valid loss 0.132480170238 val loss std 0.0154265774567
# 36
# local average valid loss 0.129935698046 val loss std 0.0255937868664
# 42
# local average valid loss 0.13273399256 val loss std 0.0153105595905
# 48
# local average valid loss 0.12857649567 val loss std 0.0356961457131
# 54
# local average valid loss 0.131700312861 val loss std 0.0324395309861
# 60
# local average valid loss 0.130618415557 val loss std 0.0186121717241
# 66
# local average valid loss 0.130080363456 val loss std 0.0184644955411
# 72
# local average valid loss 0.141355038595 val loss std 0.026587914491
# 78
# local average valid loss 0.134676067192 val loss std 0.0266714959567
# 84
# local average valid loss 0.127004311603 val loss std 0.0142340905374
# 90
# local average valid loss 0.131901844996 val loss std 0.027088425527
# 96
# local average valid loss 0.126687203472 val loss std 0.0262920931559
# 102
# local average valid loss 0.128314933265 val loss std 0.0392715325911
# 108
# local average valid loss 0.134719865641 val loss std 0.0482999356461
# 114
# local average valid loss 0.134797490148 val loss std 0.0433208791537
# 120
# local average valid loss 0.126022127744 val loss std 0.0375636169147
# 126
# local average valid loss 0.130948530128 val loss std 0.0334059643517
# 132
# local average valid loss 0.13521690902 val loss std 0.019533696009
# 138
# local average valid loss 0.132979027835 val loss std 0.0455930546348
# 144
# local average valid loss 0.136911799201 val loss std 0.0165054891628
# 150
# local average valid loss 0.135436749579 val loss std 0.0271567377092
# 156
# local average valid loss 0.133862253395 val loss std 0.0173912516662
# 162
# local average valid loss 0.12739240993 val loss std 0.0380701621024
# 168
# local average valid loss 0.139572279496 val loss std 0.0342442967822
# 174
# local average valid loss 0.133353134623 val loss std 0.0186568911359
# 180
# local average valid loss 0.140995346592 val loss std 0.039110102404
# 186
# local average valid loss 0.129718504076 val loss std 0.0344792846492
# 192
# local average valid loss 0.135636967425 val loss std 0.00998626545249
# 198
# local average valid loss 0.132961967802 val loss std 0.026967928065
# 204
# local average valid loss 0.128485727188 val loss std 0.00963897774636
# 210
# local average valid loss 0.129002867481 val loss std 0.0240399142386
# 216
# local average valid loss 0.137811382264 val loss std 0.0267276491216
# 222
# local average valid loss 0.132196590717 val loss std 0.0216656455846
# 228
# local average valid loss 0.136363515885 val loss std 0.0164017232782
# 234
# local average valid loss 0.135253402004 val loss std 0.0148509555093
# 240
# local average valid loss 0.127142476115 val loss std 0.0242925167573
# 246
# local average valid loss 0.13249137441 val loss std 0.0264630509185
# 252
# local average valid loss 0.132604994611 val loss std 0.0259205303679
# 258
# local average valid loss 0.130358542966 val loss std 0.0370589122388
# 264
# local average valid loss 0.131884011768 val loss std 0.019198022823
# 270
# local average valid loss 0.127658174039 val loss std 0.0286803796007
# 276
# local average valid loss 0.136097667682 val loss std 0.0168343017756
# 282
# local average valid loss 0.130300867158 val loss std 0.0214279748856
# 288
# local average valid loss 0.13010480517 val loss std 0.0286063546151
# 294
# local average valid loss 0.133909983386 val loss std 0.0356628564452
# 300
# local average valid loss 0.134860525252 val loss std 0.0251367359147
# 306
# local average valid loss 0.138808647338 val loss std 0.016931253808
# 312
# local average valid loss 0.134952586365 val loss std 0.0258243029025
# 318
# local average valid loss 0.13367503267 val loss std 0.0344284870985
# 324
# local average valid loss 0.131466081254 val loss std 0.0149150413643
# 330
# local average valid loss 0.131125341725 val loss std 0.0237437941476
# 336
# local average valid loss 0.131014176512 val loss std 0.0137561322974
# 342
# local average valid loss 0.129786378991 val loss std 0.0139167254859
# 348
# local average valid loss 0.135497145741 val loss std 0.0222816096969
# 354
# local average valid loss 0.138915383995 val loss std 0.0194157185742
# 360
# local average valid loss 0.137474640119 val loss std 0.0426218017971
# 366
# local average valid loss 0.132231280748 val loss std 0.0251080473451
# 372
# local average valid loss 0.135581002406 val loss std 0.0269849845888
# 378
# local average valid loss 0.132009103943 val loss std 0.0231704724947
# 384
# local average valid loss 0.127345720589 val loss std 0.0285527724639
# 390
# local average valid loss 0.132251131196 val loss std 0.0264719534253
# 396
# local average valid loss 0.136937259949 val loss std 0.00825388261059
# 402
# local average valid loss 0.129783606318 val loss std 0.0287917374279
# 408
# local average valid loss 0.131752311425 val loss std 0.03535925131
# 414
# local average valid loss 0.135379770394 val loss std 0.0241887979209
# 420
# local average valid loss 0.131474064021 val loss std 0.0159239573655
# 426
# local average valid loss 0.134444308571 val loss std 0.0191090932659
# 432
# local average valid loss 0.128536728466 val loss std 0.0156447491869
# 438
# local average valid loss 0.134952923895 val loss std 0.0277896180606
# 444
# local average valid loss 0.133508217002 val loss std 0.0329352038411
# 450
# local average valid loss 0.138239988349 val loss std 0.0256657444635
# 456
# local average valid loss 0.133061490193 val loss std 0.0230579907048
# 462
# local average valid loss 0.127075027229 val loss std 0.0421277666742
# 468
# local average valid loss 0.134252874245 val loss std 0.0227584086507
# 474
# local average valid loss 0.134195163866 val loss std 0.0125683911544
# 480
# local average valid loss 0.132233208587 val loss std 0.0413002563239
# 486
# local average valid loss 0.131204175503 val loss std 0.0187115873114
# 492
# local average valid loss 0.132717219122 val loss std 0.0150075413541
# 498
# local average valid loss 0.133990252565 val loss std 0.0270604692122
# 504
# local average valid loss 0.130780820753 val loss std 0.0366612675314
# 510
# local average valid loss 0.134190934444 val loss std 0.0139613855171
# 516
# local average valid loss 0.132231065835 val loss std 0.0183275528631
# 522
# local average valid loss 0.130544396069 val loss std 0.0251654430418
# 528
# local average valid loss 0.135268520037 val loss std 0.0366955297632
# 534
# local average valid loss 0.133139772371 val loss std 0.0328269574509
# 540
# local average valid loss 0.14138891698 val loss std 0.0422353225325
# 546
# local average valid loss 0.134095224676 val loss std 0.0295014499015
# 552
# local average valid loss 0.132265648431 val loss std 0.0284737854187
# 558
# local average valid loss 0.133228307742 val loss std 0.0325194731449
# 564
# local average valid loss 0.133149189795 val loss std 0.0127360808322
# 570
# local average valid loss 0.137323714088 val loss std 0.0218209669783
# 576
# local average valid loss 0.133132462632 val loss std 0.0187013796871
# 582
# local average valid loss 0.129790908864 val loss std 0.0204489275882
# 588
# local average valid loss 0.132899496273 val loss std 0.0246409217418
# 594
# local average valid loss 0.134347484599 val loss std 0.0241380879285

# %%
cv_test(3,42,True,500)
# Out:
# [0]	train-logloss:0.635739	valid-logloss:0.638102
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [121]	train-logloss:0.044721	valid-logloss:0.12304
#
# [0]	train-logloss:0.635909	valid-logloss:0.63679
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [110]	train-logloss:0.047345	valid-logloss:0.130934
#
# [0]	train-logloss:0.635461	valid-logloss:0.638359
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [97]	train-logloss:0.053042	valid-logloss:0.140452
#
# local average valid loss 0.132941946983 val loss std 0.00757021799504
#          id  is_iceberg
# 0  5941774d    0.025341
# 1  4023181e    0.933070
# 2  b20200e4    0.060965
# 3  e7f018bb    0.995788
# 4  4371c8c3    0.028172

# %%
cv_test(3,84,True,500)
# Out:
# [0]	train-logloss:0.636674	valid-logloss:0.637336
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [115]	train-logloss:0.046061	valid-logloss:0.116558
#
# [0]	train-logloss:0.635958	valid-logloss:0.637573
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [179]	train-logloss:0.028489	valid-logloss:0.120183
#
# [0]	train-logloss:0.635895	valid-logloss:0.639926
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [108]	train-logloss:0.048024	valid-logloss:0.1371
#
# local average valid loss 0.12519952472 val loss std 0.00908726756706
#          id  is_iceberg
# 0  5941774d    0.024709
# 1  4023181e    0.937371
# 2  b20200e4    0.073025
# 3  e7f018bb    0.997634
# 4  4371c8c3    0.038527

# %%
cv_test(5,120,True,500)
# Out:
# [0]	train-logloss:0.635671	valid-logloss:0.636818
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [121]	train-logloss:0.050553	valid-logloss:0.109382
#
# [0]	train-logloss:0.636856	valid-logloss:0.636545
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [152]	train-logloss:0.043096	valid-logloss:0.080781
#
# [0]	train-logloss:0.635314	valid-logloss:0.64004
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [58]	train-logloss:0.076853	valid-logloss:0.167893
#
# [0]	train-logloss:0.635324	valid-logloss:0.640038
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [95]	train-logloss:0.055497	valid-logloss:0.169677
#
# [0]	train-logloss:0.636499	valid-logloss:0.637456
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [148]	train-logloss:0.041765	valid-logloss:0.095456
#
# local average valid loss 0.126022127744 val loss std 0.0375636169147
#          id  is_iceberg
# 0  5941774d    0.022360
# 1  4023181e    0.922068
# 2  b20200e4    0.059827
# 3  e7f018bb    0.996555
# 4  4371c8c3    0.026131
