# %%
import pickle
import numpy as np
import xgboost as xgb
import glob
import pandas as pd

fl=[
'../2nd_features/cnn_1_aug_1_fold5_feat.pkl',
'../2nd_features/cnn_2_aug_1_fold5_feat.pkl',
'../2nd_features/cnn_3_aug_1_fold5_feat.pkl',
'../2nd_features/cnn_4_aug_1_fold5_feat.pkl',
'../2nd_features/cnn_5_aug_1_fold5_feat.pkl',
'../2nd_features/incept_aug2_feat.pkl',
#'../2nd_features/other_model_gbrt.pkl',
#'../2nd_features/other_model_gbrt2.pkl',
'../2nd_features/other_model_gbrt4.pkl',
#'../2nd_features/other_model_gbrt5.pkl',
'../2nd_features/other_model_gbrt6.pkl',
#'../2nd_features/other_model_gbrt7.pkl',
#'../2nd_features/other_model_lgb.pkl',
#'../2nd_features/other_model_lgb2.pkl',
#'../2nd_features/other_model_lgb4.pkl',
#'../2nd_features/other_model_lgb5.pkl',
'../2nd_features/other_model_lgb6.pkl',
'../2nd_features/other_model_lgb7.pkl',
#'../2nd_features/other_model_lr.pkl',
#'../2nd_features/other_model_lr2.pkl',
#'../2nd_features/other_model_lr4.pkl',
#'../2nd_features/other_model_lr7.pkl',
#'../2nd_features/other_model_rf.pkl',
#'../2nd_features/other_model_rf2.pkl',
'../2nd_features/other_model_rf4.pkl',
'../2nd_features/other_model_rf5.pkl',
'../2nd_features/other_model_rf6.pkl',
'../2nd_features/other_model_rf7.pkl',
'../2nd_features/other_model_xgb.pkl',
#'../2nd_features/other_model_xgb2.pkl',
'../2nd_features/other_model_xgb4.pkl',
'../2nd_features/other_model_xgb5.pkl',
#'../2nd_features/other_model_xgb6.pkl',
'../2nd_features/other_model_xgb7.pkl',
'../2nd_features/resnet_aug2_feat.pkl',
'../2nd_features/xception_aug1_feat.pkl',
'../2nd_features/vgg_aug1_new_feat.pkl',

 '../features/cnn_1_aug1_feat.pkl',
# '../features/cnn_1_aug_1_fold8_feat.pkl',
# '../features/cnn_1_aug_rescale_preprocess_feat.pkl',
# '../features/cnn_1_aug_skimage_denoise_feat.pkl',
# '../features/cnn_1_aug_skimage_preprocess_feat.pkl',
 '../features/cnn_1_feat.pkl',
# '../features/cnn_2_aug1_feat.pkl',
# '../features/cnn_2_aug_1_fold8_feat.pkl',
# '../features/cnn_2_aug_denoise_preprocess_feat.pkl',
# '../features/cnn_2_aug_rescale_preprocess_feat.pkl',
# '../features/cnn_2_aug_skimage_preprocess_feat.pkl',
# '../features/cnn_2_feat.pkl',
# '../features/cnn_3_aug1_feat.pkl',
# '../features/cnn_3_aug_1_fold8_feat.pkl',
 '../features/cnn_3_aug_denoise_preprocess_feat.pkl',
# '../features/cnn_3_aug_rescale_preprocess_feat.pkl',
# '../features/cnn_3_aug_skimage_preprocess_feat.pkl',
# '../features/cnn_4_aug1_feat.pkl',
# '../features/cnn_4_aug1_feat_add_early.pkl',
# '../features/cnn_4_aug_1_fold8_feat.pkl',
# '../features/cnn_4_aug_denoise_preprocess_feat.pkl',
# '../features/cnn_4_aug_rescale_preprocess_feat.pkl',
# '../features/cnn_4_aug_skimage_preprocess_feat.pkl',
# '../features/cnn_5_aug1_feat.pkl',
# '../features/cnn_5_aug_1_fold8_feat.pkl',
# '../features/cnn_5_aug_denoise_preprocess_feat.pkl',
# '../features/cnn_5_aug_rescale_preprocess_feat.pkl',
# '../features/cnn_5_aug_skimage_preprocess_feat.pkl',
# '../features/incept_1_feat.pkl',
# '../features/incept_aug1_feat.pkl',
 '../features/incept_aug1_fold8_feat.pkl',
# '../features/incept_aug2_feat.pkl',
# '../features/incept_aug3_feat.pkl',
# '../features/incept_aug4_feat.pkl',
# '../features/other_feat.pkl',
# '../features/other_model_gbrt.pkl',
# '../features/other_model_gbrt2.pkl',
# '../features/other_model_gbrt4.pkl',
# '../features/other_model_gbrt5.pkl',
# '../features/other_model_gbrt6.pkl',
# '../features/other_model_lgb.pkl',
# '../features/other_model_lgb2.pkl',
# '../features/other_model_lgb4.pkl',
# '../features/other_model_lgb5.pkl',
# '../features/other_model_lgb6.pkl',
# '../features/other_model_lr.pkl',
# '../features/other_model_lr2.pkl',
# '../features/other_model_lr4.pkl',
# '../features/other_model_lr5.pkl',
# '../features/other_model_lr6.pkl',
# '../features/other_model_rf.pkl',
# '../features/other_model_rf2.pkl',
# '../features/other_model_rf4.pkl',
# '../features/other_model_rf5.pkl',
# '../features/other_model_rf6.pkl',
# '../features/other_model_xgb.pkl',
# '../features/other_model_xgb2.pkl',
# '../features/other_model_xgb4.pkl',
# '../features/other_model_xgb5.pkl',
# '../features/other_model_xgb6.pkl',
# '../features/resnet_1_feat.pkl',
# '../features/resnet_aug1_feat.pkl',
 '../features/resnet_aug1_fold8_feat.pkl',
 '../features/resnet_aug2_feat.pkl',
# '../features/resnet_aug3_feat.pkl',
# '../features/resnet_aug4_feat.pkl',
# '../features/vgg16_1_feat.pkl',
# '../features/vgg_aug1_feat.pkl',
 '../features/vgg_aug1_fold8_feat.pkl',
# '../features/vgg_aug1_new_feat.pkl',
# '../features/xception_aug1_feat.pkl',
    
     '../features/other_model_lr8.pkl',
     '../features/other_model_rf8.pkl',
     '../features/other_model_gbrt8.pkl',
#     '../features/other_model_xgb8.pkl',
#     '../features/other_model_lgb8.pkl'
]

# %%
def load_x_y():
    train_x,test_x=[],[]
    for f in fl:
        with open(f,'rb') as fin:
            a,b = pickle.load(fin)
            train_x.append(a)
            test_x.append(b)
    train_x = np.hstack(train_x)
    test_x = np.hstack(test_x)
    train_df = pd.read_json('../input/train.json')
    y = train_df.is_iceberg.values
    return train_x,test_x,y

train_x,test_x,train_y = load_x_y()
print(train_x.shape,test_x.shape,train_y.shape)
# Out:
# (1604, 31) (8424, 31) (1604,)

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import log_loss
def cv_test(k_cnt=3,rnd=42,save_flag=False,verbose_cnt=False):
    kf = StratifiedKFold(n_splits=k_cnt, shuffle=True, random_state=rnd*2)
    w_test_pred = None
    r_val_loss = 0
    test_pred = None
    val_loss = 0
    val_loss_list = []
    for train_index, test_index in kf.split(train_x,train_y):
        X_train, X_test = train_x[train_index], train_x[test_index]
        y_train, y_test = train_y[train_index], train_y[test_index]
        params = {
                'colsample_bytree': 0.75,
                'colsample_bylevel':0.95,
                'gamma':0.2,
                'subsample': 0.9,
                'eta': 0.07,
                'max_depth': 3,
                'eval_metric':'logloss',
                'objective':'binary:logistic',
                'scale_pos_weight': 0.85,
                
                }
        
        # def mat
        d_train = xgb.DMatrix(X_train, y_train)
        d_valid = xgb.DMatrix(X_test, y_test)
        d_test = xgb.DMatrix(test_x)
        
        watchlist = [(d_train, 'train'), (d_valid, 'valid')]
        # train model
        m = xgb.train(params, d_train, 500, watchlist, 
                        early_stopping_rounds=20,
                        verbose_eval=verbose_cnt
                        )
        
        # cal val loss
        curr_val_loss = log_loss(y_test,m.predict(d_valid))
        val_loss += curr_val_loss/k_cnt
        val_loss_list.append(curr_val_loss)
        curr_r_val_loss = 1.0 / curr_val_loss
        r_val_loss += curr_r_val_loss
        
        if test_pred is None:
            test_pred = m.predict(d_test)
            w_test_pred = m.predict(d_test)*curr_r_val_loss
        else:
            curr_pred = m.predict(d_test)
            test_pred += curr_pred
            w_test_pred = w_test_pred + curr_pred*curr_r_val_loss

    # avg
    test_pred = test_pred / k_cnt
    w_test_pred = w_test_pred / r_val_loss
    
    # train log loss
    print('local average valid loss',val_loss,'val loss std',np.std(val_loss_list))
    if save_flag:
        test_df=pd.read_json('../input/test.json')
        submission = pd.DataFrame()
        submission['id']=test_df['id']
        submission['is_iceberg']=test_pred
        print(submission.head())
        submission.to_csv('../results/all_xgb3rd_sub_fold_{}_rnd_{}.csv'.format(k_cnt,rnd), index=False)
        


    
print('def done')
# Out:
# def done

# %%
# find new rnd seed
for i in range(100):
    rnd = i*6
    print(rnd)
    cv_test(3,rnd,False)
# Out:
# 0
# local average valid loss 0.141957664996 val loss std 0.0287595577086
# 6
# local average valid loss 0.134420320424 val loss std 0.0185066887051
# 12
# local average valid loss 0.134541590052 val loss std 0.0228670800681
# 18
# local average valid loss 0.139496749965 val loss std 0.0164338104259
# 24
# local average valid loss 0.130858844814 val loss std 0.0036782036345
# 30
# local average valid loss 0.135347313713 val loss std 0.0242039396272
# 36
# local average valid loss 0.139807870662 val loss std 0.0257515160582
# 42
# local average valid loss 0.128852811125 val loss std 0.00946824964275
# 48
# local average valid loss 0.136447438588 val loss std 0.0318817590316
# 54
# local average valid loss 0.133325390288 val loss std 0.0132424378221
# 60
# local average valid loss 0.136440480198 val loss std 0.0186061936607
# 66
# local average valid loss 0.12977575322 val loss std 0.0184574299668
# 72
# local average valid loss 0.136296523878 val loss std 0.0128044224983
# 78
# local average valid loss 0.136785302692 val loss std 0.0100275230972
# 84
# local average valid loss 0.128216971721 val loss std 0.00795623973813
# 90
# local average valid loss 0.140079613509 val loss std 0.0239769400479
# 96
# local average valid loss 0.130766086719 val loss std 0.0263505205
# 102
# local average valid loss 0.130427834571 val loss std 0.0316238339627
# 108
# local average valid loss 0.141950143122 val loss std 0.0243057123274
# 114
# local average valid loss 0.141037523469 val loss std 0.0348504846624
# 120
# local average valid loss 0.136259083719 val loss std 0.0249774593476
# 126
# local average valid loss 0.140818731122 val loss std 0.0320011934247
# 132
# local average valid loss 0.137173893689 val loss std 0.00545720695991
# 138
# local average valid loss 0.142414045296 val loss std 0.0387232690858
# 144
# local average valid loss 0.137667061515 val loss std 0.00908717784274
# 150
# local average valid loss 0.136372125112 val loss std 0.0262785637631
# 156
# local average valid loss 0.142385337762 val loss std 0.0126623915773
# 162
# local average valid loss 0.130732983859 val loss std 0.0324120395979
# 168
# local average valid loss 0.140360072622 val loss std 0.0451313064715
# 174
# local average valid loss 0.141400728717 val loss std 0.0202791649683
# 180
# local average valid loss 0.140924360933 val loss std 0.00681110227293
# 186
# local average valid loss 0.13724585432 val loss std 0.028230799684
# 192
# local average valid loss 0.13382199312 val loss std 0.00597543974995
# 198
# local average valid loss 0.140511489553 val loss std 0.0394640380518
# 204
# local average valid loss 0.132383862488 val loss std 0.0243921505042
# 210
# local average valid loss 0.136903258829 val loss std 0.00730280019354
# 216
# local average valid loss 0.135958036207 val loss std 0.0225653625025
# 222
# local average valid loss 0.146086244581 val loss std 0.012218372932
# 228
# local average valid loss 0.133050816715 val loss std 0.0144822024665
# 234
# local average valid loss 0.141103193479 val loss std 0.014413691177
# 240
# local average valid loss 0.140508075896 val loss std 0.022424831047
# 246
# local average valid loss 0.136716177013 val loss std 0.0173997155316
# 252
# local average valid loss 0.129776289601 val loss std 0.00550716905299
# 258
# local average valid loss 0.132522923299 val loss std 0.0282202544756
# 264
# local average valid loss 0.131635967566 val loss std 0.0142888388725
# 270
# local average valid loss 0.13240850174 val loss std 0.0270212239717
# 276
# local average valid loss 0.135400111614 val loss std 0.0260184598728
# 282
# local average valid loss 0.133241589338 val loss std 0.0139144210204
# 288
# local average valid loss 0.135335202031 val loss std 0.0190043855374
# 294
# local average valid loss 0.138969143744 val loss std 0.0260781009261
# 300
# local average valid loss 0.137172095691 val loss std 0.0102851940226
# 306
# local average valid loss 0.141633318749 val loss std 0.0262814549245
# 312
# local average valid loss 0.147291718039 val loss std 0.0136025688806
# 318
# local average valid loss 0.141392488498 val loss std 0.0337701329953
# 324
# local average valid loss 0.133612004684 val loss std 0.0157327155667
# 330
# local average valid loss 0.136422274182 val loss std 0.0111063025989
# 336
# local average valid loss 0.131322176523 val loss std 0.00600160564836
# 342
# local average valid loss 0.137546176889 val loss std 0.00710955107557
# 348
# local average valid loss 0.141343939131 val loss std 0.0260555297872
# 354
# local average valid loss 0.141733100556 val loss std 0.00535664092921
# 360
# local average valid loss 0.132889670326 val loss std 0.0301467955176
# 366
# local average valid loss 0.136208018605 val loss std 0.0401269455016
# 372
# local average valid loss 0.14862193844 val loss std 0.00797788027607
# 378
# local average valid loss 0.139914119752 val loss std 0.0165697863393
# 384
# local average valid loss 0.135574932905 val loss std 0.0125237461905
# 390
# local average valid loss 0.138245245829 val loss std 0.0284882480766
# 396
# local average valid loss 0.135190556321 val loss std 0.00662834724722
# 402
# local average valid loss 0.137512314004 val loss std 0.0265030418677
# 408
# local average valid loss 0.138470517403 val loss std 0.0290764991839
# 414
# local average valid loss 0.146014921797 val loss std 0.0405628210252
# 420
# local average valid loss 0.133590016966 val loss std 0.0220317161789
# 426
# local average valid loss 0.139792354122 val loss std 0.0130844972386
# 432
# local average valid loss 0.12814313118 val loss std 0.0121950030596
# 438
# local average valid loss 0.141598882492 val loss std 0.00532137576245
# 444
# local average valid loss 0.136302277161 val loss std 0.0433396211901
# 450
# local average valid loss 0.137375188093 val loss std 0.0247693271418
# 456
# local average valid loss 0.140334526928 val loss std 0.0208045211838
# 462
# local average valid loss 0.132197558604 val loss std 0.00939503531044
# 468
# local average valid loss 0.140912023993 val loss std 0.0216212604846
# 474
# local average valid loss 0.134405709286 val loss std 0.0207776548438
# 480
# local average valid loss 0.133267472133 val loss std 0.0255544506759
# 486
# local average valid loss 0.132904888024 val loss std 0.0039329353313
# 492
# local average valid loss 0.141541218725 val loss std 0.0129759183537
# 498
# local average valid loss 0.141621580798 val loss std 0.026284266185
# 504
# local average valid loss 0.133644159962 val loss std 0.0163921955011
# 510
# local average valid loss 0.136441471836 val loss std 0.00931095750968
# 516
# local average valid loss 0.134134390742 val loss std 0.0196623698692
# 522
# local average valid loss 0.14070503847 val loss std 0.0119895351708
# 528
# local average valid loss 0.14033208187 val loss std 0.0111650368975
# 534
# local average valid loss 0.133503824678 val loss std 0.0290104731894
# 540
# local average valid loss 0.137408300056 val loss std 0.00923140228626
# 546
# local average valid loss 0.132248689997 val loss std 0.0108034758791
# 552
# local average valid loss 0.132049204817 val loss std 0.0283104467758
# 558
# local average valid loss 0.13244441744 val loss std 0.0298660134835
# 564
# local average valid loss 0.142971474286 val loss std 0.0203246797204
# 570
# local average valid loss 0.134626077066 val loss std 0.0165553642395
# 576
# local average valid loss 0.140845942898 val loss std 0.00785219893301
# 582
# local average valid loss 0.140837340199 val loss std 0.0268260547901
# 588
# local average valid loss 0.138380984744 val loss std 0.0129048205028
# 594
# local average valid loss 0.131779052527 val loss std 0.0211227532568

# %%
# find new rnd seed
for i in range(100):
    rnd = i*6
    print(rnd)
    cv_test(5,rnd,False)
# Out:
# 0
# local average valid loss 0.136918424135 val loss std 0.0348617171189
# 6
# local average valid loss 0.133920413382 val loss std 0.0159409717434
# 12
# local average valid loss 0.133663803311 val loss std 0.0337339776027
# 18
# local average valid loss 0.136038124502 val loss std 0.0118771672026
# 24
# local average valid loss 0.136127980968 val loss std 0.00816795054776
# 30
# local average valid loss 0.138344168166 val loss std 0.0153374063698
# 36
# local average valid loss 0.129517028246 val loss std 0.0239231776815
# 42
# local average valid loss 0.13196769875 val loss std 0.0162558278069
# 48
# local average valid loss 0.124320429403 val loss std 0.034671908802
# 54
# local average valid loss 0.133111334904 val loss std 0.0305044123605
# 60
# local average valid loss 0.129076282389 val loss std 0.0212412115088
# 66
# local average valid loss 0.128286444388 val loss std 0.0180659771997
# 72
# local average valid loss 0.139574424372 val loss std 0.0270532688373
# 78
# local average valid loss 0.132820240551 val loss std 0.0267628171848
# 84
# local average valid loss 0.126872088698 val loss std 0.0108267116309
# 90
# local average valid loss 0.131615763787 val loss std 0.0281695056868
# 96
# local average valid loss 0.128012741446 val loss std 0.0269770689817
# 102
# local average valid loss 0.125849038819 val loss std 0.0378280437957
# 108
# local average valid loss 0.135602845532 val loss std 0.049120559751
# 114
# local average valid loss 0.134799225797 val loss std 0.0467720178431
# 120
# local average valid loss 0.125563046939 val loss std 0.0356769215386
# 126
# local average valid loss 0.130373763942 val loss std 0.0324923745146
# 132
# local average valid loss 0.136526380058 val loss std 0.0173107424226
# 138
# local average valid loss 0.131727283548 val loss std 0.0437568495558
# 144
# local average valid loss 0.135334976306 val loss std 0.0158225831434
# 150
# local average valid loss 0.137182198098 val loss std 0.028380558408
# 156
# local average valid loss 0.138004754692 val loss std 0.0126516151988
# 162
# local average valid loss 0.127761519559 val loss std 0.0369751124724
# 168
# local average valid loss 0.138106685373 val loss std 0.034338405281
# 174
# local average valid loss 0.132075888587 val loss std 0.0190040918599
# 180
# local average valid loss 0.139035591548 val loss std 0.0382022610022
# 186
# local average valid loss 0.132660172494 val loss std 0.0353585737933
# 192
# local average valid loss 0.13735399856 val loss std 0.0112827615207
# 198
# local average valid loss 0.132465695507 val loss std 0.0268524553266
# 204
# local average valid loss 0.129304607278 val loss std 0.00947918702072
# 210
# local average valid loss 0.128769553491 val loss std 0.0232280230906
# 216
# local average valid loss 0.135901775455 val loss std 0.0207181443525
# 222
# local average valid loss 0.132191460699 val loss std 0.0266681189818
# 228
# local average valid loss 0.133012113021 val loss std 0.0149757526049
# 234
# local average valid loss 0.136167786012 val loss std 0.0174202332037
# 240
# local average valid loss 0.125754143013 val loss std 0.0307423442424
# 246
# local average valid loss 0.132356919491 val loss std 0.0294499333766
# 252
# local average valid loss 0.131485612088 val loss std 0.0249079606607
# 258
# local average valid loss 0.131802963173 val loss std 0.0379601092569
# 264
# local average valid loss 0.129620885864 val loss std 0.0239126083313
# 270
# local average valid loss 0.129364018568 val loss std 0.0347206413799
# 276
# local average valid loss 0.1347798349 val loss std 0.0137680820125
# 282
# local average valid loss 0.131319893848 val loss std 0.0240491395611
# 288
# local average valid loss 0.130756429205 val loss std 0.0307718917134
# 294
# local average valid loss 0.129130287678 val loss std 0.0343692382631
# 300
# local average valid loss 0.13165548214 val loss std 0.0260268277275
# 306
# local average valid loss 0.141073627403 val loss std 0.0167892682335
# 312
# local average valid loss 0.136108886833 val loss std 0.0246206238379
# 318
# local average valid loss 0.13214078009 val loss std 0.031847550243
# 324
# local average valid loss 0.132248576302 val loss std 0.0152394790789
# 330
# local average valid loss 0.13143643101 val loss std 0.0232426971471
# 336
# local average valid loss 0.132765816871 val loss std 0.0162203950092
# 342
# local average valid loss 0.132807006977 val loss std 0.0132920834058
# 348
# local average valid loss 0.132449601307 val loss std 0.0211706296398
# 354
# local average valid loss 0.138749155447 val loss std 0.0185190304497
# 360
# local average valid loss 0.136441692823 val loss std 0.0413591229522
# 366
# local average valid loss 0.132190895942 val loss std 0.025189443095
# 372
# local average valid loss 0.137431242825 val loss std 0.0309093262638
# 378
# local average valid loss 0.131750992145 val loss std 0.0235999101566
# 384
# local average valid loss 0.12612563505 val loss std 0.0348521853368
# 390
# local average valid loss 0.132335317533 val loss std 0.0280235025048
# 396
# local average valid loss 0.132342433578 val loss std 0.00896160066962
# 402
# local average valid loss 0.129191789648 val loss std 0.0304412237001
# 408
# local average valid loss 0.130803041639 val loss std 0.041254998601
# 414
# local average valid loss 0.136804230485 val loss std 0.0266160494315
# 420
# local average valid loss 0.131501540084 val loss std 0.0181474309068
# 426
# local average valid loss 0.136426861442 val loss std 0.0162527736105
# 432
# local average valid loss 0.129787424647 val loss std 0.0192418400811
# 438
# local average valid loss 0.129713218564 val loss std 0.0286163818584
# 444
# local average valid loss 0.135015781888 val loss std 0.0334889342989
# 450
# local average valid loss 0.134663013157 val loss std 0.0259546661543
# 456
# local average valid loss 0.132424736869 val loss std 0.0259307672686
# 462
# local average valid loss 0.129876418921 val loss std 0.0438266007213
# 468
# local average valid loss 0.131039215359 val loss std 0.022430838481
# 474
# local average valid loss 0.13452110239 val loss std 0.0165659115152
# 480
# local average valid loss 0.135687135498 val loss std 0.0397088671228
# 486
# local average valid loss 0.128664526365 val loss std 0.02231724939
# 492
# local average valid loss 0.131940694615 val loss std 0.0161133027288
# 498
# local average valid loss 0.131208937074 val loss std 0.0256450311729
# 504
# local average valid loss 0.132695592674 val loss std 0.0357332576869
# 510
# local average valid loss 0.134207993205 val loss std 0.0157721845279
# 516
# local average valid loss 0.13174882 val loss std 0.0187380095751
# 522
# local average valid loss 0.134526321778 val loss std 0.0280358054492
# 528
# local average valid loss 0.134732604905 val loss std 0.0352582405021
# 534
# local average valid loss 0.130484704894 val loss std 0.0322915137622
# 540
# local average valid loss 0.137686570831 val loss std 0.0428007219135
# 546
# local average valid loss 0.134688604768 val loss std 0.0320448382162
# 552
# local average valid loss 0.133525360342 val loss std 0.0285453677553
# 558
# local average valid loss 0.132994748085 val loss std 0.0299815967933
# 564
# local average valid loss 0.132693901317 val loss std 0.0120978659906
# 570
# local average valid loss 0.137145730553 val loss std 0.0231255226903
# 576
# local average valid loss 0.134141136271 val loss std 0.019854871502
# 582
# local average valid loss 0.132062088292 val loss std 0.0191107964715
# 588
# local average valid loss 0.133846517739 val loss std 0.0227629286267
# 594
# local average valid loss 0.132849237738 val loss std 0.0259000466147

# %%
cv_test(3,42,True,500)
# Out:
# [0]	train-logloss:0.635994	valid-logloss:0.638482
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [148]	train-logloss:0.036394	valid-logloss:0.116255
#
# [0]	train-logloss:0.635829	valid-logloss:0.636936
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [105]	train-logloss:0.049719	valid-logloss:0.128718
#
# [0]	train-logloss:0.635343	valid-logloss:0.637762
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [89]	train-logloss:0.056812	valid-logloss:0.138714
#
# local average valid loss 0.128852811125 val loss std 0.00946824964275
#          id  is_iceberg
# 0  5941774d    0.044398
# 1  4023181e    0.892183
# 2  b20200e4    0.051542
# 3  e7f018bb    0.994553
# 4  4371c8c3    0.035138

# %%
cv_test(3,84,True,500)
# Out:
# [0]	train-logloss:0.636164	valid-logloss:0.636991
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [124]	train-logloss:0.04277	valid-logloss:0.116489
#
# [0]	train-logloss:0.636169	valid-logloss:0.636246
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [89]	train-logloss:0.058428	valid-logloss:0.129772
#
# [0]	train-logloss:0.635895	valid-logloss:0.639868
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [136]	train-logloss:0.035501	valid-logloss:0.134479
#
# local average valid loss 0.128216971721 val loss std 0.00795623973813
#          id  is_iceberg
# 0  5941774d    0.028729
# 1  4023181e    0.908333
# 2  b20200e4    0.061562
# 3  e7f018bb    0.996490
# 4  4371c8c3    0.048226

# %%
cv_test(5,120,True,500)
# Out:
# [0]	train-logloss:0.635851	valid-logloss:0.637987
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [123]	train-logloss:0.047623	valid-logloss:0.110721
#
# [0]	train-logloss:0.636787	valid-logloss:0.636934
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [183]	train-logloss:0.033651	valid-logloss:0.078428
#
# [0]	train-logloss:0.635314	valid-logloss:0.64004
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [57]	train-logloss:0.078937	valid-logloss:0.169285
#
# [0]	train-logloss:0.635211	valid-logloss:0.639648
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [119]	train-logloss:0.043823	valid-logloss:0.161764
#
# [0]	train-logloss:0.636405	valid-logloss:0.637118
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [120]	train-logloss:0.04888	valid-logloss:0.102596
#
# local average valid loss 0.125563046939 val loss std 0.0356769215386
#          id  is_iceberg
# 0  5941774d    0.023923
# 1  4023181e    0.888393
# 2  b20200e4    0.043800
# 3  e7f018bb    0.996702
# 4  4371c8c3    0.028490
