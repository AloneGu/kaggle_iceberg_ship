# %%
import pickle
# https://www.kaggle.com/submarineering/submarineering-even-better-public-score-until-now
ens_file = 'submission54.csv'
other_files = [
    '../results/cnn_1_aug_1_fold8.csv',
    '../results/cnn_2_aug_1_fold8.csv',
    '../results/cnn_3_aug_1_fold8.csv',
    '../results/cnn_5_aug_1_fold8.csv',
    '../results/cnn_4_aug1_best_acc_sub.csv',
    '../results/incept_aug1_sub.csv',
    '../results/resnet_aug1_sub.csv',
    '../results/xception_aug1_sub.csv',
    '../results/vgg_aug1_sub.csv',
    '../features/other_model_gbrt2.pkl',
    '../features/other_model_lgb2.pkl',
    '../features/other_model_lr2.pkl',
    '../features/other_model_rf2.pkl',
    '../features/other_model_xgb2.pkl',
]

import pandas as pd
best_df = pd.read_csv(ens_file)
best_df.head()
# Out:
#          id  is_iceberg
# 0  5941774d    0.005586
# 1  4023181e    0.031688
# 2  b20200e4    0.001000
# 3  e7f018bb    0.999000
# 4  4371c8c3    0.022151

# %%
other_res = []
for f in other_files:
    if f.endswith('csv'):
        other_res.append(pd.read_csv(f).is_iceberg.values)
    else:
        with open(f,'rb') as fin:
            a,b = pickle.load(fin)
            other_res.append(b.flatten())
    
import numpy as np
other_res = np.vstack(other_res).T

# %%
concat_df = pd.DataFrame(other_res,columns=['a{}'.format(i) for i in range(len(other_files))])
concat_df['base'] = best_df.is_iceberg
concat_df.head()
# Out:
#          a0        a1        a2        a3        a4        a5        a6  \
# 0  0.103387  0.073844  0.165315  0.214610  0.066792  0.093266  0.209001
# 1  0.985510  0.795579  0.660264  0.895995  0.937345  0.963237  0.701245
# 2  0.918696  0.420294  0.244674  0.034479  0.238906  0.185977  0.055742
# 3  0.995533  0.998610  0.997191  0.997006  0.992169  0.999560  0.996637
# 4  0.832899  0.081664  0.089288  0.531016  0.356168  0.466361  0.009555
#
#          a7        a8        a9       a10           a11       a12       a13  \
# 0  0.038126  0.047048  0.125865  0.141511  1.430462e-02  0.389589  0.134683
# 1  0.899046  0.724682  0.646595  0.945121  1.000000e+00  0.664402  0.878118
# 2  0.327146  0.228813  0.562446  0.312999  7.389628e-38  0.378330  0.536110
# 3  0.973960  0.997117  0.994916  0.982090  9.992191e-01  0.942157  0.979548
# 4  0.401795  0.084673  0.899276  0.923296  1.000000e+00  0.689455  0.876706
#
#        base
# 0  0.005586
# 1  0.031688
# 2  0.001000
# 3  0.999000
# 4  0.022151

# %%
concat_df.corr()
# Out:
#             a0        a1        a2        a3        a4        a5        a6  \
# a0    1.000000  0.810364  0.805080  0.811238  0.776847  0.675265  0.576780
# a1    0.810364  1.000000  0.968363  0.897532  0.885182  0.751177  0.728756
# a2    0.805080  0.968363  1.000000  0.886488  0.857688  0.704046  0.694611
# a3    0.811238  0.897532  0.886488  1.000000  0.911919  0.828868  0.783691
# a4    0.776847  0.885182  0.857688  0.911919  1.000000  0.884554  0.859869
# a5    0.675265  0.751177  0.704046  0.828868  0.884554  1.000000  0.922659
# a6    0.576780  0.728756  0.694611  0.783691  0.859869  0.922659  1.000000
# a7    0.655988  0.783638  0.741797  0.813593  0.886534  0.947634  0.929019
# a8    0.696394  0.879936  0.856875  0.795707  0.815577  0.734770  0.694257
# a9    0.702630  0.722982  0.717242  0.727466  0.688177  0.611294  0.580110
# a10   0.790553  0.768430  0.759534  0.795997  0.733725  0.650376  0.582144
# a11   0.709139  0.627945  0.592915  0.734832  0.690478  0.690432  0.601753
# a12   0.786851  0.759270  0.736630  0.795825  0.767998  0.738159  0.672472
# a13   0.791859  0.762969  0.760788  0.781324  0.721820  0.625591  0.573842
# base  0.311425  0.518336  0.485198  0.488443  0.575006  0.651440  0.675150
#
#             a7        a8        a9       a10       a11       a12       a13  \
# a0    0.655988  0.696394  0.702630  0.790553  0.709139  0.786851  0.791859
# a1    0.783638  0.879936  0.722982  0.768430  0.627945  0.759270  0.762969
# a2    0.741797  0.856875  0.717242  0.759534  0.592915  0.736630  0.760788
# a3    0.813593  0.795707  0.727466  0.795997  0.734832  0.795825  0.781324
# a4    0.886534  0.815577  0.688177  0.733725  0.690478  0.767998  0.721820
# a5    0.947634  0.734770  0.611294  0.650376  0.690432  0.738159  0.625591
# a6    0.929019  0.694257  0.580110  0.582144  0.601753  0.672472  0.573842
# a7    1.000000  0.769097  0.621297  0.647414  0.648616  0.734875  0.625761
# a8    0.769097  1.000000  0.642495  0.659422  0.543989  0.706487  0.650344
# a9    0.621297  0.642495  1.000000  0.906386  0.703034  0.849713  0.937020
# a10   0.647414  0.659422  0.906386  1.000000  0.805296  0.910549  0.982301
# a11   0.648616  0.543989  0.703034  0.805296  1.000000  0.802869  0.777537
# a12   0.734875  0.706487  0.849713  0.910549  0.802869  1.000000  0.902301
# a13   0.625761  0.650344  0.937020  0.982301  0.777537  0.902301  1.000000
# base  0.711989  0.682556  0.461156  0.392502  0.363198  0.537155  0.387244
#
#           base
# a0    0.311425
# a1    0.518336
# a2    0.485198
# a3    0.488443
# a4    0.575006
# a5    0.651440
# a6    0.675150
# a7    0.711989
# a8    0.682556
# a9    0.461156
# a10   0.392502
# a11   0.363198
# a12   0.537155
# a13   0.387244
# base  1.000000

# %%
concat_df.corr().mean()

# a0      0.640213
# a1      0.775139
# a2      0.752027
# a3      0.775800
# a4      0.794752
# a5      0.766002
# a6      0.741070
# a7      0.785623
# a8      0.770391
# a9      0.744807
# a10     0.761894
# a11     0.697090
# a12     0.763554
# a13     0.766731
# base    0.641168
# dtype: float64
# choose a0,a2,a6,a9,others 1, score 1322
# use all , other 2nd version, score 1316
# Out:
# a0      0.726694
# a1      0.790992
# a2      0.771150
# a3      0.803528
# a4      0.803692
# a5      0.761084
# a6      0.725007
# a7      0.767817
# a8      0.741860
# a9      0.724733
# a10     0.758975
# a11     0.686135
# a12     0.780077
# a13     0.752047
# base    0.549386
# dtype: float64

# %%
print(other_res.shape)
other_median = np.median(other_res,axis=1)
print(other_median[:5])
other_mean = np.mean(other_res,axis=1)
print(other_mean[:5])
# Out:
# (8424, 14)
# [ 0.11462599  0.8870569   0.27883672  0.99608495  0.49868836]
# [ 0.12981015  0.83551005  0.31747227  0.9889795   0.51729655]

# %%
concat_sub = concat_df.copy()
concat_sub['is_iceberg_base'] = best_df['is_iceberg']
all_files_cnt = len(other_files)+1
concat_sub['is_iceberg_max'] = concat_sub.iloc[:, 0:all_files_cnt].max(axis=1)
concat_sub['is_iceberg_min'] = concat_sub.iloc[:, 0:all_files_cnt].min(axis=1)
concat_sub['is_iceberg_mean'] = concat_sub.iloc[:, 0:all_files_cnt].mean(axis=1)
concat_sub['is_iceberg_median'] = concat_sub.iloc[:, 0:all_files_cnt].median(axis=1)

concat_sub.head()
# Out:
#          a0        a1        a2        a3        a4        a5        a6  \
# 0  0.103387  0.073844  0.165315  0.214610  0.066792  0.093266  0.209001
# 1  0.985510  0.795579  0.660264  0.895995  0.937345  0.963237  0.701245
# 2  0.918696  0.420294  0.244674  0.034479  0.238906  0.185977  0.055742
# 3  0.995533  0.998610  0.997191  0.997006  0.992169  0.999560  0.996637
# 4  0.832899  0.081664  0.089288  0.531016  0.356168  0.466361  0.009555
#
#          a7        a8        a9       a10           a11       a12       a13  \
# 0  0.038126  0.047048  0.125865  0.141511  1.430462e-02  0.389589  0.134683
# 1  0.899046  0.724682  0.646595  0.945121  1.000000e+00  0.664402  0.878118
# 2  0.327146  0.228813  0.562446  0.312999  7.389628e-38  0.378330  0.536110
# 3  0.973960  0.997117  0.994916  0.982090  9.992191e-01  0.942157  0.979548
# 4  0.401795  0.084673  0.899276  0.923296  1.000000e+00  0.689455  0.876706
#
#        base  is_iceberg_base  is_iceberg_max  is_iceberg_min  is_iceberg_mean  \
# 0  0.005586         0.005586        0.389589    5.586000e-03         0.121529
# 1  0.031688         0.031688        1.000000    3.168800e-02         0.781922
# 2  0.001000         0.001000        0.918696    7.389628e-38         0.296374
# 3  0.999000         0.999000        0.999560    9.421567e-01         0.989648
# 4  0.022151         0.022151        1.000000    9.555449e-03         0.484287
#
#    is_iceberg_median
# 0           0.103387
# 1           0.878118
# 2           0.244674
# 3           0.996637
# 4           0.466361

# %%
cutoff_lo = 0.8
cutoff_hi = 0.2
concat_sub['is_iceberg'] = np.where(np.all(concat_sub.iloc[:,0:all_files_cnt] > cutoff_lo, axis=1), 
                                    concat_sub['is_iceberg_max'], 
                                    np.where(np.all(concat_sub.iloc[:,0:all_files_cnt] < cutoff_hi, axis=1),
                                             concat_sub['is_iceberg_min'], 
                                             concat_sub['is_iceberg_base']))
#concat_sub['is_iceberg'] = np.clip(concat_sub['is_iceberg'].values, 0.001, 0.999)
concat_sub['id'] = best_df['id']
concat_sub[['id', 'is_iceberg']].to_csv('stack_minmax_bestbase2.csv', 
                                        index=False)

concat_sub.head(10)
# Out:
#          a0        a1        a2        a3        a4        a5        a6  \
# 0  0.103387  0.073844  0.165315  0.214610  0.066792  0.093266  0.209001
# 1  0.985510  0.795579  0.660264  0.895995  0.937345  0.963237  0.701245
# 2  0.918696  0.420294  0.244674  0.034479  0.238906  0.185977  0.055742
# 3  0.995533  0.998610  0.997191  0.997006  0.992169  0.999560  0.996637
# 4  0.832899  0.081664  0.089288  0.531016  0.356168  0.466361  0.009555
# 5  0.984342  0.876293  0.980828  0.377736  0.250300  0.193644  0.044427
# 6  0.079495  0.043564  0.045362  0.109253  0.051750  0.049468  0.060563
# 7  0.999483  0.999459  0.998909  0.998439  0.999486  0.999839  0.999946
# 8  0.000571  0.000044  0.000219  0.003423  0.000002  0.000210  0.000282
# 9  0.000168  0.000013  0.000103  0.002302  0.000059  0.000439  0.000261
#
#          a7        a8        a9    ...          a12       a13      base  \
# 0  0.038126  0.047048  0.125865    ...     0.389589  0.134683  0.005586
# 1  0.899046  0.724682  0.646595    ...     0.664402  0.878118  0.031688
# 2  0.327146  0.228813  0.562446    ...     0.378330  0.536110  0.001000
# 3  0.973960  0.997117  0.994916    ...     0.942157  0.979548  0.999000
# 4  0.401795  0.084673  0.899276    ...     0.689455  0.876706  0.022151
# 5  0.330260  0.801545  0.473977    ...     0.445534  0.561407  0.051959
# 6  0.071390  0.112617  0.000295    ...     0.123392  0.014316  0.003916
# 7  0.997832  0.996569  0.999179    ...     0.981688  0.996107  0.999000
# 8  0.000790  0.000052  0.001617    ...     0.004000  0.003478  0.001000
# 9  0.000243  0.000165  0.000215    ...     0.008000  0.000698  0.001000
#
#    is_iceberg_base  is_iceberg_max  is_iceberg_min  is_iceberg_mean  \
# 0         0.005586        0.389589    5.586000e-03         0.121529
# 1         0.031688        1.000000    3.168800e-02         0.781922
# 2         0.001000        0.918696    7.389628e-38         0.296374
# 3         0.999000        0.999560    9.421567e-01         0.989648
# 4         0.022151        1.000000    9.555449e-03         0.484287
# 5         0.051959        0.984342    7.390925e-09         0.458836
# 6         0.003916        0.123392    2.950247e-04         0.054800
# 7         0.999000        0.999946    9.816881e-01         0.997594
# 8         0.001000        0.004000    6.185342e-09         0.001234
# 9         0.001000        0.008000    1.118503e-12         0.000924
#
#    is_iceberg_median    is_iceberg        id
# 0           0.103387  5.586000e-03  5941774d
# 1           0.878118  3.168800e-02  4023181e
# 2           0.244674  1.000000e-03  b20200e4
# 3           0.996637  9.995600e-01  e7f018bb
# 4           0.466361  2.215100e-02  4371c8c3
# 5           0.445534  5.195900e-02  a8d9b1fd
# 6           0.049468  2.950247e-04  29e7727e
# 7           0.999000  9.999459e-01  92a51ffb
# 8           0.000571  6.185342e-09  c769ac97
# 9           0.000215  1.118503e-12  aee0547d
#
# [10 rows x 22 columns]

# %%
diff_res = concat_sub['is_iceberg']-concat_sub['base']
print(type(diff_res))
cnt = np.where(diff_res!=0)
print(cnt[0].shape)
print(concat_sub['is_iceberg'].std())
# Out:
# <class 'pandas.core.series.Series'>
# (1567,)
# 0.37632824747

# %%
concat_sub['is_iceberg'] = np.clip(concat_sub['is_iceberg'].values, 0.001, 0.999)
concat_sub[['id', 'is_iceberg']].to_csv('clip_stack_minmax_bestbase2.csv', 
                                        index=False)

# %%
diff_res = concat_sub['is_iceberg']-concat_sub['base']
print(type(diff_res))
cnt = np.where(diff_res!=0)
print(cnt[0].shape)
print(concat_sub['is_iceberg'].std())
# Out:
# <class 'pandas.core.series.Series'>
# (150,)
# 0.376144763798
