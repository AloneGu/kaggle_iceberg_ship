# %%
import pickle
# https://www.kaggle.com/submarineering/submarineering-even-better-public-score-until-now
ens_file = 'submission54.csv'
other_files = [
    '../results/cnn_1_aug_1_fold8.csv',
    '../results/cnn_2_aug_1_fold8.csv',
    '../results/cnn_3_aug_1_fold8.csv',
    '../results/cnn_5_aug_1_fold8.csv',
    '../results/cnn_4_aug1_best_acc_sub.csv',
    '../results/incept_aug1_sub.csv',
    '../results/resnet_aug1_sub.csv',
    '../results/xception_aug1_sub.csv',
    '../results/vgg_aug1_sub.csv',
    '../features/other_model_gbrt.pkl',
    '../features/other_model_lgb.pkl',
    '../features/other_model_lr.pkl',
    '../features/other_model_rf.pkl',
    '../features/other_model_xgb.pkl',
]

import pandas as pd
best_df = pd.read_csv(ens_file)
best_df.head()
# Out:
#          id  is_iceberg
# 0  5941774d    0.005586
# 1  4023181e    0.031688
# 2  b20200e4    0.001000
# 3  e7f018bb    0.999000
# 4  4371c8c3    0.022151

# %%
other_res = []
for f in other_files:
    if f.endswith('csv'):
        other_res.append(pd.read_csv(f).is_iceberg.values)
    else:
        with open(f,'rb') as fin:
            a,b = pickle.load(fin)
            other_res.append(b.flatten())
    
import numpy as np
other_res = np.vstack(other_res).T

# %%
concat_df = pd.DataFrame(other_res,columns=['a{}'.format(i) for i in range(len(other_files))])
concat_df['base'] = best_df.is_iceberg
concat_df.head()
# Out:
#          a0        a1        a2        a3        a4        a5        a6  \
# 0  0.103387  0.073844  0.165315  0.214610  0.066792  0.093266  0.209001
# 1  0.985510  0.795579  0.660264  0.895995  0.937345  0.963237  0.701245
# 2  0.918696  0.420294  0.244674  0.034479  0.238906  0.185977  0.055742
# 3  0.995533  0.998610  0.997191  0.997006  0.992169  0.999560  0.996637
# 4  0.832899  0.081664  0.089288  0.531016  0.356168  0.466361  0.009555
#
#          a7        a8        a9       a10           a11       a12       a13  \
# 0  0.038126  0.047048  0.098136  0.039015  7.583175e-03  0.434977  0.037466
# 1  0.899046  0.724682  0.533985  0.852546  9.215962e-01  0.399325  0.679148
# 2  0.327146  0.228813  0.048829  0.008003  4.462567e-48  0.211692  0.063756
# 3  0.973960  0.997117  0.958489  0.990437  9.554635e-01  0.873914  0.982605
# 4  0.401795  0.084673  0.341004  0.787663  9.799408e-01  0.457354  0.394014
#
#        base
# 0  0.005586
# 1  0.031688
# 2  0.001000
# 3  0.999000
# 4  0.022151

# %%
concat_df.corr()
# Out:
#             a0        a1        a2        a3        a4        a5        a6  \
# a0    1.000000  0.810364  0.805080  0.811238  0.776847  0.675265  0.576780
# a1    0.810364  1.000000  0.968363  0.897532  0.885182  0.751177  0.728756
# a2    0.805080  0.968363  1.000000  0.886488  0.857688  0.704046  0.694611
# a3    0.811238  0.897532  0.886488  1.000000  0.911919  0.828868  0.783691
# a4    0.776847  0.885182  0.857688  0.911919  1.000000  0.884554  0.859869
# a5    0.675265  0.751177  0.704046  0.828868  0.884554  1.000000  0.922659
# a6    0.576780  0.728756  0.694611  0.783691  0.859869  0.922659  1.000000
# a7    0.655988  0.783638  0.741797  0.813593  0.886534  0.947634  0.929019
# a8    0.696394  0.879936  0.856875  0.795707  0.815577  0.734770  0.694257
# a9    0.502502  0.680373  0.653663  0.683450  0.687736  0.667039  0.644897
# a10   0.524739  0.701638  0.676706  0.719306  0.712480  0.691727  0.648103
# a11   0.390219  0.584651  0.550102  0.595389  0.643168  0.674552  0.641542
# a12   0.528064  0.713616  0.695000  0.695321  0.706973  0.683041  0.667272
# a13   0.538291  0.723526  0.704783  0.726055  0.717751  0.673262  0.649451
# base  0.311425  0.518336  0.485198  0.488443  0.575006  0.651440  0.675150
#
#             a7        a8        a9       a10       a11       a12       a13  \
# a0    0.655988  0.696394  0.502502  0.524739  0.390219  0.528064  0.538291
# a1    0.783638  0.879936  0.680373  0.701638  0.584651  0.713616  0.723526
# a2    0.741797  0.856875  0.653663  0.676706  0.550102  0.695000  0.704783
# a3    0.813593  0.795707  0.683450  0.719306  0.595389  0.695321  0.726055
# a4    0.886534  0.815577  0.687736  0.712480  0.643168  0.706973  0.717751
# a5    0.947634  0.734770  0.667039  0.691727  0.674552  0.683041  0.673262
# a6    0.929019  0.694257  0.644897  0.648103  0.641542  0.667272  0.649451
# a7    1.000000  0.769097  0.692213  0.714506  0.709510  0.727373  0.701454
# a8    0.769097  1.000000  0.714838  0.727359  0.673909  0.771789  0.742796
# a9    0.692213  0.714838  1.000000  0.935684  0.775650  0.888950  0.965579
# a10   0.714506  0.727359  0.935684  1.000000  0.840808  0.897462  0.977662
# a11   0.709510  0.673909  0.775650  0.840808  1.000000  0.814706  0.810988
# a12   0.727373  0.771789  0.888950  0.897462  0.814706  1.000000  0.903020
# a13   0.701454  0.742796  0.965579  0.977662  0.810988  0.903020  1.000000
# base  0.711989  0.682556  0.679540  0.660228  0.751152  0.760719  0.666344
#
#           base
# a0    0.311425
# a1    0.518336
# a2    0.485198
# a3    0.488443
# a4    0.575006
# a5    0.651440
# a6    0.675150
# a7    0.711989
# a8    0.682556
# a9    0.679540
# a10   0.660228
# a11   0.751152
# a12   0.760719
# a13   0.666344
# base  1.000000

# %%
concat_df.corr().mean()

# a0      0.640213
# a1      0.775139
# a2      0.752027
# a3      0.775800
# a4      0.794752
# a5      0.766002
# a6      0.741070
# a7      0.785623
# a8      0.770391
# a9      0.744807
# a10     0.761894
# a11     0.697090
# a12     0.763554
# a13     0.766731
# base    0.641168
# dtype: float64
# choose a0,a2,a6,a9,others 1322
# Out:
# a0      0.640213
# a1      0.775139
# a2      0.752027
# a3      0.775800
# a4      0.794752
# a5      0.766002
# a6      0.741070
# a7      0.785623
# a8      0.770391
# a9      0.744807
# a10     0.761894
# a11     0.697090
# a12     0.763554
# a13     0.766731
# base    0.641168
# dtype: float64

# %%
print(other_res.shape)
other_median = np.median(other_res,axis=1)
print(other_median[:5])
other_mean = np.mean(other_res,axis=1)
print(other_mean[:5])
# Out:
# (8424, 14)
# [ 0.08355508  0.82406246  0.19883478  0.99385101  0.39790485]
# [ 0.11632629  0.7821074   0.21335769  0.97919231  0.41524259]

# %%
concat_sub = concat_df.copy()
concat_sub['is_iceberg_base'] = best_df['is_iceberg']
all_files_cnt = len(other_files)+1
concat_sub['is_iceberg_max'] = concat_sub.iloc[:, 0:all_files_cnt].max(axis=1)
concat_sub['is_iceberg_min'] = concat_sub.iloc[:, 0:all_files_cnt].min(axis=1)
concat_sub['is_iceberg_mean'] = concat_sub.iloc[:, 0:all_files_cnt].mean(axis=1)
concat_sub['is_iceberg_median'] = concat_sub.iloc[:, 0:all_files_cnt].median(axis=1)

concat_sub.head()
# Out:
#          a0        a1        a2        a3        a4        a5        a6  \
# 0  0.103387  0.073844  0.165315  0.214610  0.066792  0.093266  0.209001
# 1  0.985510  0.795579  0.660264  0.895995  0.937345  0.963237  0.701245
# 2  0.918696  0.420294  0.244674  0.034479  0.238906  0.185977  0.055742
# 3  0.995533  0.998610  0.997191  0.997006  0.992169  0.999560  0.996637
# 4  0.832899  0.081664  0.089288  0.531016  0.356168  0.466361  0.009555
#
#          a7        a8        a9       a10           a11       a12       a13  \
# 0  0.038126  0.047048  0.098136  0.039015  7.583175e-03  0.434977  0.037466
# 1  0.899046  0.724682  0.533985  0.852546  9.215962e-01  0.399325  0.679148
# 2  0.327146  0.228813  0.048829  0.008003  4.462567e-48  0.211692  0.063756
# 3  0.973960  0.997117  0.958489  0.990437  9.554635e-01  0.873914  0.982605
# 4  0.401795  0.084673  0.341004  0.787663  9.799408e-01  0.457354  0.394014
#
#        base  is_iceberg_base  is_iceberg_max  is_iceberg_min  is_iceberg_mean  \
# 0  0.005586         0.005586        0.434977    5.586000e-03         0.108944
# 1  0.031688         0.031688        0.985510    3.168800e-02         0.732079
# 2  0.001000         0.001000        0.918696    4.462567e-48         0.199201
# 3  0.999000         0.999000        0.999560    8.739136e-01         0.980513
# 4  0.022151         0.022151        0.979941    9.555449e-03         0.389036
#
#    is_iceberg_median
# 0           0.073844
# 1           0.795579
# 2           0.185977
# 3           0.995533
# 4           0.394014

# %%
cutoff_lo = 0.8
cutoff_hi = 0.2
concat_sub['is_iceberg'] = np.where(np.all(concat_sub.iloc[:,0:all_files_cnt] > cutoff_lo, axis=1), 
                                    concat_sub['is_iceberg_max'], 
                                    np.where(np.all(concat_sub.iloc[:,0:all_files_cnt] < cutoff_hi, axis=1),
                                             concat_sub['is_iceberg_min'], 
                                             concat_sub['is_iceberg_base']))
#concat_sub['is_iceberg'] = np.clip(concat_sub['is_iceberg'].values, 0.001, 0.999)
concat_sub['id'] = best_df['id']
concat_sub[['id', 'is_iceberg']].to_csv('stack_minmax_bestbase2.csv', 
                                        index=False)

concat_sub.head(10)
# Out:
#          a0        a1        a2        a3        a4        a5        a6  \
# 0  0.103387  0.073844  0.165315  0.214610  0.066792  0.093266  0.209001
# 1  0.985510  0.795579  0.660264  0.895995  0.937345  0.963237  0.701245
# 2  0.918696  0.420294  0.244674  0.034479  0.238906  0.185977  0.055742
# 3  0.995533  0.998610  0.997191  0.997006  0.992169  0.999560  0.996637
# 4  0.832899  0.081664  0.089288  0.531016  0.356168  0.466361  0.009555
# 5  0.984342  0.876293  0.980828  0.377736  0.250300  0.193644  0.044427
# 6  0.079495  0.043564  0.045362  0.109253  0.051750  0.049468  0.060563
# 7  0.999483  0.999459  0.998909  0.998439  0.999486  0.999839  0.999946
# 8  0.000571  0.000044  0.000219  0.003423  0.000002  0.000210  0.000282
# 9  0.000168  0.000013  0.000103  0.002302  0.000059  0.000439  0.000261
#
#          a7        a8        a9    ...          a12       a13      base  \
# 0  0.038126  0.047048  0.098136    ...     0.434977  0.037466  0.005586
# 1  0.899046  0.724682  0.533985    ...     0.399325  0.679148  0.031688
# 2  0.327146  0.228813  0.048829    ...     0.211692  0.063756  0.001000
# 3  0.973960  0.997117  0.958489    ...     0.873914  0.982605  0.999000
# 4  0.401795  0.084673  0.341004    ...     0.457354  0.394014  0.022151
# 5  0.330260  0.801545  0.313811    ...     0.421976  0.466143  0.051959
# 6  0.071390  0.112617  0.044988    ...     0.188994  0.066545  0.003916
# 7  0.997832  0.996569  0.992122    ...     0.968300  0.997253  0.999000
# 8  0.000790  0.000052  0.006214    ...     0.012000  0.001630  0.001000
# 9  0.000243  0.000165  0.008745    ...     0.000000  0.001573  0.001000
#
#    is_iceberg_base  is_iceberg_max  is_iceberg_min  is_iceberg_mean  \
# 0         0.005586        0.434977    5.586000e-03         0.108944
# 1         0.031688        0.985510    3.168800e-02         0.732079
# 2         0.001000        0.918696    4.462567e-48         0.199201
# 3         0.999000        0.999560    8.739136e-01         0.980513
# 4         0.022151        0.979941    9.555449e-03         0.389036
# 5         0.051959        0.984342    1.332589e-11         0.419285
# 6         0.003916        0.188994    3.916000e-03         0.064929
# 7         0.999000        0.999946    9.683000e-01         0.995500
# 8         0.001000        0.012000    1.697536e-07         0.001812
# 9         0.001000        0.008745    0.000000e+00         0.001071
#
#    is_iceberg_median    is_iceberg        id
# 0           0.073844  5.586000e-03  5941774d
# 1           0.795579  3.168800e-02  4023181e
# 2           0.185977  1.000000e-03  b20200e4
# 3           0.995533  9.995600e-01  e7f018bb
# 4           0.394014  2.215100e-02  4371c8c3
# 5           0.330260  5.195900e-02  a8d9b1fd
# 6           0.051750  3.916000e-03  29e7727e
# 7           0.998439  9.999459e-01  92a51ffb
# 8           0.000571  1.697536e-07  c769ac97
# 9           0.000243  0.000000e+00  aee0547d
#
# [10 rows x 22 columns]

# %%
diff_res = concat_sub['is_iceberg']-concat_sub['base']
print(type(diff_res))
cnt = np.where(diff_res!=0)
print(cnt[0].shape)
print(concat_sub['is_iceberg'].std())
# Out:
# <class 'pandas.core.series.Series'>
# (1408,)
# 0.376150337052

# %%
concat_sub['is_iceberg'] = np.clip(concat_sub['is_iceberg'].values, 0.001, 0.999)
concat_sub[['id', 'is_iceberg']].to_csv('clip_stack_minmax_bestbase2.csv', 
                                        index=False)

# %%
diff_res = concat_sub['is_iceberg']-concat_sub['base']
print(type(diff_res))
cnt = np.where(diff_res!=0)
print(cnt[0].shape)
print(concat_sub['is_iceberg'].std())
# Out:
# <class 'pandas.core.series.Series'>
# (106,)
# 0.375996328199
