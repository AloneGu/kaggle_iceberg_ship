# %%
import pickle
# https://www.kaggle.com/submarineering/submarineering-even-better-public-score-until-now
ens_file = 'all_xgb_sub_fold_3_rnd_42_bk_1277.csv' # 1277
other_files = [
    '../results/cnn_1_aug_1_fold8.csv',
    '../results/cnn_2_aug_1_fold8.csv',
    '../results/cnn_3_aug_1_fold8.csv',
    '../results/cnn_5_aug_1_fold8.csv',
    '../results/cnn_4_aug1_best_acc_sub.csv',
    '../results/incept_aug1_sub.csv',
    '../results/resnet_aug1_sub.csv',
    '../results/xception_aug1_sub.csv',
    '../results/vgg_aug1_sub.csv',
    '../features/other_model_gbrt2.pkl',
    '../features/other_model_lgb2.pkl',
    '../features/other_model_lr2.pkl',
    '../features/other_model_rf2.pkl',
    '../features/other_model_xgb2.pkl',
]

import pandas as pd
best_df = pd.read_csv(ens_file)
best_df.head()
# Out:
#          id  is_iceberg
# 0  5941774d    0.020997
# 1  4023181e    0.757023
# 2  b20200e4    0.041015
# 3  e7f018bb    0.997236
# 4  4371c8c3    0.117294

# %%
other_res = []
for f in other_files:
    if f.endswith('csv'):
        other_res.append(pd.read_csv(f).is_iceberg.values)
    else:
        with open(f,'rb') as fin:
            a,b = pickle.load(fin)
            other_res.append(b.flatten())
    
import numpy as np
other_res = np.vstack(other_res).T

# %%
concat_df = pd.DataFrame(other_res,columns=['a{}'.format(i) for i in range(len(other_files))])
concat_df['base'] = best_df.is_iceberg
concat_df.head()
# Out:
#          a0        a1        a2        a3        a4        a5        a6  \
# 0  0.195756  0.134401  0.144608  0.296872  0.066792  0.093266  0.209001
# 1  0.986309  0.861850  0.919460  0.961062  0.937345  0.963237  0.701245
# 2  0.936076  0.572117  0.543071  0.213261  0.238906  0.185977  0.055742
# 3  0.998148  0.995843  0.996963  0.998587  0.992169  0.999560  0.996637
# 4  0.800216  0.006921  0.064853  0.419967  0.356168  0.466361  0.009555
#
#          a7        a8        a9       a10           a11       a12       a13  \
# 0  0.038126  0.047048  0.125865  0.141511  1.430462e-02  0.389589  0.134683
# 1  0.899046  0.724682  0.646595  0.945121  1.000000e+00  0.664402  0.878118
# 2  0.327146  0.228813  0.562446  0.312999  7.389628e-38  0.378330  0.536110
# 3  0.973960  0.997117  0.994916  0.982090  9.992191e-01  0.942157  0.979548
# 4  0.401795  0.084673  0.899276  0.923296  1.000000e+00  0.689455  0.876706
#
#        base
# 0  0.020997
# 1  0.757023
# 2  0.041015
# 3  0.997236
# 4  0.117294

# %%
concat_df.corr()
# Out:
#             a0        a1        a2        a3        a4        a5        a6  \
# a0    1.000000  0.805236  0.799597  0.762765  0.782289  0.696394  0.586376
# a1    0.805236  1.000000  0.962575  0.887545  0.892243  0.787986  0.768115
# a2    0.799597  0.962575  1.000000  0.866912  0.855166  0.715269  0.707056
# a3    0.762765  0.887545  0.866912  1.000000  0.904974  0.842154  0.805658
# a4    0.782289  0.892243  0.855166  0.904974  1.000000  0.884554  0.859869
# a5    0.696394  0.787986  0.715269  0.842154  0.884554  1.000000  0.922659
# a6    0.586376  0.768115  0.707056  0.805658  0.859869  0.922659  1.000000
# a7    0.684978  0.825611  0.760176  0.843053  0.886534  0.947634  0.929019
# a8    0.730108  0.888263  0.854904  0.800732  0.815577  0.734770  0.694257
# a9    0.712897  0.718179  0.706119  0.684449  0.688177  0.611294  0.580110
# a10   0.795483  0.751659  0.737775  0.742016  0.733725  0.650376  0.582144
# a11   0.715013  0.621216  0.577931  0.680534  0.690478  0.690432  0.601753
# a12   0.806122  0.757281  0.726991  0.760602  0.767998  0.738159  0.672472
# a13   0.788570  0.745628  0.739412  0.720878  0.721820  0.625591  0.573842
# base  0.703267  0.881111  0.824065  0.872081  0.878213  0.855570  0.814376
#
#             a7        a8        a9       a10       a11       a12       a13  \
# a0    0.684978  0.730108  0.712897  0.795483  0.715013  0.806122  0.788570
# a1    0.825611  0.888263  0.718179  0.751659  0.621216  0.757281  0.745628
# a2    0.760176  0.854904  0.706119  0.737775  0.577931  0.726991  0.739412
# a3    0.843053  0.800732  0.684449  0.742016  0.680534  0.760602  0.720878
# a4    0.886534  0.815577  0.688177  0.733725  0.690478  0.767998  0.721820
# a5    0.947634  0.734770  0.611294  0.650376  0.690432  0.738159  0.625591
# a6    0.929019  0.694257  0.580110  0.582144  0.601753  0.672472  0.573842
# a7    1.000000  0.769097  0.621297  0.647414  0.648616  0.734875  0.625761
# a8    0.769097  1.000000  0.642495  0.659422  0.543989  0.706487  0.650344
# a9    0.621297  0.642495  1.000000  0.906386  0.703034  0.849713  0.937020
# a10   0.647414  0.659422  0.906386  1.000000  0.805296  0.910549  0.982301
# a11   0.648616  0.543989  0.703034  0.805296  1.000000  0.802869  0.777537
# a12   0.734875  0.706487  0.849713  0.910549  0.802869  1.000000  0.902301
# a13   0.625761  0.650344  0.937020  0.982301  0.777537  0.902301  1.000000
# base  0.870530  0.839641  0.757509  0.754201  0.690824  0.788244  0.737517
#
#           base
# a0    0.703267
# a1    0.881111
# a2    0.824065
# a3    0.872081
# a4    0.878213
# a5    0.855570
# a6    0.814376
# a7    0.870530
# a8    0.839641
# a9    0.757509
# a10   0.754201
# a11   0.690824
# a12   0.788244
# a13   0.737517
# base  1.000000

# %%
concat_df.corr().mean()

# a0      0.640213
# a1      0.775139
# a2      0.752027
# a3      0.775800
# a4      0.794752
# a5      0.766002
# a6      0.741070
# a7      0.785623
# a8      0.770391
# a9      0.744807
# a10     0.761894
# a11     0.697090
# a12     0.763554
# a13     0.766731
# base    0.641168
# dtype: float64
# choose a0,a2,a6,a9,others 1, score 1322
# use all , other 2nd version, score 1316
# Out:
# a0      0.757940
# a1      0.819510
# a2      0.788930
# a3      0.811624
# a4      0.824108
# a5      0.780189
# a6      0.739847
# a7      0.786306
# a8      0.755339
# a9      0.741245
# a10     0.777250
# a11     0.703301
# a12     0.794978
# a13     0.768568
# base    0.817810
# dtype: float64

# %%
print(other_res.shape)
other_median = np.median(other_res,axis=1)
print(other_median[:5])
other_mean = np.mean(other_res,axis=1)
print(other_mean[:5])
# Out:
# (8424, 14)
# [ 0.13454209  0.90925287  0.32007252  0.99624008  0.44316367]
# [ 0.14513006  0.8634624   0.36364236  0.98906531  0.49994581]

# %%
concat_sub = concat_df.copy()
concat_sub['is_iceberg_base'] = best_df['is_iceberg']
all_files_cnt = len(other_files)+1
concat_sub['is_iceberg_max'] = concat_sub.iloc[:, 0:all_files_cnt].max(axis=1)
concat_sub['is_iceberg_min'] = concat_sub.iloc[:, 0:all_files_cnt].min(axis=1)
concat_sub['is_iceberg_mean'] = concat_sub.iloc[:, 0:all_files_cnt].mean(axis=1)
concat_sub['is_iceberg_median'] = concat_sub.iloc[:, 0:all_files_cnt].median(axis=1)

concat_sub.head()
# Out:
#          a0        a1        a2        a3        a4        a5        a6  \
# 0  0.195756  0.134401  0.144608  0.296872  0.066792  0.093266  0.209001
# 1  0.986309  0.861850  0.919460  0.961062  0.937345  0.963237  0.701245
# 2  0.936076  0.572117  0.543071  0.213261  0.238906  0.185977  0.055742
# 3  0.998148  0.995843  0.996963  0.998587  0.992169  0.999560  0.996637
# 4  0.800216  0.006921  0.064853  0.419967  0.356168  0.466361  0.009555
#
#          a7        a8        a9       a10           a11       a12       a13  \
# 0  0.038126  0.047048  0.125865  0.141511  1.430462e-02  0.389589  0.134683
# 1  0.899046  0.724682  0.646595  0.945121  1.000000e+00  0.664402  0.878118
# 2  0.327146  0.228813  0.562446  0.312999  7.389628e-38  0.378330  0.536110
# 3  0.973960  0.997117  0.994916  0.982090  9.992191e-01  0.942157  0.979548
# 4  0.401795  0.084673  0.899276  0.923296  1.000000e+00  0.689455  0.876706
#
#        base  is_iceberg_base  is_iceberg_max  is_iceberg_min  is_iceberg_mean  \
# 0  0.020997         0.020997        0.389589    1.430462e-02         0.136855
# 1  0.757023         0.757023        1.000000    6.465948e-01         0.856366
# 2  0.041015         0.041015        0.936076    7.389628e-38         0.342134
# 3  0.997236         0.997236        0.999560    9.421567e-01         0.989610
# 4  0.117294         0.117294        1.000000    6.920645e-03         0.474436
#
#    is_iceberg_median
# 0           0.134401
# 1           0.899046
# 2           0.312999
# 3           0.996637
# 4           0.419967

# %%
cutoff_lo = 0.8
cutoff_hi = 0.2
concat_sub['is_iceberg'] = np.where(np.all(concat_sub.iloc[:,0:all_files_cnt] > cutoff_lo, axis=1), 
                                    concat_sub['is_iceberg_max'], 
                                    np.where(np.all(concat_sub.iloc[:,0:all_files_cnt] < cutoff_hi, axis=1),
                                             concat_sub['is_iceberg_min'], 
                                             concat_sub['is_iceberg_base']))
#concat_sub['is_iceberg'] = np.clip(concat_sub['is_iceberg'].values, 0.001, 0.999)
concat_sub['id'] = best_df['id']
concat_sub[['id', 'is_iceberg']].to_csv('stack_minmax_bestbase3.csv', 
                                        index=False)

concat_sub.head(10)
# Out:
#          a0        a1        a2        a3        a4        a5        a6  \
# 0  0.195756  0.134401  0.144608  0.296872  0.066792  0.093266  0.209001
# 1  0.986309  0.861850  0.919460  0.961062  0.937345  0.963237  0.701245
# 2  0.936076  0.572117  0.543071  0.213261  0.238906  0.185977  0.055742
# 3  0.998148  0.995843  0.996963  0.998587  0.992169  0.999560  0.996637
# 4  0.800216  0.006921  0.064853  0.419967  0.356168  0.466361  0.009555
# 5  0.969114  0.608777  0.927533  0.130899  0.250300  0.193644  0.044427
# 6  0.147382  0.053463  0.073740  0.149254  0.051750  0.049468  0.060563
# 7  0.999754  0.998552  0.996662  0.999250  0.999486  0.999839  0.999946
# 8  0.005384  0.000082  0.000488  0.004006  0.000002  0.000210  0.000282
# 9  0.000642  0.000180  0.000742  0.001289  0.000059  0.000439  0.000261
#
#          a7        a8        a9    ...          a12       a13      base  \
# 0  0.038126  0.047048  0.125865    ...     0.389589  0.134683  0.020997
# 1  0.899046  0.724682  0.646595    ...     0.664402  0.878118  0.757023
# 2  0.327146  0.228813  0.562446    ...     0.378330  0.536110  0.041015
# 3  0.973960  0.997117  0.994916    ...     0.942157  0.979548  0.997236
# 4  0.401795  0.084673  0.899276    ...     0.689455  0.876706  0.117294
# 5  0.330260  0.801545  0.473977    ...     0.445534  0.561407  0.177663
# 6  0.071390  0.112617  0.000295    ...     0.123392  0.014316  0.007182
# 7  0.997832  0.996569  0.999179    ...     0.981688  0.996107  0.997051
# 8  0.000790  0.000052  0.001617    ...     0.004000  0.003478  0.001799
# 9  0.000243  0.000165  0.000215    ...     0.008000  0.000698  0.001599
#
#    is_iceberg_base  is_iceberg_max  is_iceberg_min  is_iceberg_mean  \
# 0         0.020997        0.389589    1.430462e-02         0.136855
# 1         0.757023        1.000000    6.465948e-01         0.856366
# 2         0.041015        0.936076    7.389628e-38         0.342134
# 3         0.997236        0.999560    9.421567e-01         0.989610
# 4         0.117294        1.000000    6.920645e-03         0.474436
# 5         0.177663        0.969114    7.390925e-09         0.428357
# 6         0.007182        0.149254    2.950247e-04         0.064762
# 7         0.997051        0.999946    9.816881e-01         0.997326
# 8         0.001799        0.005384    6.185342e-09         0.001668
# 9         0.001599        0.008000    1.118503e-12         0.000982
#
#    is_iceberg_median    is_iceberg        id
# 0           0.134401  2.099743e-02  5941774d
# 1           0.899046  7.570229e-01  4023181e
# 2           0.312999  4.101531e-02  b20200e4
# 3           0.996637  9.995600e-01  e7f018bb
# 4           0.419967  1.172941e-01  4371c8c3
# 5           0.445534  1.776626e-01  a8d9b1fd
# 6           0.053463  2.950247e-04  29e7727e
# 7           0.998552  9.999459e-01  92a51ffb
# 8           0.000790  6.185342e-09  c769ac97
# 9           0.000261  1.118503e-12  aee0547d
#
# [10 rows x 22 columns]

# %%
diff_res = concat_sub['is_iceberg']-concat_sub['base']
print(type(diff_res))
cnt = np.where(diff_res!=0)
print(cnt[0].shape)
print(concat_sub['is_iceberg'].std())
# Out:
# <class 'pandas.core.series.Series'>
# (1731,)
# 0.397689771202

# %%
concat_sub['is_iceberg'] = np.clip(concat_sub['is_iceberg'].values, 0.001, 0.999)
diff_res = concat_sub['is_iceberg']-concat_sub['base']
print(type(diff_res))
cnt = np.where(diff_res!=0)
print(cnt[0].shape)
print(concat_sub['is_iceberg'].std())
# Out:
# <class 'pandas.core.series.Series'>
# (1731,)
# 0.397497682469
