# %%
import pickle
# https://www.kaggle.com/submarineering/submarineering-even-better-public-score-until-now
#ens_file = 'all_xgb3rd_sub_fold_3_rnd_84_local_1251.csv' # 1244
ens_file ='all_xgb3rd_sub_fold_3_rnd_42_local_1329.csv' # submit this one later and stacking result
other_files = [
    'vgg_new.csv', #1400
    #'submission54.csv', #1326
    '../results/cnn_1_aug_1_fold8.csv',
    '../results/cnn_2_aug_1_fold8.csv',
    '../results/cnn_3_aug_1_fold8.csv',
    '../results/cnn_5_aug_1_fold8.csv',
    #'../results/cnn_4_aug1_best_acc_sub.csv',
    '../results/incept_aug1_sub.csv',
    '../results/resnet_aug1_sub.csv',
    '../results/xception_aug1_sub.csv',
    '../results/vgg_aug1_sub.csv',
    '../features/other_model_gbrt2.pkl',
    '../features/other_model_lgb2.pkl',
    '../features/other_model_lr2.pkl',
    '../features/other_model_rf2.pkl',
    '../features/other_model_xgb2.pkl',
]

import pandas as pd
best_df = pd.read_csv(ens_file)
best_df.head()
# Out:
#          id  is_iceberg
# 0  5941774d    0.024709
# 1  4023181e    0.937371
# 2  b20200e4    0.073025
# 3  e7f018bb    0.997634
# 4  4371c8c3    0.038527

# %%
other_res = []
for f in other_files:
    if f.endswith('csv'):
        other_res.append(pd.read_csv(f).is_iceberg.values)
    else:
        with open(f,'rb') as fin:
            a,b = pickle.load(fin)
            other_res.append(b.flatten())
    
import numpy as np
other_res = np.vstack(other_res).T

# %%
concat_df = pd.DataFrame(other_res,columns=['a{}'.format(i) for i in range(len(other_files))])
concat_df['base'] = best_df.is_iceberg
concat_df.head()
# Out:
#          a0        a1        a2        a3        a4        a5        a6  \
# 0  0.030369  0.195756  0.134401  0.144608  0.296872  0.093266  0.209001
# 1  0.364333  0.986309  0.861850  0.919460  0.961062  0.963237  0.701245
# 2  0.017298  0.936076  0.572117  0.543071  0.213261  0.185977  0.055742
# 3  0.998199  0.998148  0.995843  0.996963  0.998587  0.999560  0.996637
# 4  0.657598  0.800216  0.006921  0.064853  0.419967  0.466361  0.009555
#
#          a7        a8        a9       a10           a11       a12       a13  \
# 0  0.038126  0.047048  0.125865  0.141511  1.430462e-02  0.389589  0.134683
# 1  0.899046  0.724682  0.646595  0.945121  1.000000e+00  0.664402  0.878118
# 2  0.327146  0.228813  0.562446  0.312999  7.389628e-38  0.378330  0.536110
# 3  0.973960  0.997117  0.994916  0.982090  9.992191e-01  0.942157  0.979548
# 4  0.401795  0.084673  0.899276  0.923296  1.000000e+00  0.689455  0.876706
#
#        base
# 0  0.024709
# 1  0.937371
# 2  0.073025
# 3  0.997634
# 4  0.038527

# %%
concat_df.corr()
# Out:
#             a0        a1        a2        a3        a4        a5        a6  \
# a0    1.000000  0.531075  0.687510  0.610146  0.677998  0.765519  0.734071
# a1    0.531075  1.000000  0.805236  0.799597  0.762765  0.696394  0.586376
# a2    0.687510  0.805236  1.000000  0.962575  0.887545  0.787986  0.768115
# a3    0.610146  0.799597  0.962575  1.000000  0.866912  0.715269  0.707056
# a4    0.677998  0.762765  0.887545  0.866912  1.000000  0.842154  0.805658
# a5    0.765519  0.696394  0.787986  0.715269  0.842154  1.000000  0.922659
# a6    0.734071  0.586376  0.768115  0.707056  0.805658  0.922659  1.000000
# a7    0.778208  0.684978  0.825611  0.760176  0.843053  0.947634  0.929019
# a8    0.743889  0.730108  0.888263  0.854904  0.800732  0.734770  0.694257
# a9    0.557971  0.712897  0.718179  0.706119  0.684449  0.611294  0.580110
# a10   0.534747  0.795483  0.751659  0.737775  0.742016  0.650376  0.582144
# a11   0.519477  0.715013  0.621216  0.577931  0.680534  0.690432  0.601753
# a12   0.646218  0.806122  0.757281  0.726991  0.760602  0.738159  0.672472
# a13   0.518119  0.788570  0.745628  0.739412  0.720878  0.625591  0.573842
# base  0.784274  0.695659  0.886856  0.836734  0.885923  0.844396  0.811269
#
#             a7        a8        a9       a10       a11       a12       a13  \
# a0    0.778208  0.743889  0.557971  0.534747  0.519477  0.646218  0.518119
# a1    0.684978  0.730108  0.712897  0.795483  0.715013  0.806122  0.788570
# a2    0.825611  0.888263  0.718179  0.751659  0.621216  0.757281  0.745628
# a3    0.760176  0.854904  0.706119  0.737775  0.577931  0.726991  0.739412
# a4    0.843053  0.800732  0.684449  0.742016  0.680534  0.760602  0.720878
# a5    0.947634  0.734770  0.611294  0.650376  0.690432  0.738159  0.625591
# a6    0.929019  0.694257  0.580110  0.582144  0.601753  0.672472  0.573842
# a7    1.000000  0.769097  0.621297  0.647414  0.648616  0.734875  0.625761
# a8    0.769097  1.000000  0.642495  0.659422  0.543989  0.706487  0.650344
# a9    0.621297  0.642495  1.000000  0.906386  0.703034  0.849713  0.937020
# a10   0.647414  0.659422  0.906386  1.000000  0.805296  0.910549  0.982301
# a11   0.648616  0.543989  0.703034  0.805296  1.000000  0.802869  0.777537
# a12   0.734875  0.706487  0.849713  0.910549  0.802869  1.000000  0.902301
# a13   0.625761  0.650344  0.937020  0.982301  0.777537  0.902301  1.000000
# base  0.863573  0.843925  0.731615  0.728006  0.650455  0.762737  0.714079
#
#           base
# a0    0.784274
# a1    0.695659
# a2    0.886856
# a3    0.836734
# a4    0.885923
# a5    0.844396
# a6    0.811269
# a7    0.863573
# a8    0.843925
# a9    0.731615
# a10   0.728006
# a11   0.650455
# a12   0.762737
# a13   0.714079
# base  1.000000

# %%
concat_df.corr().mean()

# a0      0.640213
# a1      0.775139
# a2      0.752027
# a3      0.775800
# a4      0.794752
# a5      0.766002
# a6      0.741070
# a7      0.785623
# a8      0.770391
# a9      0.744807
# a10     0.761894
# a11     0.697090
# a12     0.763554
# a13     0.766731
# base    0.641168
# dtype: float64
# choose a0,a2,a6,a9,others 1, score 1322
# use all , other 2nd version, score 1316
# Out:
# a0      0.672615
# a1      0.740685
# a2      0.806244
# a3      0.773440
# a4      0.797415
# a5      0.771509
# a6      0.731253
# a7      0.778621
# a8      0.750846
# a9      0.730839
# a10     0.762238
# a11     0.689210
# a12     0.785158
# a13     0.753426
# base    0.802633
# dtype: float64

# %%
print(other_res.shape)
other_median = np.median(other_res,axis=1)
print(other_median[:5])
other_mean = np.mean(other_res,axis=1)
print(other_mean[:5])
# Out:
# (8424, 14)
# [ 0.13454209  0.88858225  0.32007252  0.99679967  0.56197927]
# [ 0.14252839  0.82253296  0.34781326  0.98949601  0.52147653]

# %%
concat_sub = concat_df.copy()
concat_sub['is_iceberg_base'] = best_df['is_iceberg']
all_files_cnt = len(other_files)+1
concat_sub['is_iceberg_max'] = concat_sub.iloc[:, 0:all_files_cnt].max(axis=1)
concat_sub['is_iceberg_min'] = concat_sub.iloc[:, 0:all_files_cnt].min(axis=1)
concat_sub['is_iceberg_mean'] = concat_sub.iloc[:, 0:all_files_cnt].mean(axis=1)
concat_sub['is_iceberg_median'] = concat_sub.iloc[:, 0:all_files_cnt].median(axis=1)

concat_sub.head()
# Out:
#          a0        a1        a2        a3        a4        a5        a6  \
# 0  0.030369  0.195756  0.134401  0.144608  0.296872  0.093266  0.209001
# 1  0.364333  0.986309  0.861850  0.919460  0.961062  0.963237  0.701245
# 2  0.017298  0.936076  0.572117  0.543071  0.213261  0.185977  0.055742
# 3  0.998199  0.998148  0.995843  0.996963  0.998587  0.999560  0.996637
# 4  0.657598  0.800216  0.006921  0.064853  0.419967  0.466361  0.009555
#
#          a7        a8        a9       a10           a11       a12       a13  \
# 0  0.038126  0.047048  0.125865  0.141511  1.430462e-02  0.389589  0.134683
# 1  0.899046  0.724682  0.646595  0.945121  1.000000e+00  0.664402  0.878118
# 2  0.327146  0.228813  0.562446  0.312999  7.389628e-38  0.378330  0.536110
# 3  0.973960  0.997117  0.994916  0.982090  9.992191e-01  0.942157  0.979548
# 4  0.401795  0.084673  0.899276  0.923296  1.000000e+00  0.689455  0.876706
#
#        base  is_iceberg_base  is_iceberg_max  is_iceberg_min  is_iceberg_mean  \
# 0  0.024709         0.024709        0.389589    1.430462e-02         0.134674
# 1  0.937371         0.937371        1.000000    3.643330e-01         0.830189
# 2  0.073025         0.073025        0.936076    7.389628e-38         0.329494
# 3  0.997634         0.997634        0.999560    9.421567e-01         0.990039
# 4  0.038527         0.038527        1.000000    6.920645e-03         0.489280
#
#    is_iceberg_median
# 0           0.134401
# 1           0.899046
# 2           0.312999
# 3           0.996963
# 4           0.466361

# %%
cutoff_lo = 0.8
cutoff_hi = 0.2
concat_sub['is_iceberg'] = np.where(np.all(concat_sub.iloc[:,0:all_files_cnt] > cutoff_lo, axis=1), 
                                    concat_sub['is_iceberg_max'], 
                                    np.where(np.all(concat_sub.iloc[:,0:all_files_cnt] < cutoff_hi, axis=1),
                                             concat_sub['is_iceberg_min'], 
                                             concat_sub['is_iceberg_base']))
concat_sub['is_iceberg'] = np.clip(concat_sub['is_iceberg'].values, 0.00001, 0.99999)
concat_sub['id'] = best_df['id']
concat_sub[['id', 'is_iceberg']].to_csv('stack_minmax_bestbase5.csv', 
                                        index=False)

concat_sub[['id', 'is_iceberg']].head(10)
# Out:
#          id  is_iceberg
# 0  5941774d    0.024709
# 1  4023181e    0.937371
# 2  b20200e4    0.073025
# 3  e7f018bb    0.999560
# 4  4371c8c3    0.038527
# 5  a8d9b1fd    0.159981
# 6  29e7727e    0.000295
# 7  92a51ffb    0.999946
# 8  c769ac97    0.000010
# 9  aee0547d    0.000010

# %%
diff_res = concat_sub['is_iceberg']-concat_sub['base']
print(type(diff_res))
cnt = np.where(diff_res!=0)
print(cnt[0].shape)
print(concat_sub['is_iceberg'].std())
# Out:
# <class 'pandas.core.series.Series'>
# (1677,)
# 0.406175486238
